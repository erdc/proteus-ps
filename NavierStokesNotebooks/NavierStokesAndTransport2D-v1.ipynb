# %%
from proteus.iproteus import * 
# from proteus import default_n, default_s, default_so
Profiling.logLevel=3
Profiling.verbose=False

load_macros("macros.tex")
# Out:
# $\newcommand{\C}{\mathbb{C}}$
# $\newcommand{\Du}{\underline{D}}$
# $\newcommand{\veps}{\varepsilon}$
# $\newcommand{\eps}{\epsilon}$
# $\newcommand{\f}{\textbf{f}}$
# $\newcommand{\fb}{\textbf{f}}$
# $\newcommand{\F}{\mathbb{F}}$
# $\newcommand{\Fb}{\textbf{F}}$
# $\newcommand{\gb}{\textbf{g}}$
# $\newcommand{\h}{\textbf{h}}$
# $\newcommand{\kb}{\textbf{k}}$
# $\newcommand{\M}{\mathcal{M}}$
# $\newcommand{\N}{\mathbb{N}}$
# $\newcommand{\Norm}{\textbf{N}}$
# $\newcommand{\n}{\textbf{n}}$
# $\newcommand{\vp}{\varphi}$
# $\newcommand{\vph}{\hat{\varphi}}$
# $\newcommand{\p}{\phi}$
# $\newcommand{\Proj}{\mathbb{P}}$
# $\newcommand{\Pcal}{\mathcal{P}}$
# $\newcommand{\Q}{\mathbb{Q}}$
# $\newcommand{\R}{\mathbb{R}}$
# $\newcommand{\rb}{\textbf{r}}$
# $\newcommand{\s}[1]{\mathcal{#1}}$
# $\newcommand{\supp}{\text{supp}}$
# $\newcommand{\Surf}{\textbf{S}}$
# $\newcommand{\tpsi}{\tilde{\psi}}$
# $\newcommand{\ub}{\textbf{u}}$
# $\newcommand{\U}{\textbf{U}}$
# $\newcommand{\vb}{\textbf{v}}$
# $\newcommand{\V}{\mathbb{V}}$
# $\newcommand{\wb}{\textbf{w}}$
# $\newcommand{\x}{\textbf{x}}$
# $\newcommand{\xh}{\hat{x}}$
# $\newcommand{\X}{\textbf{X}}$
# $\newcommand{\y}{\textbf{y}}$
# $\newcommand{\yh}{\hat{y}}$
# $\newcommand{\Y}{\textbf{Y}}$
# $\newcommand{\Z}{\mathbb{Z}}$
# $\DeclareMathOperator{\sech}{sech}$
# $\DeclareMathOperator{\atanh}{atanh}$
# $\DeclareMathOperator{\sign}{sign}$
# $\DeclareMathOperator{\tr}{Trace}$
# $\DeclareMathOperator{\gradsymm}{\nabla_{s}}$
# $\DeclareMathOperator{\divergence}{div}$
# $\DeclareMathOperator{\diag}{diag}$
# $\DeclareMathOperator*{\argmin}{argmin}$
# $\DeclareMathOperator*{\argmax}{argmax}$
# $\DeclareMathOperator{\Span}{Span}$
# $\DeclareMathOperator{\rank}{rank}$
# $\newcommand{\br}[1]{\left\langle #1 \right\rangle}$
# $\newcommand{\paren}[1]{\left(#1\right)}$
# $\newcommand{\sq}[1]{\left[#1\right]}$
# $\newcommand{\set}[1]{\left\{\: #1 \:\right\}}$
# $\newcommand{\setp}[2]{\left\{\, #1\: \middle|\: #2 \, \right\}}$
# $\newcommand{\abs}[1]{\left| #1 \right|}$
# $\newcommand{\norm}[1]{\left\| #1 \right\|}$
# $\newcommand{\system}[1]{\left\{ \begin{array}{rl} #1 \end{array} \right.}$
# $\newcommand{\pf}[2]{\frac{\partial #1}{\partial #2}}$
# $\newcommand{\ipt}[2]{\langle #1,#2 \rangle}$
# $\newcommand{\ip}{\int_{-\infty}^{+\infty}}$
# $\renewcommand{\ker}[1]{\mathcal{N}(#1)}$
# $\newcommand{\ran}[1]{\mathcal{R}(#1)}$

# %% [markdown]
# ## Problem Description
#
# Solve the 2D Navier-Stokes equation on a square domain.  That is, find density $\rho>0$, velocity field $\mathbf{v}:\Omega \rightarrow \mathbb{R} \times \mathbb{R}^2$ and pressure $p:\Omega\rightarrow\R$ such that
#
# $$
# \begin{equation}
# \begin{cases}
# \rho_t + \nabla\cdot(\rho\vb) = 0,&\\
# \rho\left(\frac{\partial \vb}{\partial t} + \vb\cdot\nabla\vb\right) +  \nabla p  - \nabla \cdot \left(\mu \nabla\vb\right) = \fb(x,t),&\\
# \nabla \cdot \vb  = 0,&
# \end{cases}
# \end{equation}
# $$
#
# on domain $\Omega = [0,1]^2$ and time interval $[0,T].$ Here $\mathbf{f}(x,t)$ is a smooth external force and the dynamic viscosity, $\mu>0$, is constant.
#
# Let $\partial\Omega^{in} = \{\x\in\partial\Omega \:|\: \vb\cdot \n < 0 \}$ be the inflow boundary.  We supplement the above system with initial conditions for density and velocity and inflow boundary conditions for density and dirichlet boundary conditions for velocity.
#
# $$
# \begin{equation}
#   \begin{cases}
#     \rho(\x,0) = \rho_0(\x),&\\
#     \vb(\x,0) = \vb_0(\x),&
#   \end{cases}
# \end{equation}
# $$
# and
# $$
# \begin{equation}
#   \begin{cases}
#     \left.\rho(\x,t)\right|_{\partial\Omega^{in}} = \rho^{in}(\x,t),&\\
#     \left.\vb(\x,t)\right|_{\partial\Omega} = b(\x,t),&
#   \end{cases}
# \end{equation}
# $$
#
# If $b(\x,t)=0$ then our boundary is impermeable and $\partial\Omega^{in} = \emptyset$.  However if we do allow for non zero boundary conditions for velocity, then our inflow set could be non empty.
#
# We can add inflow boundary conditions for the pressure term as well until we do our splitting in which case pressure will be fixed by our intermediate steps.
#
# ###Manufactured Solution
# Setup the problem by method of manufactured solution.
#
# We will introduce a specific example that we have implemented, but we use sympy to symbolically compute the source terms based on the navier stokes equation as defined above.  In order to change the solution, it is only necessary to update p and v below.
#
#
# A specific solution to 2D navier-stokes equation given by Guermond and Salgado is (using $\rb = (r,\theta)$ as shortcut notation )
#
# $$
# \rho(\rb,t) = 2+r\cos(\theta-\sin(t)),
# $$
#
# $$
# p(\x,t) = \sin(x)\sin(y)\sin(t),
# $$
#
# and
#
# $$
# v(\x,t) = (-y,x)^{T}\cos(t)
# $$
#
# with
#
# $$
# f(\x,t) =
# \left(\begin{split}
#  &\left(y\sin(t) - x\cos^2(t)\right)\rho(\rb,t) + \cos(x)\sin(y)\sin(t)\\
#          -&\left(x\sin(t)+y\cos^2(t)\right)\rho(\rb,t) + \sin(x)\cos(y)\sin(t)
# \end{split}\right)
# $$
#
# which we solve on the time domain $t\in [0,10].$
#
#
# After we have used Sympy to find the various source terms, we lambdify them to get a numpy function and then build a wrapper to transform the input that proteus gives into something usable.  Note that the x array for the quadrature points will be a multidimensional array. The last dimension will be 3 always though.

# %%
import variable_density2D.guermond_example_variable_density_so as so
display_src(so)
# Out:
# [       2] Mesh generated using: triangle -VApq30Dena0.00087730 mesh.poly
# ```Python
# from proteus.default_so import *
# from proteus import Context
#
# import guermond_example_variable_density
# Context.setFromModule(guermond_example_variable_density)
# ctx = Context.get()
#
# pnList = [("rho_p", "rho_n"),
#           ("mom_p", "mom_n")]
#
# name = "guermond_example_variable_density_p3"
#
# # modelSpinUpList = [1] # for model [1] take a step and then rewind time to time t^0 and proceed as usual
# # systemStepControllerType = Sequential_MinAdaptiveModelStep  # uses minimal time step from each _n model
# # systemStepControllerType = Sequential_FixedStep  # not sure what this one currently does but it should use the DT
# # systemStepControllerType = Sequential_MinModelStep # uses DT set in _n.py files
# systemStepControllerType = Sequential_FixedStep_Simple # uses time steps in so.tnList
#
# needEBQ_GLOBAL = True
# needEBQ = True
#
# tnList = ctx.tnList
#
#
# ```

# %%
# set running options here
import os
from importlib import import_module
from proteus import default_s

pList=[]
nList=[]
sList=[]
for (p,n) in so.pnList:
    so.sList.append(default_s)
    pList.append(import_module('variable_density2D.'+p))
    nList.append(import_module('variable_density2D.'+n))
    pList[-1].name = p
opts.save_dof = True
opts.dataDir='.'
opts.probDir='.'

# %%
# simulation flags for error analysis
#
#

simFlagsList = [{},{}]

# Density
simFlagsList[0]['errorQuantities']=['u']
simFlagsList[0]['errorTypes']= ['numericalSolution'] #compute error in soln and glob. mass bal
simFlagsList[0]['errorNorms']= ['L2'] #compute L2 norm in space
simFlagsList[0]['errorTimes']= ['All'] #'All', 'Last'
simFlagsList[0]['echo']=True
simFlagsList[0]['dataFile']       = 'density_%3.0e_DT_BDF%1d.db' %(DT,int(float(numerics.timeOrder)))
simFlagsList[0]['dataDir']        = os.getcwd()+'/results'
simFlagsList[0]['storeQuantities']= ['simulationData','errorData'] #include errorData for mass bal
simFlagsList[0]['storeTimes']     = ['Last']

# Momentum
simFlagsList[1]['components']=[0,1,2] # only do the pressure L2 norm for 'u'
simFlagsList[1]['errorQuantities']=['u','velocity'] # do components of 'u' and the 'velocity'
simFlagsList[1]['errorTypes']= ['numericalSolution'] #compute error in soln and glob. mass bal
simFlagsList[1]['errorNorms']= ['L2','H1'] #compute L2 norm in space or H1 or ...
simFlagsList[1]['errorTimes']= ['All'] #'All', 'Last'
simFlagsList[1]['echo']=True
simFlagsList[1]['dataFile']       = 'momentum_%3.0e_DT_BDF%1d.db' %(DT,int(float(numerics.timeOrder)))
simFlagsList[1]['dataDir']        = os.getcwd()+'/results'
simFlagsList[1]['storeQuantities']= ['simulationData','errorData'] #include errorData for mass bal
simFlagsList[1]['storeTimes']     = ['Last']

# %%
# %pdb off
# Out:
# Automatic pdb calling has been turned OFF

# %%
# ns = NumericalSolution.NS_base(so, pList, nList, so.sList, opts)
ns = NumericalSolution.NS_base(so, pList, nList, so.sList, opts,simFlagsList=simFlagsList)
ns.calculateSolution('run1')
# Out:
# [       3] Initializing NumericalSolution for guermond_example_variable_density_p3
#  System includes:
# rho_p
# mom_p
#
# [       3] Setting Archiver(s)
# [       3] Warning Numerical Solution storeQuantity = simulationData not recognized won't archive
# [       3] Warning Numerical Solution storeQuantity = errorData not recognized won't archive
# [       3] Warning Numerical Solution storeQuantity = simulationData not recognized won't archive
# [       3] Warning Numerical Solution storeQuantity = errorData not recognized won't archive
# [       3] Setting up MultilevelMesh
# [       3] Building one multilevel mesh for all models
# [       3] Generating mesh for rho_p
# [       3] Calling Triangle to generate 2D mesh forrho_p
# TriangleBaseMesh nbase=1 baseFlags= VApq30Dena0.00087730
# [       3] Converting to Proteus Mesh
# [       3] Generating 1-level mesh from coarse Triangle mesh
# [       3] Partitioning mesh among 1 processors using partitioningType = 0
# [       3] Number of Subdomain Elements Owned= 5514
# [       3] Number of Subdomain Elements = 5514
# [       3] Number of Subdomain Nodes Owned= 2833
# [       3] Number of Subdomain Nodes = 2833
# [       3] Number of Subdomain elementBoundaries Owned= 8346
# [       3] Number of Subdomain elementBoundaries = 8346
# [       3] Number of Subdomain Edges Owned= 8346
# [       3] Number of Subdomain Edges = 8346
# [       3] Finished partitioning
# [       3] *** Global ***
# Number of triangles  : 5514
# Number of edges : 8346
# Number of nodes : 2833
#
# *** Local ***
# Number of triangles  : 5514
# Number of edges : 8346
# Number of nodes : 2833
#
# [       3] Setting up MultilevelTransport for rho_p
# [       3] Building Transport for each mesh
# [       3] Generating Trial Space
# [       3] Generating Test Space
# [       3] Allocating u
# [       3] Allocating phi
# [       3] Setting Boundary Conditions
# [       3] Setting Boundary Conditions-1
# [       3] Setting Boundary Conditions-2
# [       3] Setting Boundary Conditions-2a
# [       3] Setting Boundary Conditions-3
# [       3] Setting Boundary Conditions-4
# [       3] Initializing OneLevelTransport
# [       3] Updating local to global mappings
# [       3] Building time integration object
# [       3] Calculating numerical quadrature formulas
# fluxBoundaryCondition_components set([0])
# [       4] Allocating residual and solution vectors
# [       4] Allocating Jacobian
# [       4] Building sparse matrix structure
# [       4] Allocating parallel storage
# [       4] Building Mesh Transfers
# [       4] Setting rho_p stepController to proteus.StepControl.SC_base
# [       4] Setting up MultilevelLinearSolver forrho_p
# [       4] multilevelLinearSolverChooser type= proteus.LinearSolvers.LU
# [       4] Setting up MultilevelNonLinearSolver for rho_p
# [       4] Setting up MultilevelTransport for mom_p
# [       4] Building Transport for each mesh
# [       4] Generating Trial Space
# [       4] Generating Test Space
# [       4] Allocating u
# [       4] Allocating phi
# [       4] Setting Boundary Conditions
# [       4] Setting Boundary Conditions-1
# [       4] Setting Boundary Conditions-2
# [       4] Setting Boundary Conditions-2a
# [      10] Setting Boundary Conditions-3
# [      10] Setting Boundary Conditions-4
# [      10] Initializing OneLevelTransport
# [      10] Sparse diffusion information key (0, 0) = (array([0, 1, 2], dtype=int32), array([0, 1], dtype=int32))
# [      10] Sparse diffusion information key (1, 1) = (array([0, 1, 2], dtype=int32), array([0, 1], dtype=int32))
# [      10] Updating local to global mappings
# [      10] Building time integration object
# [      10] Calculating numerical quadrature formulas
# fluxBoundaryCondition_components set([0, 1, 2])
# [      11] Allocating residual and solution vectors
# [      11] Allocating Jacobian
# [      11] Building sparse matrix structure
# [      12] Allocating parallel storage
# [      12] Building Mesh Transfers
# [      12] Setting mom_p stepController to proteus.StepControl.SC_base
# [      12] Setting up MultilevelLinearSolver formom_p
# [      12] multilevelLinearSolverChooser type= proteus.LinearSolvers.LU
# [      12] Setting up MultilevelNonLinearSolver for mom_p
# [      12] Finished setting up models and solvers
# [      12] Setting up SimTools for mom_p
# [      12] Warning SimTools storing data removing old data in /home/srobertp/proteus_files/proteus-ps/NavierStokesNotebooks/results/density_results.dat
# [      12] Warning SimTools storing data removing old data in /home/srobertp/proteus_files/proteus-ps/NavierStokesNotebooks/results/momentum_results.dat
# [      12] Using tnList from so = guermond_example_variable_density_p3
# [      12] Time sequence[0.0, 0.00625, 0.0125, 0.018750000000000003, 0.025, 0.03125, 0.037500000000000006, 0.043750000000000004, 0.05, 0.05625, 0.0625, 0.06875, 0.07500000000000001, 0.08125, 0.08750000000000001, 0.09375, 0.1, 0.10625000000000001, 0.1125, 0.11875000000000001, 0.125, 0.13125, 0.1375, 0.14375000000000002, 0.15000000000000002, 0.15625, 0.1625, 0.16875, 0.17500000000000002, 0.18125000000000002, 0.1875, 0.19375, 0.2, 0.20625000000000002, 0.21250000000000002, 0.21875, 0.225, 0.23125, 0.23750000000000002, 0.24375000000000002, 0.25, 0.25625000000000003, 0.2625, 0.26875, 0.275, 0.28125, 0.28750000000000003, 0.29375, 0.30000000000000004, 0.30625, 0.3125, 0.31875000000000003, 0.325, 0.33125000000000004, 0.3375, 0.34375, 0.35000000000000003, 0.35625, 0.36250000000000004, 0.36875, 0.375, 0.38125000000000003, 0.3875, 0.39375000000000004, 0.4, 0.40625, 0.41250000000000003, 0.41875, 0.42500000000000004, 0.43125, 0.4375, 0.44375000000000003, 0.45, 0.45625000000000004, 0.4625, 0.46875, 0.47500000000000003, 0.48125, 0.48750000000000004, 0.49375, 0.5, 0.50625, 0.5125000000000001, 0.51875, 0.525, 0.53125, 0.5375, 0.5437500000000001, 0.55, 0.55625, 0.5625, 0.56875, 0.5750000000000001, 0.58125, 0.5875, 0.59375, 0.6000000000000001, 0.6062500000000001, 0.6125, 0.61875, 0.625, 0.6312500000000001, 0.6375000000000001, 0.64375, 0.65, 0.65625, 0.6625000000000001, 0.6687500000000001, 0.675, 0.68125, 0.6875, 0.6937500000000001, 0.7000000000000001, 0.70625, 0.7125, 0.71875, 0.7250000000000001, 0.7312500000000001, 0.7375, 0.74375, 0.75, 0.7562500000000001, 0.7625000000000001, 0.76875, 0.775, 0.78125, 0.7875000000000001, 0.7937500000000001, 0.8, 0.80625, 0.8125, 0.8187500000000001, 0.8250000000000001, 0.83125, 0.8375, 0.84375, 0.8500000000000001, 0.8562500000000001, 0.8625, 0.86875, 0.875, 0.8812500000000001, 0.8875000000000001, 0.89375, 0.9, 0.90625, 0.9125000000000001, 0.9187500000000001, 0.925, 0.93125, 0.9375, 0.9437500000000001, 0.9500000000000001, 0.95625, 0.9625, 0.96875, 0.9750000000000001, 0.9812500000000001, 0.9875, 0.99375, 1.0, 1.00625, 1.0125, 1.01875, 1.0250000000000001, 1.03125, 1.0375, 1.04375, 1.05, 1.0562500000000001, 1.0625, 1.06875, 1.075, 1.08125, 1.0875000000000001, 1.09375, 1.1, 1.10625, 1.1125, 1.1187500000000001, 1.125, 1.13125, 1.1375, 1.14375, 1.1500000000000001, 1.15625, 1.1625, 1.16875, 1.175, 1.1812500000000001, 1.1875, 1.19375, 1.2000000000000002, 1.20625, 1.2125000000000001, 1.21875, 1.225, 1.2312500000000002, 1.2375, 1.2437500000000001, 1.25, 1.25625, 1.2625000000000002, 1.26875, 1.2750000000000001, 1.28125, 1.2875, 1.2937500000000002, 1.3, 1.3062500000000001, 1.3125, 1.31875, 1.3250000000000002, 1.33125, 1.3375000000000001, 1.34375, 1.35, 1.3562500000000002, 1.3625, 1.3687500000000001, 1.375, 1.38125, 1.3875000000000002, 1.39375, 1.4000000000000001, 1.40625, 1.4125, 1.4187500000000002, 1.425, 1.4312500000000001, 1.4375, 1.44375, 1.4500000000000002, 1.45625, 1.4625000000000001, 1.46875, 1.475, 1.4812500000000002, 1.4875, 1.4937500000000001, 1.5, 1.50625, 1.5125000000000002, 1.51875, 1.5250000000000001, 1.53125, 1.5375, 1.5437500000000002, 1.55, 1.5562500000000001, 1.5625, 1.56875, 1.5750000000000002, 1.58125, 1.5875000000000001, 1.59375, 1.6, 1.6062500000000002, 1.6125, 1.6187500000000001, 1.625, 1.63125, 1.6375000000000002, 1.64375, 1.6500000000000001, 1.65625, 1.6625, 1.6687500000000002, 1.675, 1.6812500000000001, 1.6875, 1.69375, 1.7000000000000002, 1.70625, 1.7125000000000001, 1.71875, 1.725, 1.7312500000000002, 1.7375, 1.7437500000000001, 1.75, 1.75625, 1.7625000000000002, 1.76875, 1.7750000000000001, 1.78125, 1.7875, 1.7937500000000002, 1.8, 1.8062500000000001, 1.8125, 1.81875, 1.8250000000000002, 1.83125, 1.8375000000000001, 1.84375, 1.85, 1.8562500000000002, 1.8625, 1.8687500000000001, 1.875, 1.88125, 1.8875000000000002, 1.89375, 1.9000000000000001, 1.90625, 1.9125, 1.9187500000000002, 1.925, 1.9312500000000001, 1.9375, 1.94375, 1.9500000000000002, 1.95625, 1.9625000000000001, 1.96875, 1.975, 1.9812500000 ...
# [      12] Setting guermond_example_variable_density_p3 systemStepController to object of type proteus.SplitOperator.Sequential_FixedStep_Simple
# [      12] Finished NumericalSolution initialization
# [      12] Setting initial conditions
# [      12] Setting initial conditions for rho_p
# [      12] Setting initial conditions on model rho_p
# [      13] Setting initial conditions for mom_p
# [      13] Setting initial conditions on model mom_p
# [      14] Attaching models and running spin-up step if requested
# [      14] Archiving initial conditions
# [      14] Estimating initial time derivative and initializing time history for model rho_p
# [      14] Choosing initial time step for model rho_p
# [      14] Initializing time step on model rho_p to dt =  6.25000e-03
# [      14] VBDF calculateElementCoefficients t= 0.00625 dt= 0.00625 alpha= 160.0
# [      14] Initializing time history for model step controller
# [      14] VBDF initialTimeHistory call 0 tLast=0.0 t=0.00625 dt= 0.00625 dt_history[0] = 0.0
# [      14] Auxiliary variable calculations for model rho_p
# [      14] Archiving initial conditions
# [      14] Estimating initial time derivative and initializing time history for model mom_p
# [      14] Choosing initial time step for model mom_p
# [      14] Initializing time step on model mom_p to dt =  6.25000e-03
# [      15] Initializing time history for model step controller
# [      15] VBDF initialTimeHistory call 0 tLast=0.0 t=0.00625 dt= 0.00625 dt_history[0] = 0.0
# [      15] Auxiliary variable calculations for model mom_p
# [      15] Initializing time step on system Default System to dt =  6.25000e-03
# [      15] Initializing step sequence  for system Default System to [(0.00625, <proteus.Transport.MultilevelTransport instance at 0x7f8efa6d13b0>), (0.00625, <proteus.Transport.MultilevelTransport instance at 0x7f8efa6de7e8>)]
# [      15] Starting time stepping
# [      15] ==============================================================
# [      15] Solving over interval [ 0.00000e+00, 6.25000e-03]
# [      15] ==============================================================
# [      15] Model: rho_p
# [      15] StepControl base stepExact t_model= 0.00625 tOut= 0.00625 t_model_last= 0.0 dt_model= 0.00625 setting to 0.00625
# [      15] VBDF calculateElementCoefficients t= 0.00625 dt= 0.00625 alpha= 160.0
# [      15]    Newton it 0 norm(r) =  0.00000e+00  		 norm(r)/(rtol*norm(r0)+atol) = 0 test=r
# [      15] VBDF calculateElementCoefficients t= 0.00625 dt= 0.00625 alpha= 160.0
# [      15] residual increase 0.0
# [      15]    Newton it 1 norm(r) =  0.00000e+00  		 norm(r)/(rtol*norm(r0)+atol) =  0.00000e+00
# [      15] Model: mom_p
# [      15] StepControl base stepExact t_model= 0.00625 tOut= 0.00625 t_model_last= 0.0 dt_model= 0.00625 setting to 0.00625
# [      15]    Newton it 0 norm(r) =  8.97918e-04  		 norm(r)/(rtol*norm(r0)+atol) = 51.1752 test=r
# [      17]    Newton it 1 norm(r) =  1.87278e-06  		 norm(r)/(rtol*norm(r0)+atol) =  1.06736e-01
# [      17] Max local divergence (dgp1 enriched all elements) =  5.37764e-17
# [      17] Global divergence =  1.40308e-16
# [      17] VBDF updateTimeHistory call 1 tLast=0.0 t=0.00625 dt= 0.00625 dt_history[0] = 0.0
# [      17] VBDF updateTimeHistory call 1 tLast=0.0 t=0.00625 dt= 0.00625 dt_history[0] = 0.0
# [      18]
# t= 0.00625; error_u_L2[0][0]= 0.00553725;
# [      18] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [      18] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [      19]
# t= 0.00625; error_u_L2[0][0]= 1.45675e-05;
# [      22]
# t= 0.00625; error_u_H1[0][0]= 0.000102327;
# [      23]
# t= 0.00625; error_velocity_L2[0][0]= 0;
# [      24]
# t= 0.00625; error_u_L2[1][0]= 1.5379e-05;
# [      27]
# t= 0.00625; error_u_H1[1][0]= 0.00011365;
# [      28]
# t= 0.00625; error_velocity_L2[1][0]= 0;
# [      29]
# t= 0.00625; error_u_L2[2][0]= 0.000568188;
# [      32]
# t= 0.00625; error_u_H1[2][0]= 0.00572643;
# [      35]
# t= 0.00625; error_velocity_L2[2][0]= 0.00280229;
# [      35] Step Taken, System time step t= 1.25000e-02, dt= 6.25000e-03
# [      35] Step Taken, Model step t= 1.25000e-02, dt= 6.25000e-03 for model mom_p
# [      37] ==============================================================
# [      37] Solving over interval [ 6.25000e-03, 1.25000e-02]
# [      37] ==============================================================
# [      37] Model: rho_p
# [      37] StepControl base stepExact t_model= 0.0125 tOut= 0.0125 t_model_last= 0.00625 dt_model= 0.00625 setting to 0.00625
# [      37] VBDF calculateElementCoefficients t= 0.0125 dt= 0.00625 alpha= 160.0
# [      37]    Newton it 0 norm(r) =  1.75989e-02  		 norm(r)/(rtol*norm(r0)+atol) = 1003.02 test=r
# [      37] VBDF calculateElementCoefficients t= 0.0125 dt= 0.00625 alpha= 160.0
# [      37]    Newton it 1 norm(r) =  1.19789e-15  		 norm(r)/(rtol*norm(r0)+atol) =  6.82716e-11
# [      37] Model: mom_p
# [      37] StepControl base stepExact t_model= 0.0125 tOut= 0.0125 t_model_last= 0.00625 dt_model= 0.00625 setting to 0.00625
# [      37]    Newton it 0 norm(r) =  2.09814e-03  		 norm(r)/(rtol*norm(r0)+atol) = 119.58 test=r
# [      39]    Newton it 1 norm(r) =  3.74914e-06  		 norm(r)/(rtol*norm(r0)+atol) =  2.13675e-01
# [      39] Max local divergence (dgp1 enriched all elements) =  5.33427e-17
# [      39] Global divergence = -7.78635e-18
# [      39] VBDF updateTimeHistory call 2 tLast=0.00625 t=0.0125 dt= 0.00625 dt_history[0] = 0.00625
# [      39] VBDF updateTimeHistory call 2 tLast=0.00625 t=0.0125 dt= 0.00625 dt_history[0] = 0.00625
# [      41]
# t= 0.0125; error_u_L2[0][0]= 0.00553601;
# [      41] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [      41] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [      41]
# t= 0.0125; error_u_L2[0][0]= 2.7665e-05;
# [      44]
# t= 0.0125; error_u_H1[0][0]= 0.00017559;
# [      45]
# t= 0.0125; error_velocity_L2[0][0]= 0;
# [      46]
# t= 0.0125; error_u_L2[1][0]= 2.91978e-05;
# [      49]
# t= 0.0125; error_u_H1[1][0]= 0.000197765;
# [      50]
# t= 0.0125; error_velocity_L2[1][0]= 0;
# [      51]
# t= 0.0125; error_u_L2[2][0]= 0.000469592;
# [      55]
# t= 0.0125; error_u_H1[2][0]= 0.00958499;
# [      57]
# t= 0.0125; error_velocity_L2[2][0]= 0.00280226;
# [      57] Step Taken, System time step t= 1.87500e-02, dt= 6.25000e-03
# [      57] Step Taken, Model step t= 1.87500e-02, dt= 6.25000e-03 for model mom_p
# [      59] ==============================================================
# [      59] Solving over interval [ 1.25000e-02, 1.87500e-02]
# [      59] ==============================================================
# [      59] Model: rho_p
# [      59] StepControl base stepExact t_model= 0.01875 tOut= 0.01875 t_model_last= 0.0125 dt_model= 0.00625 setting to 0.00625
# [      59] VBDF calculateElementCoefficients t= 0.01875 dt= 0.00625 alpha= 160.0
# [      59]    Newton it 0 norm(r) =  1.75977e-02  		 norm(r)/(rtol*norm(r0)+atol) = 1002.95 test=r
# [      59] VBDF calculateElementCoefficients t= 0.01875 dt= 0.00625 alpha= 160.0
# [      59]    Newton it 1 norm(r) =  1.19813e-15  		 norm(r)/(rtol*norm(r0)+atol) =  6.82849e-11
# [      59] Model: mom_p
# [      59] StepControl base stepExact t_model= 0.01875 tOut= 0.01875 t_model_last= 0.0125 dt_model= 0.00625 setting to 0.00625
# [      59]    Newton it 0 norm(r) =  3.40861e-03  		 norm(r)/(rtol*norm(r0)+atol) = 194.268 test=r
# [      61]    Newton it 1 norm(r) =  5.66897e-06  		 norm(r)/(rtol*norm(r0)+atol) =  3.23092e-01
# [      61] Max local divergence (dgp1 enriched all elements) =  5.37764e-17
# [      61] Global divergence =  1.53724e-16
# [      61] VBDF updateTimeHistory call 3 tLast=0.0125 t=0.01875 dt= 0.00625 dt_history[0] = 0.00625
# [      61] VBDF updateTimeHistory call 3 tLast=0.0125 t=0.01875 dt= 0.00625 dt_history[0] = 0.00625
# [      63]
# t= 0.01875; error_u_L2[0][0]= 0.00553479;
# [      63] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [      63] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [      63]
# t= 0.01875; error_u_L2[0][0]= 3.97424e-05;
# [      66]
# t= 0.01875; error_u_H1[0][0]= 0.000236248;
# [      67]
# t= 0.01875; error_velocity_L2[0][0]= 0;
# [      68]
# t= 0.01875; error_u_L2[1][0]= 4.18421e-05;
# [      71]
# t= 0.01875; error_u_H1[1][0]= 0.000266773;
# [      72]
# t= 0.01875; error_velocity_L2[1][0]= 0;
# [      73]
# t= 0.01875; error_u_L2[2][0]= 0.000504433;
# [      77]
# t= 0.01875; error_u_H1[2][0]= 0.0127352;
# [      79]
# t= 0.01875; error_velocity_L2[2][0]= 0.00280224;
# [      79] Step Taken, System time step t= 2.50000e-02, dt= 6.25000e-03
# [      79] Step Taken, Model step t= 2.50000e-02, dt= 6.25000e-03 for model mom_p
# [      81] ==============================================================
# [      81] Solving over interval [ 1.87500e-02, 2.50000e-02]
# [      81] ==============================================================
# [      81] Model: rho_p
# [      81] StepControl base stepExact t_model= 0.025 tOut= 0.025 t_model_last= 0.01875 dt_model= 0.00625 setting to 0.00625
# [      81] VBDF calculateElementCoefficients t= 0.025 dt= 0.00625 alpha= 240.0
# [      81]    Newton it 0 norm(r) =  2.63936e-02  		 norm(r)/(rtol*norm(r0)+atol) = 1504.26 test=r
# [      81] VBDF calculateElementCoefficients t= 0.025 dt= 0.00625 alpha= 240.0
# [      81]    Newton it 1 norm(r) =  1.51946e-15  		 norm(r)/(rtol*norm(r0)+atol) =  8.65986e-11
# [      81] Model: mom_p
# [      81] StepControl base stepExact t_model= 0.025 tOut= 0.025 t_model_last= 0.01875 dt_model= 0.00625 setting to 0.00625
# [      81]    Newton it 0 norm(r) =  4.95351e-03  		 norm(r)/(rtol*norm(r0)+atol) = 282.316 test=r
# [      83]    Newton it 1 norm(r) =  7.05156e-06  		 norm(r)/(rtol*norm(r0)+atol) =  4.01891e-01
# [      83] Max local divergence (dgp1 enriched all elements) =  5.72459e-17
# [      83] Global divergence =  1.04779e-17
# [      83] VBDF updateTimeHistory call 4 tLast=0.01875 t=0.025 dt= 0.00625 dt_history[0] = 0.00625
# [      83] VBDF updateTimeHistory call 4 tLast=0.01875 t=0.025 dt= 0.00625 dt_history[0] = 0.00625
# [      84]
# t= 0.025; error_u_L2[0][0]= 0.00553328;
# [      84] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [      84] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [      85]
# t= 0.025; error_u_L2[0][0]= 4.1537e-05;
# [      88]
# t= 0.025; error_u_H1[0][0]= 0.000233136;
# [      89]
# t= 0.025; error_velocity_L2[0][0]= 0;
# [      90]
# t= 0.025; error_u_L2[1][0]= 4.49369e-05;
# [      93]
# t= 0.025; error_u_H1[1][0]= 0.00027544;
# [      94]
# t= 0.025; error_velocity_L2[1][0]= 0;
# [      95]
# t= 0.025; error_u_L2[2][0]= 0.000589716;
# [      99]
# t= 0.025; error_u_H1[2][0]= 0.0152219;
# [     101]
# t= 0.025; error_velocity_L2[2][0]= 0.00280202;
# [     101] Step Taken, System time step t= 3.12500e-02, dt= 6.25000e-03
# [     101] Step Taken, Model step t= 3.12500e-02, dt= 6.25000e-03 for model mom_p
# [     103] ==============================================================
# [     103] Solving over interval [ 2.50000e-02, 3.12500e-02]
# [     103] ==============================================================
# [     103] Model: rho_p
# [     103] StepControl base stepExact t_model= 0.03125 tOut= 0.03125 t_model_last= 0.025 dt_model= 0.00625 setting to 0.00625
# [     103] VBDF calculateElementCoefficients t= 0.03125 dt= 0.00625 alpha= 240.0
# [     103]    Newton it 0 norm(r) =  2.63907e-02  		 norm(r)/(rtol*norm(r0)+atol) = 1504.09 test=r
# [     103] VBDF calculateElementCoefficients t= 0.03125 dt= 0.00625 alpha= 240.0
# [     103]    Newton it 1 norm(r) =  1.51029e-15  		 norm(r)/(rtol*norm(r0)+atol) =  8.60764e-11
# [     103] Model: mom_p
# [     103] StepControl base stepExact t_model= 0.03125 tOut= 0.03125 t_model_last= 0.025 dt_model= 0.00625 setting to 0.00625
# [     103]    Newton it 0 norm(r) =  6.37904e-03  		 norm(r)/(rtol*norm(r0)+atol) = 363.562 test=r
# [     105]    Newton it 1 norm(r) =  8.88178e-06  		 norm(r)/(rtol*norm(r0)+atol) =  5.06201e-01
# [     105] Max local divergence (dgp1 enriched all elements) =  5.14951e-17
# [     105] Global divergence = -1.03727e-16
# [     105] VBDF updateTimeHistory call 5 tLast=0.025 t=0.03125 dt= 0.00625 dt_history[0] = 0.00625
# [     105] VBDF updateTimeHistory call 5 tLast=0.025 t=0.03125 dt= 0.00625 dt_history[0] = 0.00625
# [     106]
# t= 0.03125; error_u_L2[0][0]= 0.00553157;
# [     106] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     106] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     107]
# t= 0.03125; error_u_L2[0][0]= 4.0378e-05;
# [     110]
# t= 0.03125; error_u_H1[0][0]= 0.000223366;
# [     111]
# t= 0.03125; error_velocity_L2[0][0]= 0;
# [     112]
# t= 0.03125; error_u_L2[1][0]= 4.52433e-05;
# [     115]
# t= 0.03125; error_u_H1[1][0]= 0.000275795;
# [     116]
# t= 0.03125; error_velocity_L2[1][0]= 0;
# [     117]
# t= 0.03125; error_u_L2[2][0]= 0.000674082;
# [     120]
# t= 0.03125; error_u_H1[2][0]= 0.0170478;
# [     123]
# t= 0.03125; error_velocity_L2[2][0]= 0.00280157;
# [     123] Step Taken, System time step t= 3.75000e-02, dt= 6.25000e-03
# [     123] Step Taken, Model step t= 3.75000e-02, dt= 6.25000e-03 for model mom_p
# [     125] ==============================================================
# [     125] Solving over interval [ 3.12500e-02, 3.75000e-02]
# [     125] ==============================================================
# [     125] Model: rho_p
# [     125] StepControl base stepExact t_model= 0.0375 tOut= 0.0375 t_model_last= 0.03125 dt_model= 0.00625 setting to 0.00625
# [     125] VBDF calculateElementCoefficients t= 0.0375 dt= 0.00625 alpha= 240.0
# [     125]    Newton it 0 norm(r) =  2.63869e-02  		 norm(r)/(rtol*norm(r0)+atol) = 1503.88 test=r
# [     125] VBDF calculateElementCoefficients t= 0.0375 dt= 0.00625 alpha= 240.0
# [     125]    Newton it 1 norm(r) =  1.51636e-15  		 norm(r)/(rtol*norm(r0)+atol) =  8.64224e-11
# [     125] Model: mom_p
# [     125] StepControl base stepExact t_model= 0.0375 tOut= 0.0375 t_model_last= 0.03125 dt_model= 0.00625 setting to 0.00625
# [     125]    Newton it 0 norm(r) =  7.79927e-03  		 norm(r)/(rtol*norm(r0)+atol) = 444.505 test=r
# [     127]    Newton it 1 norm(r) =  1.08449e-05  		 norm(r)/(rtol*norm(r0)+atol) =  6.18086e-01
# [     127] Max local divergence (dgp1 enriched all elements) =  5.37764e-17
# [     127] Global divergence = -7.57005e-17
# [     127] VBDF updateTimeHistory call 6 tLast=0.03125 t=0.0375 dt= 0.00625 dt_history[0] = 0.00625
# [     127] VBDF updateTimeHistory call 6 tLast=0.03125 t=0.0375 dt= 0.00625 dt_history[0] = 0.00625
# [     128]
# t= 0.0375; error_u_L2[0][0]= 0.00552964;
# [     128] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     128] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     129]
# t= 0.0375; error_u_L2[0][0]= 3.85532e-05;
# [     132]
# t= 0.0375; error_u_H1[0][0]= 0.000215234;
# [     133]
# t= 0.0375; error_velocity_L2[0][0]= 0;
# [     134]
# t= 0.0375; error_u_L2[1][0]= 4.4836e-05;
# [     137]
# t= 0.0375; error_u_H1[1][0]= 0.000275623;
# [     138]
# t= 0.0375; error_velocity_L2[1][0]= 0;
# [     139]
# t= 0.0375; error_u_L2[2][0]= 0.000744065;
# [     143]
# t= 0.0375; error_u_H1[2][0]= 0.0183587;
# [     145]
# t= 0.0375; error_velocity_L2[2][0]= 0.00280096;
# [     145] Step Taken, System time step t= 4.37500e-02, dt= 6.25000e-03
# [     145] Step Taken, Model step t= 4.37500e-02, dt= 6.25000e-03 for model mom_p
# [     147] ==============================================================
# [     147] Solving over interval [ 3.75000e-02, 4.37500e-02]
# [     147] ==============================================================
# [     147] Model: rho_p
# [     147] StepControl base stepExact t_model= 0.04375 tOut= 0.04375 t_model_last= 0.0375 dt_model= 0.00625 setting to 0.00625
# [     147] VBDF calculateElementCoefficients t= 0.04375 dt= 0.00625 alpha= 240.0
# [     147]    Newton it 0 norm(r) =  2.63822e-02  		 norm(r)/(rtol*norm(r0)+atol) = 1503.6 test=r
# [     147] VBDF calculateElementCoefficients t= 0.04375 dt= 0.00625 alpha= 240.0
# [     147]    Newton it 1 norm(r) =  1.53113e-15  		 norm(r)/(rtol*norm(r0)+atol) =  8.72641e-11
# [     147] Model: mom_p
# [     147] StepControl base stepExact t_model= 0.04375 tOut= 0.04375 t_model_last= 0.0375 dt_model= 0.00625 setting to 0.00625
# [     147]    Newton it 0 norm(r) =  9.21784e-03  		 norm(r)/(rtol*norm(r0)+atol) = 525.354 test=r
# [     150]    Newton it 1 norm(r) =  1.28433e-05  		 norm(r)/(rtol*norm(r0)+atol) =  7.31978e-01
# [     150] Max local divergence (dgp1 enriched all elements) =  5.20417e-17
# [     150] Global divergence =  9.61470e-17
# [     150] VBDF updateTimeHistory call 7 tLast=0.0375 t=0.04375 dt= 0.00625 dt_history[0] = 0.00625
# [     150] VBDF updateTimeHistory call 7 tLast=0.0375 t=0.04375 dt= 0.00625 dt_history[0] = 0.00625
# [     151]
# t= 0.04375; error_u_L2[0][0]= 0.00552749;
# [     151] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     151] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     151]
# t= 0.04375; error_u_L2[0][0]= 3.67346e-05;
# [     154]
# t= 0.04375; error_u_H1[0][0]= 0.000209397;
# [     155]
# t= 0.04375; error_velocity_L2[0][0]= 0;
# [     156]
# t= 0.04375; error_u_L2[1][0]= 4.43066e-05;
# [     159]
# t= 0.04375; error_u_H1[1][0]= 0.000275667;
# [     160]
# t= 0.04375; error_velocity_L2[1][0]= 0;
# [     161]
# t= 0.04375; error_u_L2[2][0]= 0.000800015;
# [     165]
# t= 0.04375; error_u_H1[2][0]= 0.0192994;
# [     168]
# t= 0.04375; error_velocity_L2[2][0]= 0.00280024;
# [     168] Step Taken, System time step t= 5.00000e-02, dt= 6.25000e-03
# [     168] Step Taken, Model step t= 5.00000e-02, dt= 6.25000e-03 for model mom_p
# [     169] ==============================================================
# [     169] Solving over interval [ 4.37500e-02, 5.00000e-02]
# [     169] ==============================================================
# [     169] Model: rho_p
# [     169] StepControl base stepExact t_model= 0.05 tOut= 0.05 t_model_last= 0.04375 dt_model= 0.00625 setting to 0.00625
# [     169] VBDF calculateElementCoefficients t= 0.05 dt= 0.00625 alpha= 240.0
# [     169]    Newton it 0 norm(r) =  2.63764e-02  		 norm(r)/(rtol*norm(r0)+atol) = 1503.28 test=r
# [     170] VBDF calculateElementCoefficients t= 0.05 dt= 0.00625 alpha= 240.0
# [     170]    Newton it 1 norm(r) =  1.52754e-15  		 norm(r)/(rtol*norm(r0)+atol) =  8.70592e-11
# [     170] Model: mom_p
# [     170] StepControl base stepExact t_model= 0.05 tOut= 0.05 t_model_last= 0.04375 dt_model= 0.00625 setting to 0.00625
# [     170]    Newton it 0 norm(r) =  1.06360e-02  		 norm(r)/(rtol*norm(r0)+atol) = 606.181 test=r
# [     172]    Newton it 1 norm(r) =  1.48477e-05  		 norm(r)/(rtol*norm(r0)+atol) =  8.46218e-01
# [     172] Max local divergence (dgp1 enriched all elements) =  6.76542e-17
# [     172] Global divergence =  5.07163e-17
# [     172] VBDF updateTimeHistory call 8 tLast=0.04375 t=0.05 dt= 0.00625 dt_history[0] = 0.00625
# [     172] VBDF updateTimeHistory call 8 tLast=0.04375 t=0.05 dt= 0.00625 dt_history[0] = 0.00625
# [     173]
# t= 0.05; error_u_L2[0][0]= 0.00552513;
# [     173] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     173] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     174]
# t= 0.05; error_u_L2[0][0]= 3.50904e-05;
# [     176]
# t= 0.05; error_u_H1[0][0]= 0.000205289;
# [     178]
# t= 0.05; error_velocity_L2[0][0]= 0;
# [     178]
# t= 0.05; error_u_L2[1][0]= 4.38093e-05;
# [     181]
# t= 0.05; error_u_H1[1][0]= 0.000275796;
# [     183]
# t= 0.05; error_velocity_L2[1][0]= 0;
# [     183]
# t= 0.05; error_u_L2[2][0]= 0.000845212;
# [     187]
# t= 0.05; error_u_H1[2][0]= 0.0199816;
# [     190]
# t= 0.05; error_velocity_L2[2][0]= 0.0027994;
# [     190] Step Taken, System time step t= 5.62500e-02, dt= 6.25000e-03
# [     190] Step Taken, Model step t= 5.62500e-02, dt= 6.25000e-03 for model mom_p
# [     191] ==============================================================
# [     191] Solving over interval [ 5.00000e-02, 5.62500e-02]
# [     191] ==============================================================
# [     191] Model: rho_p
# [     191] StepControl base stepExact t_model= 0.05625 tOut= 0.05625 t_model_last= 0.05 dt_model= 0.00625 setting to 0.00625
# [     191] VBDF calculateElementCoefficients t= 0.05625 dt= 0.00625 alpha= 240.0
# [     191]    Newton it 0 norm(r) =  2.63697e-02  		 norm(r)/(rtol*norm(r0)+atol) = 1502.89 test=r
# [     192] VBDF calculateElementCoefficients t= 0.05625 dt= 0.00625 alpha= 240.0
# [     192]    Newton it 1 norm(r) =  1.52095e-15  		 norm(r)/(rtol*norm(r0)+atol) =  8.66839e-11
# [     192] Model: mom_p
# [     192] StepControl base stepExact t_model= 0.05625 tOut= 0.05625 t_model_last= 0.05 dt_model= 0.00625 setting to 0.00625
# [     192]    Newton it 0 norm(r) =  1.20537e-02  		 norm(r)/(rtol*norm(r0)+atol) = 686.981 test=r
# [     194]    Newton it 1 norm(r) =  1.68500e-05  		 norm(r)/(rtol*norm(r0)+atol) =  9.60336e-01
# [     194] Max local divergence (dgp1 enriched all elements) =  5.72459e-17
# [     194] Global divergence = -1.48366e-16
# [     194] VBDF updateTimeHistory call 9 tLast=0.05 t=0.05625 dt= 0.00625 dt_history[0] = 0.00625
# [     194] VBDF updateTimeHistory call 9 tLast=0.05 t=0.05625 dt= 0.00625 dt_history[0] = 0.00625
# [     195]
# t= 0.05625; error_u_L2[0][0]= 0.00552254;
# [     195] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     195] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     196]
# t= 0.05625; error_u_L2[0][0]= 3.36398e-05;
# [     198]
# t= 0.05625; error_u_H1[0][0]= 0.000202353;
# [     200]
# t= 0.05625; error_velocity_L2[0][0]= 0;
# [     200]
# t= 0.05625; error_u_L2[1][0]= 4.33762e-05;
# [     203]
# t= 0.05625; error_u_H1[1][0]= 0.0002759;
# [     205]
# t= 0.05625; error_velocity_L2[1][0]= 0;
# [     205]
# t= 0.05625; error_u_L2[2][0]= 0.000882846;
# [     209]
# t= 0.05625; error_u_H1[2][0]= 0.020484;
# [     212]
# t= 0.05625; error_velocity_L2[2][0]= 0.00279846;
# [     212] Step Taken, System time step t= 6.25000e-02, dt= 6.25000e-03
# [     212] Step Taken, Model step t= 6.25000e-02, dt= 6.25000e-03 for model mom_p
# [     213] ==============================================================
# [     213] Solving over interval [ 5.62500e-02, 6.25000e-02]
# [     213] ==============================================================
# [     213] Model: rho_p
# [     213] StepControl base stepExact t_model= 0.0625 tOut= 0.0625 t_model_last= 0.05625 dt_model= 0.00625 setting to 0.00625
# [     213] VBDF calculateElementCoefficients t= 0.0625 dt= 0.00625 alpha= 240.0
# [     213]    Newton it 0 norm(r) =  2.63619e-02  		 norm(r)/(rtol*norm(r0)+atol) = 1502.45 test=r
# [     214] VBDF calculateElementCoefficients t= 0.0625 dt= 0.00625 alpha= 240.0
# [     214]    Newton it 1 norm(r) =  1.51785e-15  		 norm(r)/(rtol*norm(r0)+atol) =  8.65072e-11
# [     214] Model: mom_p
# [     214] StepControl base stepExact t_model= 0.0625 tOut= 0.0625 t_model_last= 0.05625 dt_model= 0.00625 setting to 0.00625
# [     214]    Newton it 0 norm(r) =  1.34709e-02  		 norm(r)/(rtol*norm(r0)+atol) = 767.751 test=r
# [     216]    Newton it 1 norm(r) =  1.88481e-05  		 norm(r)/(rtol*norm(r0)+atol) = 1.07421 test=r
# [     218]    Newton it 2 norm(r) =  1.23028e-08  		 norm(r)/(rtol*norm(r0)+atol) =  7.01178e-04
# [     218] Max local divergence (dgp1 enriched all elements) =  6.11490e-17
# [     218] Global divergence = -1.40264e-16
# [     218] VBDF updateTimeHistory call 10 tLast=0.05625 t=0.0625 dt= 0.00625 dt_history[0] = 0.00625
# [     218] VBDF updateTimeHistory call 10 tLast=0.05625 t=0.0625 dt= 0.00625 dt_history[0] = 0.00625
# [     219]
# t= 0.0625; error_u_L2[0][0]= 0.00551974;
# [     219] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     219] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     220]
# t= 0.0625; error_u_L2[0][0]= 3.23499e-05;
# [     223]
# t= 0.0625; error_u_H1[0][0]= 0.00020003;
# [     224]
# t= 0.0625; error_velocity_L2[0][0]= 0;
# [     225]
# t= 0.0625; error_u_L2[1][0]= 4.30189e-05;
# [     228]
# t= 0.0625; error_u_H1[1][0]= 0.000276028;
# [     229]
# t= 0.0625; error_velocity_L2[1][0]= 0;
# [     230]
# t= 0.0625; error_u_L2[2][0]= 0.000865706;
# [     233]
# t= 0.0625; error_u_H1[2][0]= 0.0208429;
# [     236]
# t= 0.0625; error_velocity_L2[2][0]= 0.0027974;
# [     236] Step Taken, System time step t= 6.87500e-02, dt= 6.25000e-03
# [     236] Step Taken, Model step t= 6.87500e-02, dt= 6.25000e-03 for model mom_p
# [     238] ==============================================================
# [     238] Solving over interval [ 6.25000e-02, 6.87500e-02]
# [     238] ==============================================================
# [     238] Model: rho_p
# [     238] StepControl base stepExact t_model= 0.06875 tOut= 0.06875 t_model_last= 0.0625 dt_model= 0.00625 setting to 0.00625
# [     238] VBDF calculateElementCoefficients t= 0.06875 dt= 0.00625 alpha= 240.0
# [     238]    Newton it 0 norm(r) =  2.63531e-02  		 norm(r)/(rtol*norm(r0)+atol) = 1501.95 test=r
# [     238] VBDF calculateElementCoefficients t= 0.06875 dt= 0.00625 alpha= 240.0
# [     238]    Newton it 1 norm(r) =  1.51599e-15  		 norm(r)/(rtol*norm(r0)+atol) =  8.64012e-11
# [     238] Model: mom_p
# [     238] StepControl base stepExact t_model= 0.06875 tOut= 0.06875 t_model_last= 0.0625 dt_model= 0.00625 setting to 0.00625
# [     238]    Newton it 0 norm(r) =  1.48875e-02  		 norm(r)/(rtol*norm(r0)+atol) = 848.488 test=r
# [     240]    Newton it 1 norm(r) =  2.08415e-05  		 norm(r)/(rtol*norm(r0)+atol) = 1.18782 test=r
# [     242]    Newton it 2 norm(r) =  1.35759e-08  		 norm(r)/(rtol*norm(r0)+atol) =  7.73734e-04
# [     242] Max local divergence (dgp1 enriched all elements) =  5.03070e-17
# [     242] Global divergence =  5.43137e-17
# [     242] VBDF updateTimeHistory call 11 tLast=0.0625 t=0.06875 dt= 0.00625 dt_history[0] = 0.00625
# [     242] VBDF updateTimeHistory call 11 tLast=0.0625 t=0.06875 dt= 0.00625 dt_history[0] = 0.00625
# [     244]
# t= 0.06875; error_u_L2[0][0]= 0.00551672;
# [     244] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     244] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     244]
# t= 0.06875; error_u_L2[0][0]= 3.12016e-05;
# [     247]
# t= 0.06875; error_u_H1[0][0]= 0.000198181;
# [     248]
# t= 0.06875; error_velocity_L2[0][0]= 0;
# [     249]
# t= 0.06875; error_u_L2[1][0]= 4.27243e-05;
# [     252]
# t= 0.06875; error_u_H1[1][0]= 0.000276121;
# [     253]
# t= 0.06875; error_velocity_L2[1][0]= 0;
# [     254]
# t= 0.06875; error_u_L2[2][0]= 0.000880281;
# [     258]
# t= 0.06875; error_u_H1[2][0]= 0.0211201;
# [     261]
# t= 0.06875; error_velocity_L2[2][0]= 0.00279625;
# [     261] Step Taken, System time step t= 7.50000e-02, dt= 6.25000e-03
# [     261] Step Taken, Model step t= 7.50000e-02, dt= 6.25000e-03 for model mom_p
# [     262] ==============================================================
# [     262] Solving over interval [ 6.87500e-02, 7.50000e-02]
# [     262] ==============================================================
# [     262] Model: rho_p
# [     262] StepControl base stepExact t_model= 0.075 tOut= 0.075 t_model_last= 0.06875 dt_model= 0.00625 setting to 0.00625
# [     262] VBDF calculateElementCoefficients t= 0.075 dt= 0.00625 alpha= 240.0
# [     262]    Newton it 0 norm(r) =  2.63433e-02  		 norm(r)/(rtol*norm(r0)+atol) = 1501.39 test=r
# [     263] VBDF calculateElementCoefficients t= 0.075 dt= 0.00625 alpha= 240.0
# [     263]    Newton it 1 norm(r) =  1.50216e-15  		 norm(r)/(rtol*norm(r0)+atol) =  8.56129e-11
# [     263] Model: mom_p
# [     263] StepControl base stepExact t_model= 0.075 tOut= 0.075 t_model_last= 0.06875 dt_model= 0.00625 setting to 0.00625
# [     263]    Newton it 0 norm(r) =  1.63035e-02  		 norm(r)/(rtol*norm(r0)+atol) = 929.188 test=r
# [     265]    Newton it 1 norm(r) =  2.28301e-05  		 norm(r)/(rtol*norm(r0)+atol) = 1.30116 test=r
# [     267]    Newton it 2 norm(r) =  1.48483e-08  		 norm(r)/(rtol*norm(r0)+atol) =  8.46250e-04
# [     267] Max local divergence (dgp1 enriched all elements) =  6.07153e-17
# [     267] Global divergence = -1.08960e-18
# [     267] VBDF updateTimeHistory call 12 tLast=0.06875 t=0.075 dt= 0.00625 dt_history[0] = 0.00625
# [     267] VBDF updateTimeHistory call 12 tLast=0.06875 t=0.075 dt= 0.00625 dt_history[0] = 0.00625
# [     268]
# t= 0.075; error_u_L2[0][0]= 0.00551349;
# [     268] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     268] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     269]
# t= 0.075; error_u_L2[0][0]= 3.01762e-05;
# [     272]
# t= 0.075; error_u_H1[0][0]= 0.000196704;
# [     273]
# t= 0.075; error_velocity_L2[0][0]= 0;
# [     274]
# t= 0.075; error_u_L2[1][0]= 4.2482e-05;
# [     277]
# t= 0.075; error_u_H1[1][0]= 0.00027617;
# [     278]
# t= 0.075; error_velocity_L2[1][0]= 0;
# [     279]
# t= 0.075; error_u_L2[2][0]= 0.000891288;
# [     282]
# t= 0.075; error_u_H1[2][0]= 0.0213305;
# [     285]
# t= 0.075; error_velocity_L2[2][0]= 0.00279498;
# [     285] Step Taken, System time step t= 8.12500e-02, dt= 6.25000e-03
# [     285] Step Taken, Model step t= 8.12500e-02, dt= 6.25000e-03 for model mom_p
# [     287] ==============================================================
# [     287] Solving over interval [ 7.50000e-02, 8.12500e-02]
# [     287] ==============================================================
# [     287] Model: rho_p
# [     287] StepControl base stepExact t_model= 0.08125 tOut= 0.08125 t_model_last= 0.075 dt_model= 0.00625 setting to 0.00625
# [     287] VBDF calculateElementCoefficients t= 0.08125 dt= 0.00625 alpha= 240.0
# [     287]    Newton it 0 norm(r) =  2.63325e-02  		 norm(r)/(rtol*norm(r0)+atol) = 1500.77 test=r
# [     287] VBDF calculateElementCoefficients t= 0.08125 dt= 0.00625 alpha= 240.0
# [     287]    Newton it 1 norm(r) =  1.53279e-15  		 norm(r)/(rtol*norm(r0)+atol) =  8.73586e-11
# [     287] Model: mom_p
# [     287] StepControl base stepExact t_model= 0.08125 tOut= 0.08125 t_model_last= 0.075 dt_model= 0.00625 setting to 0.00625
# [     287]    Newton it 0 norm(r) =  1.77188e-02  		 norm(r)/(rtol*norm(r0)+atol) = 1009.85 test=r
# [     289]    Newton it 1 norm(r) =  2.48139e-05  		 norm(r)/(rtol*norm(r0)+atol) = 1.41422 test=r
# [     291]    Newton it 2 norm(r) =  1.61186e-08  		 norm(r)/(rtol*norm(r0)+atol) =  9.18651e-04
# [     291] Max local divergence (dgp1 enriched all elements) =  6.11626e-17
# [     291] Global divergence = -9.05304e-17
# [     291] VBDF updateTimeHistory call 13 tLast=0.075 t=0.08125 dt= 0.00625 dt_history[0] = 0.00625
# [     291] VBDF updateTimeHistory call 13 tLast=0.075 t=0.08125 dt= 0.00625 dt_history[0] = 0.00625
# [     292]
# t= 0.08125; error_u_L2[0][0]= 0.00551003;
# [     292] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     292] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     293]
# t= 0.08125; error_u_L2[0][0]= 2.92574e-05;
# [     296]
# t= 0.08125; error_u_H1[0][0]= 0.000195522;
# [     297]
# t= 0.08125; error_velocity_L2[0][0]= 0;
# [     298]
# t= 0.08125; error_u_L2[1][0]= 4.22843e-05;
# [     301]
# t= 0.08125; error_u_H1[1][0]= 0.000276185;
# [     302]
# t= 0.08125; error_velocity_L2[1][0]= 0;
# [     303]
# t= 0.08125; error_u_L2[2][0]= 0.00089966;
# [     307]
# t= 0.08125; error_u_H1[2][0]= 0.0214922;
# [     309]
# t= 0.08125; error_velocity_L2[2][0]= 0.0027936;
# [     309] Step Taken, System time step t= 8.75000e-02, dt= 6.25000e-03
# [     309] Step Taken, Model step t= 8.75000e-02, dt= 6.25000e-03 for model mom_p
# [     311] ==============================================================
# [     311] Solving over interval [ 8.12500e-02, 8.75000e-02]
# [     311] ==============================================================
# [     311] Model: rho_p
# [     311] StepControl base stepExact t_model= 0.0875 tOut= 0.0875 t_model_last= 0.08125 dt_model= 0.00625 setting to 0.00625
# [     311] VBDF calculateElementCoefficients t= 0.0875 dt= 0.00625 alpha= 240.0
# [     311]    Newton it 0 norm(r) =  2.63206e-02  		 norm(r)/(rtol*norm(r0)+atol) = 1500.09 test=r
# [     311] VBDF calculateElementCoefficients t= 0.0875 dt= 0.00625 alpha= 240.0
# [     311]    Newton it 1 norm(r) =  1.51147e-15  		 norm(r)/(rtol*norm(r0)+atol) =  8.61434e-11
# [     311] Model: mom_p
# [     311] StepControl base stepExact t_model= 0.0875 tOut= 0.0875 t_model_last= 0.08125 dt_model= 0.00625 setting to 0.00625
# [     311]    Newton it 0 norm(r) =  1.91333e-02  		 norm(r)/(rtol*norm(r0)+atol) = 1090.47 test=r
# [     313]    Newton it 1 norm(r) =  2.67927e-05  		 norm(r)/(rtol*norm(r0)+atol) = 1.527 test=r
# [     315]    Newton it 2 norm(r) =  1.73859e-08  		 norm(r)/(rtol*norm(r0)+atol) =  9.90876e-04
# [     315] Max local divergence (dgp1 enriched all elements) =  5.20417e-17
# [     315] Global divergence =  4.96809e-17
# [     315] VBDF updateTimeHistory call 14 tLast=0.08125 t=0.0875 dt= 0.00625 dt_history[0] = 0.00625
# [     315] VBDF updateTimeHistory call 14 tLast=0.08125 t=0.0875 dt= 0.00625 dt_history[0] = 0.00625
# [     317]
# t= 0.0875; error_u_L2[0][0]= 0.00550636;
# [     317] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     317] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     317]
# t= 0.0875; error_u_L2[0][0]= 2.8432e-05;
# [     320]
# t= 0.0875; error_u_H1[0][0]= 0.00019458;
# [     321]
# t= 0.0875; error_velocity_L2[0][0]= 0;
# [     322]
# t= 0.0875; error_u_L2[1][0]= 4.21246e-05;
# [     325]
# t= 0.0875; error_u_H1[1][0]= 0.000276176;
# [     326]
# t= 0.0875; error_velocity_L2[1][0]= 0;
# [     327]
# t= 0.0875; error_u_L2[2][0]= 0.000906064;
# [     331]
# t= 0.0875; error_u_H1[2][0]= 0.0216177;
# [     334]
# t= 0.0875; error_velocity_L2[2][0]= 0.00279212;
# [     334] Step Taken, System time step t= 9.37500e-02, dt= 6.25000e-03
# [     334] Step Taken, Model step t= 9.37500e-02, dt= 6.25000e-03 for model mom_p
# [     335] ==============================================================
# [     335] Solving over interval [ 8.75000e-02, 9.37500e-02]
# [     335] ==============================================================
# [     335] Model: rho_p
# [     335] StepControl base stepExact t_model= 0.09375 tOut= 0.09375 t_model_last= 0.0875 dt_model= 0.00625 setting to 0.00625
# [     335] VBDF calculateElementCoefficients t= 0.09375 dt= 0.00625 alpha= 240.0
# [     335]    Newton it 0 norm(r) =  2.63076e-02  		 norm(r)/(rtol*norm(r0)+atol) = 1499.35 test=r
# [     336] VBDF calculateElementCoefficients t= 0.09375 dt= 0.00625 alpha= 240.0
# [     336]    Newton it 1 norm(r) =  1.56259e-15  		 norm(r)/(rtol*norm(r0)+atol) =  8.90569e-11
# [     336] Model: mom_p
# [     336] StepControl base stepExact t_model= 0.09375 tOut= 0.09375 t_model_last= 0.0875 dt_model= 0.00625 setting to 0.00625
# [     336]    Newton it 0 norm(r) =  2.05471e-02  		 norm(r)/(rtol*norm(r0)+atol) = 1171.04 test=r
# [     338]    Newton it 1 norm(r) =  2.87666e-05  		 norm(r)/(rtol*norm(r0)+atol) = 1.6395 test=r
# [     340]    Newton it 2 norm(r) =  1.86492e-08  		 norm(r)/(rtol*norm(r0)+atol) =  1.06288e-03
# [     340] Max local divergence (dgp1 enriched all elements) =  5.20417e-17
# [     340] Global divergence =  2.65070e-17
# [     340] VBDF updateTimeHistory call 15 tLast=0.0875 t=0.09375 dt= 0.00625 dt_history[0] = 0.00625
# [     340] VBDF updateTimeHistory call 15 tLast=0.0875 t=0.09375 dt= 0.00625 dt_history[0] = 0.00625
# [     341]
# t= 0.09375; error_u_L2[0][0]= 0.00550248;
# [     341] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     341] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     342]
# t= 0.09375; error_u_L2[0][0]= 2.76895e-05;
# [     345]
# t= 0.09375; error_u_H1[0][0]= 0.000193837;
# [     346]
# t= 0.09375; error_velocity_L2[0][0]= 0;
# [     347]
# t= 0.09375; error_u_L2[1][0]= 4.19974e-05;
# [     350]
# t= 0.09375; error_u_H1[1][0]= 0.00027615;
# [     351]
# t= 0.09375; error_velocity_L2[1][0]= 0;
# [     352]
# t= 0.09375; error_u_L2[2][0]= 0.00091098;
# [     356]
# t= 0.09375; error_u_H1[2][0]= 0.0217159;
# [     358]
# t= 0.09375; error_velocity_L2[2][0]= 0.00279053;
# [     358] Step Taken, System time step t= 1.00000e-01, dt= 6.25000e-03
# [     358] Step Taken, Model step t= 1.00000e-01, dt= 6.25000e-03 for model mom_p
# [     360] ==============================================================
# [     360] Solving over interval [ 9.37500e-02, 1.00000e-01]
# [     360] ==============================================================
# [     360] Model: rho_p
# [     360] StepControl base stepExact t_model= 0.1 tOut= 0.1 t_model_last= 0.09375 dt_model= 0.00625 setting to 0.00625
# [     360] VBDF calculateElementCoefficients t= 0.1 dt= 0.00625 alpha= 240.0
# [     360]    Newton it 0 norm(r) =  2.62936e-02  		 norm(r)/(rtol*norm(r0)+atol) = 1498.56 test=r
# [     360] VBDF calculateElementCoefficients t= 0.1 dt= 0.00625 alpha= 240.0
# [     360]    Newton it 1 norm(r) =  1.49388e-15  		 norm(r)/(rtol*norm(r0)+atol) =  8.51411e-11
# [     360] Model: mom_p
# [     360] StepControl base stepExact t_model= 0.1 tOut= 0.1 t_model_last= 0.09375 dt_model= 0.00625 setting to 0.00625
# [     360]    Newton it 0 norm(r) =  2.19600e-02  		 norm(r)/(rtol*norm(r0)+atol) = 1251.57 test=r
# [     362]    Newton it 1 norm(r) =  3.07352e-05  		 norm(r)/(rtol*norm(r0)+atol) = 1.7517 test=r
# [     365]    Newton it 2 norm(r) =  1.99080e-08  		 norm(r)/(rtol*norm(r0)+atol) =  1.13462e-03
# [     365] Max local divergence (dgp1 enriched all elements) =  5.72459e-17
# [     365] Global divergence =  3.82070e-17
# [     365] VBDF updateTimeHistory call 16 tLast=0.09375 t=0.1 dt= 0.00625 dt_history[0] = 0.00625
# [     365] VBDF updateTimeHistory call 16 tLast=0.09375 t=0.1 dt= 0.00625 dt_history[0] = 0.00625
# [     366]
# t= 0.1; error_u_L2[0][0]= 0.00549838;
# [     366] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     366] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [     366]
# t= 0.1; error_u_L2[0][0]= 2.70212e-05;
# [     369]
# t= 0.1; error_u_H1[0][0]= 0.000193263;
# [     371]
# t= 0.1; error_velocity_L2[0][0]= 0;
# [     371]
# t= 0.1; error_u_L2[1][0]= 4.18978e-05;
# [     374]
# t= 0.1; error_u_H1[1][0]= 0.000276113;
# [     375]
# t= 0.1; error_velocity_L2[1][0]= 0;
# [     376]
# t= 0.1; error_u_L2[2][0]= 0.000914759;
# [     380]
# t= 0.1; error_u_H1[2][0]= 0.0217933;
# [     383]
# t= 0.1; error_velocity_L2[2][0]= 0.00278883;
# [     383] Step Taken, System time step t= 1.06250e-01, dt= 6.25000e-03
# [     383] Step Taken, Model step t= 1.06250e-01, dt= 6.25000e-03 for model mom_p
# [     385] ==============================================================
# [     385] Solving over interval [ 1.00000e-01, 1.06250e-01]
# [     385] ==============================================================
# [     385] Model: rho_p
# [     385] StepControl base stepExact t_model= 0.10625 tOut= 0.10625 t_model_last= 0.1 dt_model= 0.00625 setting to 0.00625
# [     385] VBDF calculateElementCoefficients t= 0.10625 dt= 0.00625 alpha= 240.0
# [     385]    Newton it 0 norm(r) =  2.62786e-02  		 norm(r)/(rtol*norm(r0)+atol) = 1497.7 test=r
# [     385] VBDF calculateElementCoefficients t= 0.10625 dt= 0.00625 alpha= 240.0
# [     385]    Newton it 1 norm(r) =  1.53098e-15  		 norm(r)/(rtol*norm(r0)+atol) =  8.72556e-11
# [     385] Model: mom_p
# [     385] StepControl base stepExact t_model= 0.10625 tOut= 0.10625 t_model_last= 0.1 dt_model= 0.00625 setting to 0.00625
# [     385]    Newton it 0 norm(r) =  2.33721e-02  		 norm(r)/(rtol*norm(r0)+atol) = 1332.05 test=r
# ...
# [    7433] ==============================================================
# [    7433] Solving over interval [ 1.75625e+00, 1.76250e+00]
# [    7433] ==============================================================
# [    7433] Model: rho_p
# [    7433] StepControl base stepExact t_model= 1.7625 tOut= 1.7625 t_model_last= 1.75625 dt_model= 0.00625 setting to 0.00625
# [    7433] VBDF calculateElementCoefficients t= 1.7625 dt= 0.00625 alpha= 240.0
# [    7433]    Newton it 0 norm(r) =  4.78912e-03  		 norm(r)/(rtol*norm(r0)+atol) = 272.947 test=r
# [    7433] VBDF calculateElementCoefficients t= 1.7625 dt= 0.00625 alpha= 240.0
# [    7433]    Newton it 1 norm(r) =  1.10543e-15  		 norm(r)/(rtol*norm(r0)+atol) =  6.30018e-11
# [    7433] Model: mom_p
# [    7433] StepControl base stepExact t_model= 1.7625 tOut= 1.7625 t_model_last= 1.75625 dt_model= 0.00625 setting to 0.00625
# [    7433]    Newton it 0 norm(r) =  2.22956e-01  		 norm(r)/(rtol*norm(r0)+atol) = 12706.9 test=r
# [    7436]    Newton it 1 norm(r) =  5.97354e-05  		 norm(r)/(rtol*norm(r0)+atol) = 3.40451 test=r
# [    7438]    Newton it 2 norm(r) =  7.40180e-09  		 norm(r)/(rtol*norm(r0)+atol) =  4.21852e-04
# [    7438] Max local divergence (dgp1 enriched all elements) =  9.97466e-18
# [    7438] Global divergence =  9.86137e-18
# [    7438] VBDF updateTimeHistory call 282 tLast=1.75625 t=1.7625 dt= 0.00625 dt_history[0] = 0.00625
# [    7438] VBDF updateTimeHistory call 282 tLast=1.75625 t=1.7625 dt= 0.00625 dt_history[0] = 0.00625
# [    7439]
# t= 1.7625; error_u_L2[0][0]= 0.00145728;
# [    7439] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [    7439] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [    7440]
# t= 1.7625; error_u_L2[0][0]= 6.03375e-06;
# [    7442]
# t= 1.7625; error_u_H1[0][0]= 6.03444e-05;
# [    7444]
# t= 1.7625; error_velocity_L2[0][0]= 0;
# [    7444]
# t= 1.7625; error_u_L2[1][0]= 7.74805e-06;
# [    7447]
# t= 1.7625; error_u_H1[1][0]= 6.86964e-05;
# [    7449]
# t= 1.7625; error_velocity_L2[1][0]= 0;
# [    7449]
# t= 1.7625; error_u_L2[2][0]= 0.000210053;
# [    7453]
# t= 1.7625; error_u_H1[2][0]= 0.0228382;
# [    7456]
# t= 1.7625; error_velocity_L2[2][0]= 0.000534041;
# [    7456] Step Taken, System time step t= 1.76875e+00, dt= 6.25000e-03
# [    7456] Step Taken, Model step t= 1.76875e+00, dt= 6.25000e-03 for model mom_p
# [    7459] ==============================================================
# [    7459] Solving over interval [ 1.76250e+00, 1.76875e+00]
# [    7459] ==============================================================
# [    7459] Model: rho_p
# [    7459] StepControl base stepExact t_model= 1.76875 tOut= 1.76875 t_model_last= 1.7625 dt_model= 0.00625 setting to 0.00625
# [    7459] VBDF calculateElementCoefficients t= 1.76875 dt= 0.00625 alpha= 240.0
# [    7459]    Newton it 0 norm(r) =  4.95138e-03  		 norm(r)/(rtol*norm(r0)+atol) = 282.195 test=r
# [    7459] VBDF calculateElementCoefficients t= 1.76875 dt= 0.00625 alpha= 240.0
# [    7459]    Newton it 1 norm(r) =  1.10060e-15  		 norm(r)/(rtol*norm(r0)+atol) =  6.27269e-11
# [    7459] Model: mom_p
# [    7459] StepControl base stepExact t_model= 1.76875 tOut= 1.76875 t_model_last= 1.7625 dt_model= 0.00625 setting to 0.00625
# [    7459]    Newton it 0 norm(r) =  2.22685e-01  		 norm(r)/(rtol*norm(r0)+atol) = 12691.5 test=r
# [    7461]    Newton it 1 norm(r) =  6.15833e-05  		 norm(r)/(rtol*norm(r0)+atol) = 3.50983 test=r
# [    7463]    Newton it 2 norm(r) =  7.87633e-09  		 norm(r)/(rtol*norm(r0)+atol) =  4.48897e-04
# [    7463] Max local divergence (dgp1 enriched all elements) =  1.17094e-17
# [    7463] Global divergence = -3.76799e-17
# [    7463] VBDF updateTimeHistory call 283 tLast=1.7625 t=1.76875 dt= 0.00625 dt_history[0] = 0.00625
# [    7463] VBDF updateTimeHistory call 283 tLast=1.7625 t=1.76875 dt= 0.00625 dt_history[0] = 0.00625
# [    7464]
# t= 1.76875; error_u_L2[0][0]= 0.0014844;
# [    7464] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [    7464] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [    7465]
# t= 1.76875; error_u_L2[0][0]= 6.36184e-06;
# [    7468]
# t= 1.76875; error_u_H1[0][0]= 6.16169e-05;
# [    7469]
# t= 1.76875; error_velocity_L2[0][0]= 0;
# [    7470]
# t= 1.76875; error_u_L2[1][0]= 8.13692e-06;
# [    7473]
# t= 1.76875; error_u_H1[1][0]= 7.04243e-05;
# [    7474]
# t= 1.76875; error_velocity_L2[1][0]= 0;
# [    7475]
# t= 1.76875; error_u_L2[2][0]= 0.000214378;
# [    7479]
# t= 1.76875; error_u_H1[2][0]= 0.0228159;
# [    7481]
# t= 1.76875; error_velocity_L2[2][0]= 0.000551231;
# [    7481] Step Taken, System time step t= 1.77500e+00, dt= 6.25000e-03
# [    7481] Step Taken, Model step t= 1.77500e+00, dt= 6.25000e-03 for model mom_p
# [    7484] ==============================================================
# [    7484] Solving over interval [ 1.76875e+00, 1.77500e+00]
# [    7484] ==============================================================
# [    7484] Model: rho_p
# [    7484] StepControl base stepExact t_model= 1.775 tOut= 1.775 t_model_last= 1.76875 dt_model= 0.00625 setting to 0.00625
# [    7484] VBDF calculateElementCoefficients t= 1.775 dt= 0.00625 alpha= 240.0
# [    7484]    Newton it 0 norm(r) =  5.11345e-03  		 norm(r)/(rtol*norm(r0)+atol) = 291.431 test=r
# [    7484] VBDF calculateElementCoefficients t= 1.775 dt= 0.00625 alpha= 240.0
# [    7484]    Newton it 1 norm(r) =  1.09593e-15  		 norm(r)/(rtol*norm(r0)+atol) =  6.24608e-11
# [    7484] Model: mom_p
# [    7484] StepControl base stepExact t_model= 1.775 tOut= 1.775 t_model_last= 1.76875 dt_model= 0.00625 setting to 0.00625
# [    7484]    Newton it 0 norm(r) =  2.22406e-01  		 norm(r)/(rtol*norm(r0)+atol) = 12675.6 test=r
# [    7486]    Newton it 1 norm(r) =  6.34218e-05  		 norm(r)/(rtol*norm(r0)+atol) = 3.61461 test=r
# [    7489]    Newton it 2 norm(r) =  8.36403e-09  		 norm(r)/(rtol*norm(r0)+atol) =  4.76693e-04
# [    7489] Max local divergence (dgp1 enriched all elements) =  1.12757e-17
# [    7489] Global divergence = -2.44914e-17
# [    7489] VBDF updateTimeHistory call 284 tLast=1.76875 t=1.775 dt= 0.00625 dt_history[0] = 0.00625
# [    7489] VBDF updateTimeHistory call 284 tLast=1.76875 t=1.775 dt= 0.00625 dt_history[0] = 0.00625
# [    7490]
# t= 1.775; error_u_L2[0][0]= 0.00151173;
# [    7490] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [    7490] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [    7490]
# t= 1.775; error_u_L2[0][0]= 6.6896e-06;
# [    7493]
# t= 1.775; error_u_H1[0][0]= 6.29238e-05;
# [    7495]
# t= 1.775; error_velocity_L2[0][0]= 0;
# [    7495]
# t= 1.775; error_u_L2[1][0]= 8.52528e-06;
# [    7498]
# t= 1.775; error_u_H1[1][0]= 7.21764e-05;
# [    7500]
# t= 1.775; error_velocity_L2[1][0]= 0;
# [    7500]
# t= 1.775; error_u_L2[2][0]= 0.000218721;
# [    7504]
# t= 1.775; error_u_H1[2][0]= 0.0227928;
# [    7507]
# t= 1.775; error_velocity_L2[2][0]= 0.0005684;
# [    7507] Step Taken, System time step t= 1.78125e+00, dt= 6.25000e-03
# [    7507] Step Taken, Model step t= 1.78125e+00, dt= 6.25000e-03 for model mom_p
# [    7510] ==============================================================
# [    7510] Solving over interval [ 1.77500e+00, 1.78125e+00]
# [    7510] ==============================================================
# [    7510] Model: rho_p
# [    7510] StepControl base stepExact t_model= 1.78125 tOut= 1.78125 t_model_last= 1.775 dt_model= 0.00625 setting to 0.00625
# [    7510] VBDF calculateElementCoefficients t= 1.78125 dt= 0.00625 alpha= 240.0
# [    7510]    Newton it 0 norm(r) =  5.27531e-03  		 norm(r)/(rtol*norm(r0)+atol) = 300.657 test=r
# [    7510] VBDF calculateElementCoefficients t= 1.78125 dt= 0.00625 alpha= 240.0
# [    7510]    Newton it 1 norm(r) =  1.11033e-15  		 norm(r)/(rtol*norm(r0)+atol) =  6.32813e-11
# [    7510] Model: mom_p
# [    7510] StepControl base stepExact t_model= 1.78125 tOut= 1.78125 t_model_last= 1.775 dt_model= 0.00625 setting to 0.00625
# [    7510]    Newton it 0 norm(r) =  2.22119e-01  		 norm(r)/(rtol*norm(r0)+atol) = 12659.3 test=r
# [    7512]    Newton it 1 norm(r) =  6.52504e-05  		 norm(r)/(rtol*norm(r0)+atol) = 3.71883 test=r
# [    7514]    Newton it 2 norm(r) =  8.86470e-09  		 norm(r)/(rtol*norm(r0)+atol) =  5.05227e-04
# [    7514] Max local divergence (dgp1 enriched all elements) =  1.10589e-17
# [    7514] Global divergence = -2.41722e-17
# [    7514] VBDF updateTimeHistory call 285 tLast=1.775 t=1.78125 dt= 0.00625 dt_history[0] = 0.00625
# [    7514] VBDF updateTimeHistory call 285 tLast=1.775 t=1.78125 dt= 0.00625 dt_history[0] = 0.00625
# [    7515]
# t= 1.78125; error_u_L2[0][0]= 0.00153925;
# [    7515] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [    7515] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [    7516]
# t= 1.78125; error_u_L2[0][0]= 7.01694e-06;
# [    7519]
# t= 1.78125; error_u_H1[0][0]= 6.42627e-05;
# [    7520]
# t= 1.78125; error_velocity_L2[0][0]= 0;
# [    7521]
# t= 1.78125; error_u_L2[1][0]= 8.9129e-06;
# [    7524]
# t= 1.78125; error_u_H1[1][0]= 7.39497e-05;
# [    7525]
# t= 1.78125; error_velocity_L2[1][0]= 0;
# [    7526]
# t= 1.78125; error_u_L2[2][0]= 0.000223079;
# [    7530]
# t= 1.78125; error_u_H1[2][0]= 0.022769;
# [    7532]
# t= 1.78125; error_velocity_L2[2][0]= 0.000585546;
# [    7532] Step Taken, System time step t= 1.78750e+00, dt= 6.25000e-03
# [    7532] Step Taken, Model step t= 1.78750e+00, dt= 6.25000e-03 for model mom_p
# [    7535] ==============================================================
# [    7535] Solving over interval [ 1.78125e+00, 1.78750e+00]
# [    7535] ==============================================================
# [    7535] Model: rho_p
# [    7535] StepControl base stepExact t_model= 1.7875 tOut= 1.7875 t_model_last= 1.78125 dt_model= 0.00625 setting to 0.00625
# [    7535] VBDF calculateElementCoefficients t= 1.7875 dt= 0.00625 alpha= 240.0
# [    7535]    Newton it 0 norm(r) =  5.43697e-03  		 norm(r)/(rtol*norm(r0)+atol) = 309.87 test=r
# [    7535] VBDF calculateElementCoefficients t= 1.7875 dt= 0.00625 alpha= 240.0
# [    7535]    Newton it 1 norm(r) =  1.10481e-15  		 norm(r)/(rtol*norm(r0)+atol) =  6.29668e-11
# [    7535] Model: mom_p
# [    7535] StepControl base stepExact t_model= 1.7875 tOut= 1.7875 t_model_last= 1.78125 dt_model= 0.00625 setting to 0.00625
# [    7535]    Newton it 0 norm(r) =  2.21823e-01  		 norm(r)/(rtol*norm(r0)+atol) = 12642.4 test=r
# [    7538]    Newton it 1 norm(r) =  6.70689e-05  		 norm(r)/(rtol*norm(r0)+atol) = 3.82247 test=r
# [    7540]    Newton it 2 norm(r) =  9.37814e-09  		 norm(r)/(rtol*norm(r0)+atol) =  5.34490e-04
# [    7540] Max local divergence (dgp1 enriched all elements) =  1.09504e-17
# [    7540] Global divergence = -1.60549e-17
# [    7540] VBDF updateTimeHistory call 286 tLast=1.78125 t=1.7875 dt= 0.00625 dt_history[0] = 0.00625
# [    7540] VBDF updateTimeHistory call 286 tLast=1.78125 t=1.7875 dt= 0.00625 dt_history[0] = 0.00625
# [    7541]
# t= 1.7875; error_u_L2[0][0]= 0.00156694;
# [    7541] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [    7541] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [    7542]
# t= 1.7875; error_u_L2[0][0]= 7.34377e-06;
# [    7544]
# t= 1.7875; error_u_H1[0][0]= 6.56314e-05;
# [    7546]
# t= 1.7875; error_velocity_L2[0][0]= 0;
# [    7546]
# t= 1.7875; error_u_L2[1][0]= 9.29958e-06;
# [    7549]
# t= 1.7875; error_u_H1[1][0]= 7.57408e-05;
# [    7551]
# t= 1.7875; error_velocity_L2[1][0]= 0;
# [    7551]
# t= 1.7875; error_u_L2[2][0]= 0.000227448;
# [    7555]
# t= 1.7875; error_u_H1[2][0]= 0.0227445;
# [    7558]
# t= 1.7875; error_velocity_L2[2][0]= 0.00060267;
# [    7558] Step Taken, System time step t= 1.79375e+00, dt= 6.25000e-03
# [    7558] Step Taken, Model step t= 1.79375e+00, dt= 6.25000e-03 for model mom_p
# [    7561] ==============================================================
# [    7561] Solving over interval [ 1.78750e+00, 1.79375e+00]
# [    7561] ==============================================================
# [    7561] Model: rho_p
# [    7561] StepControl base stepExact t_model= 1.79375 tOut= 1.79375 t_model_last= 1.7875 dt_model= 0.00625 setting to 0.00625
# [    7561] VBDF calculateElementCoefficients t= 1.79375 dt= 0.00625 alpha= 240.0
# [    7561]    Newton it 0 norm(r) =  5.59842e-03  		 norm(r)/(rtol*norm(r0)+atol) = 319.072 test=r
# [    7561] VBDF calculateElementCoefficients t= 1.79375 dt= 0.00625 alpha= 240.0
# [    7561]    Newton it 1 norm(r) =  1.08586e-15  		 norm(r)/(rtol*norm(r0)+atol) =  6.18866e-11
# [    7561] Model: mom_p
# [    7561] StepControl base stepExact t_model= 1.79375 tOut= 1.79375 t_model_last= 1.7875 dt_model= 0.00625 setting to 0.00625
# [    7561]    Newton it 0 norm(r) =  2.21518e-01  		 norm(r)/(rtol*norm(r0)+atol) = 12625 test=r
# [    7563]    Newton it 1 norm(r) =  6.88771e-05  		 norm(r)/(rtol*norm(r0)+atol) = 3.92552 test=r
# [    7565]    Newton it 2 norm(r) =  9.90416e-09  		 norm(r)/(rtol*norm(r0)+atol) =  5.64470e-04
# [    7565] Max local divergence (dgp1 enriched all elements) =  1.30104e-17
# [    7565] Global divergence = -6.47999e-18
# [    7565] VBDF updateTimeHistory call 287 tLast=1.7875 t=1.79375 dt= 0.00625 dt_history[0] = 0.00625
# [    7565] VBDF updateTimeHistory call 287 tLast=1.7875 t=1.79375 dt= 0.00625 dt_history[0] = 0.00625
# [    7566]
# t= 1.79375; error_u_L2[0][0]= 0.00159479;
# [    7566] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [    7566] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [    7567]
# t= 1.79375; error_u_L2[0][0]= 7.67001e-06;
# [    7570]
# t= 1.79375; error_u_H1[0][0]= 6.70278e-05;
# [    7571]
# t= 1.79375; error_velocity_L2[0][0]= 0;
# [    7572]
# t= 1.79375; error_u_L2[1][0]= 9.68517e-06;
# [    7575]
# t= 1.79375; error_u_H1[1][0]= 7.75472e-05;
# [    7576]
# t= 1.79375; error_velocity_L2[1][0]= 0;
# [    7577]
# t= 1.79375; error_u_L2[2][0]= 0.000231824;
# [    7581]
# t= 1.79375; error_u_H1[2][0]= 0.0227192;
# [    7583]
# t= 1.79375; error_velocity_L2[2][0]= 0.000619771;
# [    7583] Step Taken, System time step t= 1.80000e+00, dt= 6.25000e-03
# [    7583] Step Taken, Model step t= 1.80000e+00, dt= 6.25000e-03 for model mom_p
# [    7586] ==============================================================
# [    7586] Solving over interval [ 1.79375e+00, 1.80000e+00]
# [    7586] ==============================================================
# [    7586] Model: rho_p
# [    7586] StepControl base stepExact t_model= 1.8 tOut= 1.8 t_model_last= 1.79375 dt_model= 0.00625 setting to 0.00625
# [    7586] VBDF calculateElementCoefficients t= 1.8 dt= 0.00625 alpha= 240.0
# [    7586]    Newton it 0 norm(r) =  5.75966e-03  		 norm(r)/(rtol*norm(r0)+atol) = 328.261 test=r
# [    7586] VBDF calculateElementCoefficients t= 1.8 dt= 0.00625 alpha= 240.0
# [    7586]    Newton it 1 norm(r) =  1.11053e-15  		 norm(r)/(rtol*norm(r0)+atol) =  6.32927e-11
# [    7586] Model: mom_p
# [    7586] StepControl base stepExact t_model= 1.8 tOut= 1.8 t_model_last= 1.79375 dt_model= 0.00625 setting to 0.00625
# [    7586]    Newton it 0 norm(r) =  2.21204e-01  		 norm(r)/(rtol*norm(r0)+atol) = 12607.1 test=r
# [    7589]    Newton it 1 norm(r) =  7.06746e-05  		 norm(r)/(rtol*norm(r0)+atol) = 4.02797 test=r
# [    7591]    Newton it 2 norm(r) =  1.04426e-08  		 norm(r)/(rtol*norm(r0)+atol) =  5.95154e-04
# [    7591] Max local divergence (dgp1 enriched all elements) =  1.34441e-17
# [    7591] Global divergence =  1.28176e-18
# [    7591] VBDF updateTimeHistory call 288 tLast=1.79375 t=1.8 dt= 0.00625 dt_history[0] = 0.00625
# [    7591] VBDF updateTimeHistory call 288 tLast=1.79375 t=1.8 dt= 0.00625 dt_history[0] = 0.00625
# [    7592]
# t= 1.8; error_u_L2[0][0]= 0.0016228;
# [    7592] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [    7592] SimTools proj velocity for error calling projectVelocityToFinestLevelNC
# [    7593]
# t= 1.8; error_u_L2[0][0]= 7.99558e-06;
# [    7596]
# t= 1.8; error_u_H1[0][0]= 6.845e-05;
# [    7597]
# t= 1.8; error_velocity_L2[0][0]= 0;

# %% [markdown]
# ### Import all the packages and tools needed to plot and analyze the solutions

# %%
import numpy as np

import matplotlib
matplotlib.use('svg')
# %matplotlib inline
# matplotlib.pylab.rcParams['figure.figsize'] = 16, 12
from matplotlib import  pyplot as plt
from matplotlib import animation
# from JSAnimation import IPython_display
from tables import openFile

from matplotlib import rc
rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex=True)

# %% [markdown]
# ### Error analysis
# Calculate the maximal values and maximal errors of computed quantities for plotting below

# %%
# # initialize the values to be calculated        
# velocity_max = -float("inf")  
# velocity_min = float("inf")
# pressure_max = -float("inf")
# pressure_min = float("inf")
# density_max = -float("inf")
# density_min = float("inf")

# velocity_diff_max = -float("inf")
# velocity_diff_min = float("inf")
# pressure_diff_max = -float("inf")
# pressure_diff_min = float("inf")
# density_diff_max = -float("inf")
# density_diff_min = float("inf")

# # loop through solutions and calculate the errors and extrema
# for i in np.arange(len(so.ctx.tnList)):
#     h5=openFile("guermond_example_variable_density_p0.h5","r")        
#     t = so.ctx.tnList[i]
#     xvals = h5.getNode("/nodesSpatial_Domain%i" %i)[:]
#     n = xvals.shape[0]
    
#     u = h5.getNode("/u%i" %i)[:n]
#     u_true = so.ctx.utrue(xvals,t)
#     v = h5.getNode("/v%i" %i)[:n]
#     v_true = so.ctx.vtrue(xvals,t)
#     p = h5.getNode("/p%i" %i)[:]
#     p_true = so.ctx.ptrue(xvals,t)
#     rho = h5.getNode("/rho%i" %i)[:n]
#     rho_true = so.ctx.rhotrue(xvals,t)
    
#     u_diff = u-u_true
#     v_diff = v-v_true
#     p_diff = p-p_true
#     rho_diff = rho-rho_true
    
#     h5.close()

#     # calculate the max and minima over entire solution output time
#     velocity_max = max(velocity_max, max(u), max(v))        
#     velocity_min = min(velocity_min, min(u), min(v)) 
#     pressure_max = max(pressure_max, max(p))
#     pressure_min = min(pressure_min, min(p)) 
#     density_max = max(density_max, max(rho))
#     density_min = min(density_min, min(rho)) 

#     # calculate maximal errors
#     velocity_diff_max = max(velocity_diff_max, max(u_diff), max(v_diff))
#     velocity_diff_min = min(velocity_diff_min, min(u_diff), min(v_diff))

#     pressure_diff_max = max(pressure_diff_max, max(p_diff))
#     pressure_diff_min = min(pressure_diff_min, min(p_diff))

#     density_diff_max = max(density_diff_max, max(rho_diff))
#     density_diff_min = min(density_diff_min, min(rho_diff))

# # now we have errors calculated, output them
# print "max velocity = %2.4f,\t min velocity = %2.4f" %(velocity_max, velocity_min)
# print "max pressure = %2.4f,\t min pressure = %2.4f" %(pressure_max, pressure_min)
# print "max density = %2.4f,\t min density = %2.4f" %(density_max, density_min)

# print "Discrete maximum norms (evaluated at nodal points):"
# print "\t||v||_{max}\t= %2.4e" %max(np.abs(velocity_diff_max),np.abs(velocity_diff_min))
# print "\t||p||_{max}\t= %2.4e" %max(np.abs(pressure_diff_max),np.abs(pressure_diff_min))
# print "\t||rho||_{max}\t= %2.4e" %max(np.abs(density_diff_max),np.abs(density_diff_min))

# %% [markdown]
# ### Norms Calculated at output time steps

# %%
rho_L2Error = np.array([0] + ns.modelList[0].simTools.errorData[0][0]['error_u_L2'])
u_L2Error = np.array([0] + ns.modelList[1].simTools.errorData[0][0]['error_u_L2'])
v_L2Error = np.array([0] + ns.modelList[1].simTools.errorData[1][0]['error_u_L2'])
p_L2Error = np.array([0] + ns.modelList[1].simTools.errorData[2][0]['error_u_L2'])
gradu_L2Error = np.array([0] + ns.modelList[1].simTools.errorData[0][0]['error_u_H1'])
gradv_L2Error = np.array([0] + ns.modelList[1].simTools.errorData[1][0]['error_u_H1'])
gradp_L2Error = np.array([0] + ns.modelList[1].simTools.errorData[2][0]['error_u_H1'])

velpp_L2Error = np.array([0] + ns.modelList[1].simTools.errorData[2][0]['error_velocity_L2'])

vel_L2Error = np.sqrt(u_L2Error**2 + v_L2Error**2)
vel_H1Error = np.sqrt(vel_L2Error**2 + gradu_L2Error**2 + gradv_L2Error**2)

diff_vel_L2Error = velpp_L2Error - vel_L2Error

# plt.plot(so.ctx.tnList,diff_vel_L2Error)
plt.plot(so.ctx.tnList,velpp_L2Error)


# calculate the maximum time E space norm
vel_maxL2Norm = np.max(vel_L2Error)
vel_maxH1Norm = np.max(vel_H1Error)
p_maxL2Norm = np.max(p_L2Error)
rho_maxL2Norm = np.max(rho_L2Error)
velpp_maxL2Norm = np.max(velpp_L2Error)

print "Maximum in time norms:"
print "  ||v||_{Linf-L2}\t= %2.4e" %vel_maxL2Norm
print "  ||v||_{Linf-H1}\t= %2.4e" %vel_maxH1Norm
print "  ||p||_{Linf-L2}\t= %2.4e" %p_maxL2Norm
print "  ||rho||_{Linf-L2}\t= %2.4e" %rho_maxL2Norm
print "  ||vpp||_{Linf-L2}\t= %2.4e" %velpp_maxL2Norm


# calculate the \ell_2 time E space norm
rho_ell2L2Norm = p_ell2L2Norm = vel_ell2L2Norm = vel_ell2H1Norm = velpp_ell2L2Norm = 0
for i,t in enumerate(so.ctx.tnList):
    if i > 0:
        dt = so.ctx.tnList[i] - so.ctx.tnList[i-1]
        vel_ell2L2Norm += dt * vel_L2Error[i]**2
        vel_ell2H1Norm += dt * vel_H1Error[i]**2
        p_ell2L2Norm   += dt * p_L2Error[i]**2
        rho_ell2L2Norm += dt * rho_L2Error[i]**2
        velpp_ell2L2Norm += dt * velpp_L2Error[i]**2

#         print i, dt, rho_L2Error[i]**2, dt * rho_L2Error[i]**2,  rho_ell2L2Norm

vel_ell2L2Norm = np.sqrt(vel_ell2L2Norm)
vel_ell2H1Norm = np.sqrt(vel_ell2H1Norm)
p_ell2L2Norm = np.sqrt(p_ell2L2Norm)
rho_ell2L2Norm = np.sqrt(rho_ell2L2Norm)
velpp_ell2L2Norm = np.sqrt(velpp_ell2L2Norm)


print "\n\\ell_2 in time norms:"
print "  ||v||_{\\ell_2-L2}\t= %2.4g" %vel_ell2L2Norm
print "  ||v||_{\\ell_2-H1}\t= %2.4g" %vel_ell2H1Norm
print "  ||p||_{\\ell_2-L2}\t= %2.4g" %p_ell2L2Norm
print "  ||rho||_{\\ell_2-L2}\t= %2.4g" %rho_ell2L2Norm
print "  ||vpp||_{\\ell_2-L2}\t= %2.4g" %velpp_ell2L2Norm

# %%
# plot time series of errors

fig = plt.figure(figsize=(8,6)) # w, h in inches
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

ax1.set_title("$\\|\\rho(t)\\|_{L^2(\\Omega)}$")
ax2.set_title("$\\|p(t)\\|_{L^2(\\Omega)}$")
ax3.set_title("$\\|\mathbf{v}(t)\\|_{L^2(\\Omega)}$")
ax4.set_title("$\\|\mathbf{v}(t)\\|_{H^1(\\Omega)}$")

ax1.set_xlabel("t")
ax2.set_xlabel("t")
ax3.set_xlabel("t")
ax4.set_xlabel("t")

ax1.plot(so.ctx.tnList,rho_L2Error)
ax2.plot(so.ctx.tnList,p_L2Error)
ax3.plot(so.ctx.tnList,vel_L2Error)
ax4.plot(so.ctx.tnList,vel_H1Error)

fig.tight_layout() # spread out the plots so that they don't overlap

# %% [markdown]
# ##Plotting and Animations

# %% [markdown]
# Check to see if ffmpeg or mencoder are available for creating mp4 video of animations
# and whether or not to produce the mp4 movies

# %%
cmd_exists = lambda x: any(os.access(os.path.join(path, x), os.X_OK) for path in os.environ["PATH"].split(os.pathsep))
ffmpeg_is_available = cmd_exists('ffmpeg')
print 'ffmpeg_is_available = %r' %ffmpeg_is_available
mencoder_is_available = cmd_exists('mencoder')
print 'mencoder_is_available = %r' %mencoder_is_available


# switch to save animations as mp4 if it is possible (you have ffmpeg or mencoder installed)
# we check for the availability of these encoders below

make_mp4_movie = False
print 'make_mp4_movie = %r' %make_mp4_movie

# %% [markdown]
# ###Plot the Triangulation

# %%
fig_mesh = plt.figure(figsize=(4,4)) # w, h in inches
h5=openFile("guermond_example_variable_density_p0.h5","r") 
nodes = h5.getNode("/nodesSpatial_Domain%i" %0)[:]
triangles = h5.getNode("/elementsSpatial_Domain%i" %0)[:]
plt.triplot(nodes[:,0],nodes[:,1],triangles)
plt.axis('equal')
# close the table file after extracting all the solutions for the movie above
h5.close()

# %% [markdown]
# ###Plot the velocity errors

# %%
# if outputVelocity:
# setup initial figure spacing and create frames for input
fig = plt.figure(figsize=(12,6.5)) # w, h in inches

axvelerr = fig.add_subplot(231)
axu = fig.add_subplot(232)
axv = fig.add_subplot(233)
axvelquiv = fig.add_subplot(234)
axeu = fig.add_subplot(235)
axev = fig.add_subplot(236)

axvelerr.set_aspect('equal')
axvelquiv.set_aspect('equal')
axu.set_aspect('equal')
axv.set_aspect('equal')
axeu.set_aspect('equal')
axev.set_aspect('equal')

axvelerr.set_title('$\\|\\vec{v} - \\vec{v}_{true}\\|_{\ell_2}$')
axvelquiv.set_title('velocity')
axu.set_title('computed u')
axv.set_title('computed v')
axeu.set_title('exact u')
axev.set_title('exact v')

fig.tight_layout() # spread out the plots so that they don't overlap

# adjust plots to make room for colorbars
fig.subplots_adjust(right=0.8,top=0.98,left=0.15)
cbar_ax_right = fig.add_axes([0.85, 0.15, 0.05, 0.7])
cbar_ax_left = fig.add_axes([0.0, 0.15, 0.05, 0.7])


title = fig.suptitle("",x=0.5, y=1.00,
         horizontalalignment='center',
         fontsize=14,)

velocity_ell2_max = np.sqrt(2)*max(np.abs(velocity_diff_max),np.abs(velocity_diff_min))

# normalization parameters for plots to make colors consistent across plots
norm_velerr = plt.Normalize(vmin=0.0,vmax=velocity_ell2_max)
norm_vel = plt.Normalize(vmin=velocity_min,vmax=velocity_max)

# create scalar mappables that we will use for the colorbars to show entire range
# of colors instead of have them be autoscaled at each time step
#
# Thus the colorbars will be static instead of adapted to each shown plot
velerrfullrange = np.linspace(0.0,velocity_ell2_max,10)
vfullrange = np.linspace(velocity_min,velocity_max,10)

sm_velerr = plt.cm.ScalarMappable(cmap=plt.get_cmap(), norm=norm_velerr)
sm_velerr.set_array(velerrfullrange)

sm_vel = plt.cm.ScalarMappable(cmap=plt.get_cmap(), norm=norm_vel)
sm_vel.set_array(vfullrange)


def init():
    c_velerr = axvelerr.plot([],[])
    c_velquiv = axvelquiv.plot([],[])
    c_u = axu.plot([],[])
    c_v = axv.plot([],[])
    c_eu = axeu.plot([],[])
    c_ev = axev.plot([],[])
    return (c_u,c_v,c_eu,c_ev,c_velquiv,c_velerr)


def animate(i):
    # time
    t = so.ctx.tnList[i]
    title.set_text("t = %.2f" %t)

    h5=openFile("guermond_example_variable_density_p0.h5","r")        
    triangles = h5.getNode("/elementsSpatial_Domain%i" %i)
    xvals = h5.getNode("/nodesSpatial_Domain%i" %i)[:]
    n = xvals.shape[0]

    u = h5.getNode("/u%i" %i)[:n]
    v = h5.getNode("/v%i" %i)[:n]
    u_true = so.ctx.utrue(xvals,t)
    v_true = so.ctx.vtrue(xvals,t)

    vel_error = np.sqrt(pow(u-u_true,2.) + pow(v-v_true,2.))

    c_velerr = axvelerr.tricontourf(xvals[:,0],xvals[:,1], triangles, vel_error, norm=norm_velerr)
    axvelquiv.cla() # clear quiver axes explicitly since it doesn't seem to do it on its own
    c_velquiv = axvelquiv.quiver(xvals[:,0],xvals[:,1],u,v,angles='xy',scale=10)
    axvelquiv.set_title('computed velocity')    
    c_u = axu.tricontourf(xvals[:,0],xvals[:,1], triangles, u, norm=norm_vel)
    c_eu = axeu.tricontourf(xvals[:,0],xvals[:,1], triangles, u_true, norm=norm_vel)    
    c_v = axv.tricontourf(xvals[:,0],xvals[:,1], triangles, v, norm=norm_vel)
    c_ev = axev.tricontourf(xvals[:,0],xvals[:,1], triangles, v_true, norm=norm_vel)

    cbar_left = fig.colorbar(sm_velerr,cax=cbar_ax_left, norm=norm_velerr)  # static colorbar
    cbar_left.set_label("velocity norm error")

    cbar_right = fig.colorbar(sm_vel, cax=cbar_ax_right, norm=norm_vel)
    cbar_right.set_label("velocity")

    h5.close()
#     plt.show() # force the legends and formatting to show up

    return (c_u,c_v,c_eu,c_ev,c_velquiv,c_velerr)

# generate an animation from the data using the matplotlib.animation.FuncAnimation() function
anim = animation.FuncAnimation(fig, animate, init_func=init,
                        frames=len(so.ctx.tnList), interval=30, blit=True) # 30 milliseconds between frames  

# Now if possible, save movie as velocity_animation.mp4
if (ffmpeg_is_available or mencoder_is_available) and make_mp4_movie:
    # save the animation as an mp4.  This requires ffmpeg or mencoder to be
    # installed.  The extra_args ensure that the x264 codec is used, so that
    # the video can be embedded in html5.  You may need to adjust this for
    # your system: for more information, see
    # http://matplotlib.sourceforge.net/api/animation_api.html
    anim.save('velocity_animation.mp4', fps=10, extra_args=['-vcodec', 'libx264','-pix_fmt', 'yuv420p']) #fps=30

# by saving the animation as anim, we suppress the html display modified by the JSanimation package
# so we explicitly call the display function in JSanimation as the last thing with our anim object
IPython_display.display_animation(anim)

# %% [markdown]
# ###Plot the Pressure Errors

# %%
# if outputPressure:
fig = plt.figure(figsize=(8,6)) # w, h in inches
axp = fig.add_subplot(222)
axep = fig.add_subplot(224)
axpdiff = fig.add_subplot(221)
axperr = fig.add_subplot(223)

fig.tight_layout() # spread out the plots so that they don't overlap
fig.subplots_adjust(left=0.15, right=0.8,top=0.95)

cbar_ax_right = fig.add_axes([0.85, 0.15, 0.05, 0.7])
cbar_ax_left = fig.add_axes([0.0, 0.15, 0.05, 0.7])

title = fig.suptitle("",x=0.5, y=1.0,
         horizontalalignment='center',
         fontsize=14,)

axp.set_aspect('equal')
axep.set_aspect('equal')
axpdiff.set_aspect('equal')
axperr.set_aspect('equal')

axp.set_title('computed p')
axep.set_title('exact p')
axpdiff.set_title('diff p = $p-p_{true}$ ')
axperr.set_title('error p = $|p-p_{true}|$')

# normalization parameters for plots to make colors consistent across plots
norm_p = plt.Normalize(vmin=pressure_min,vmax=pressure_max)
norm_pdiff = plt.Normalize(vmin=pressure_diff_min,vmax=pressure_diff_max)

# create scalar mappables that we will use for the colorbars to show entire range
# of colors instead of have them be autoscaled at each time step
#
# Thus the colorbars will be static instead of adapted to each shown plot
pfullrange = np.linspace(pressure_min,pressure_max,10)
pdifffullrange = np.linspace(pressure_diff_min,pressure_diff_max,10)

sm_p = plt.cm.ScalarMappable(cmap=plt.get_cmap(), norm=norm_p)
sm_p.set_array(pfullrange)

sm_pdiff = plt.cm.ScalarMappable(cmap=plt.get_cmap(), norm=norm_pdiff)
sm_pdiff.set_array(pdifffullrange)

# create animation plots
def init():
    c_p = axp.plot([],[])
    c_ep = axep.plot([],[])
    c_pdiff = axpdiff.plot([],[])
    c_perr = axperr.plot([],[])
    return (c_p, c_ep, c_pdiff, c_perr)

def animate(i):
    # time
    t = so.tnList[i]
    title.set_text("t = %.2f" %t)

    h5=openFile("guermond_example_variable_density_p0.h5","r") 

    # density
    xvals = h5.getNode("/nodesSpatial_Domain%i" %i)[:]
    n = xvals.shape[0]
    triangles = h5.getNode("/elementsSpatial_Domain%i" %i)[:]

    p = h5.getNode("/p%i" %i)[:]
    p_true = so.ctx.ptrue(xvals,t)

    pdiff = p-p_true
    perr = np.abs(pdiff)

    c_p = axp.tricontourf(xvals[:,0],xvals[:,1], triangles, p, norm=norm_p)
    c_ep = axep.tricontourf(xvals[:,0],xvals[:,1], triangles, p_true, norm=norm_p)
    c_pdiff = axpdiff.tricontourf(xvals[:,0],xvals[:,1],triangles,pdiff, norm=norm_pdiff)
    c_perr = axperr.tricontourf(xvals[:,0],xvals[:,1],triangles,perr, norm=norm_pdiff)

    cbar_left = fig.colorbar(sm_pdiff,cax=cbar_ax_left, norm=norm_pdiff)
    cbar_left.set_label("pressure diff")

    cbar_right = fig.colorbar(sm_p, cax=cbar_ax_right, norm=norm_p)
    cbar_right.set_label("pressure")

    h5.close()
#     plt.show() # force the legends and formatting to show up

    return (c_p, c_ep, c_pdiff, c_perr)


# generate an animation from the data using the matplotlib.animation.FuncAnimation() function
anim = animation.FuncAnimation(fig, animate, init_func=init,
                        frames=len(so.ctx.tnList), interval=30, blit=True) # 30 milliseconds between frames  

# Now if possible, save movie as velocity_animation.mp4
if (ffmpeg_is_available or mencoder_is_available) and make_mp4_movie:
    # save the animation as an mp4.  This requires ffmpeg or mencoder to be
    # installed.  The extra_args ensure that the x264 codec is used, so that
    # the video can be embedded in html5.  You may need to adjust this for
    # your system: for more information, see
    # http://matplotlib.sourceforge.net/api/animation_api.html
    anim.save('pressure_animation.mp4', fps=10, extra_args=['-vcodec', 'libx264','-pix_fmt', 'yuv420p']) #fps=30

# by saving the animation as anim, we suppress the html display modified by the JSanimation package
# so we explicitly call the display function in JSanimation as the last thing with our anim object
IPython_display.display_animation(anim)

# %% [markdown]
# ###Plot the density errors

# %%
# if outputDensity:
fig = plt.figure(figsize=(8,6)) # w, h in inches
axrho = fig.add_subplot(222)
axrhoerr = fig.add_subplot(221)
axvel = fig.add_subplot(224)
axrhodiff = fig.add_subplot(223)


fig.tight_layout() # spread out the plots so that they don't overlap
fig.subplots_adjust(right=0.8,top=0.95,left=0.15)

cbar_ax_right = fig.add_axes([0.85, 0.15, 0.05, 0.7])
cbar_ax_left = fig.add_axes([0.0, 0.15, 0.05, 0.7])

title = fig.suptitle("",x=0.5, y=1.0,
         horizontalalignment='center',
         fontsize=14,)

axrho.set_aspect('equal')
axrhoerr.set_aspect('equal')
axvel.set_aspect('equal')
axrhodiff.set_aspect('equal')

axrho.set_title('computed $\\rho$')
# axerho.set_title('exact $\\rho$')
axrhoerr.set_title('$\\rho$ error = $|\\rho - \\rho_{ex}|$')
axrhodiff.set_title('$\\rho$ diff = $\\rho - \\rho_{ex}$')
axvel.set_title('computed velocity')

# normalization parameters for plots to make colors consistent across plots
norm_rho = plt.Normalize(vmin=density_min,vmax=density_max)
norm_rhodiff = plt.Normalize(vmin=density_diff_min,vmax=density_diff_max)

# create scalar mappables that we will use for the colorbars to show entire range
# of colors instead of have them be autoscaled at each time step
#
# Thus the colorbars will be static instead of adapted to each shown plot
rhofullrange = np.linspace(density_min,density_max,10)
rhodifffullrange = np.linspace(density_diff_min,density_diff_max,10)

sm_rhodiff = plt.cm.ScalarMappable(cmap=plt.get_cmap(), norm=norm_rhodiff)
sm_rhodiff.set_array(rhodifffullrange)

sm_rho = plt.cm.ScalarMappable(cmap=plt.get_cmap(), norm=norm_rho)
sm_rho.set_array(rhofullrange)


# create animation plots

def init():
    t = so.tnList[0]
    title.set_text("t = %.2f" %t)

    h5=openFile("guermond_example_variable_density_p0.h5","r") 
    xvals = h5.getNode("/nodesSpatial_Domain%i" %0)[:]
    n = xvals.shape[0]
    triangles = h5.getNode("/elementsSpatial_Domain%i" %0)[:]
    u = h5.getNode("/u%i" %0)[:n]
    v = h5.getNode("/v%i" %0)[:n]
    rho_comp = h5.getNode("/rho%i" %0)[:n]
    rho_true = so.ctx.rhotrue(xvals,t)
    h5.close()

    c_rhodiff = axrhodiff.tricontourf(xvals[:,0],xvals[:,1],triangles,rho_true, norm=norm_rhodiff)
    c_rho = axrho.tricontourf(xvals[:,0],xvals[:,1],triangles,rho_comp, norm=norm_rho)
    c_rhoerr = axrhoerr.tricontourf(xvals[:,0],xvals[:,1],triangles,rho_true, norm=norm_rhodiff)
    c_vel = axvel.quiver(xvals[:,0],xvals[:,1],u,v,angles='xy',scale=10)
    axvel.set_title('computed velocity')
    return (c_rho, c_rhodiff,c_vel,c_rhoerr)

def animate(i):
    # time
    t = so.tnList[i]
    title.set_text("t = %.2f" %t)

    h5=openFile("guermond_example_variable_density_p0.h5","r") 

    # density
    xvals = h5.getNode("/nodesSpatial_Domain%i" %i)[:]
    n = xvals.shape[0]
    triangles = h5.getNode("/elementsSpatial_Domain%i" %i)[:]

    u = h5.getNode("/u%i" %i)[:n]
    v = h5.getNode("/v%i" %i)[:n]

    rho = h5.getNode("/rho%i" %i)[:n]
    rho_true = so.ctx.rhotrue(xvals,t)

    rho_diff = rho-rho_true
    rho_err = np.abs(rho-rho_true)

    c_rho = axrho.tricontourf(xvals[:,0],xvals[:,1],triangles,rho, norm=norm_rho)
    c_rhodiff = axrhodiff.tricontourf(xvals[:,0],xvals[:,1],triangles,rho_diff, norm=norm_rhodiff)
    c_rhoerr = axrhoerr.tricontourf(xvals[:,0],xvals[:,1],triangles,rho_err, norm=norm_rhodiff)
    axvel.cla() # clear quiver axes explicitly since it doesn't seem to do it on its own
    c_vel = axvel.quiver(xvals[:,0],xvals[:,1],u,v,angles='xy',scale=10)
    axvel.set_title('computed velocity')

    cbar_right = fig.colorbar(sm_rho, cax=cbar_ax_right, norm=norm_rho)
    cbar_right.set_label("density")

    cbar_left = fig.colorbar(sm_rhodiff,cax=cbar_ax_left, norm=norm_rhodiff)
    cbar_left.set_label("$\\rho$ diff")

    h5.close()
#     plt.show() # force the legends and formatting to show up

    return (c_rho, c_rhoerr, c_vel,c_rhodiff)


# generate an animation from the data using the matplotlib.animation.FuncAnimation() function
anim = animation.FuncAnimation(fig, animate, init_func=init,
                        frames=len(so.ctx.tnList), interval=30, blit=True) # 30 milliseconds between frames  

# Now if possible, save movie as velocity_animation.mp4
if (ffmpeg_is_available or mencoder_is_available) and make_mp4_movie:
    # save the animation as an mp4.  This requires ffmpeg or mencoder to be
    # installed.  The extra_args ensure that the x264 codec is used, so that
    # the video can be embedded in html5.  You may need to adjust this for
    # your system: for more information, see
    # http://matplotlib.sourceforge.net/api/animation_api.html
    anim.save('density_animation.mp4', fps=10, extra_args=['-vcodec', 'libx264','-pix_fmt', 'yuv420p']) #fps=30

# by saving the animation as anim, we suppress the html display modified by the JSanimation package
# so we explicitly call the display function in JSanimation as the last thing with our anim object
IPython_display.display_animation(anim)

# %% [markdown]
# ###Plot all computed solutions

# %%
# if outputSolutions:
# setup initial figure spacing and create frames for input
fig = plt.figure(figsize=(10,6)) # w, h in inches

axp = fig.add_subplot(221)
axu = fig.add_subplot(222)
axv = fig.add_subplot(224)
axrho = fig.add_subplot(223)

axp.set_aspect('equal')
axu.set_aspect('equal')
axv.set_aspect('equal')
axrho.set_aspect('equal')

axp.set_title('pressure')
axu.set_title('u velocity')
axv.set_title('v velocity')
axrho.set_title('density')

fig.tight_layout() # spread out the plots so that they don't overlap

# adjust plots to make room for colorbars
fig.subplots_adjust(left=0.2,right=0.8,top=0.95)
cbar_ax_right = fig.add_axes([0.85, 0.15, 0.05, 0.7])
cbar_ax_farleft = fig.add_axes([0.0, 0.15, 0.05, 0.7]) #[left bottom width height]
cbar_ax_left = fig.add_axes([0.10, 0.15, 0.05, 0.7])

title = fig.suptitle("",x=0.5, y=1.00,
         horizontalalignment='center',
         fontsize=14,)

# normalization parameters for plots to make colors consistent across plots
norm_p = plt.Normalize(vmin=pressure_min,vmax=pressure_max)
norm_vel = plt.Normalize(vmin=velocity_min,vmax=velocity_max)
norm_rho = plt.Normalize(vmin=density_min,vmax=density_max)

# create scalar mappables that we will use for the colorbars to show entire range
# of colors instead of have them be autoscaled at each time step
#
# Thus the colorbars will be static instead of adapted to each shown plot
pfullrange = np.linspace(pressure_min,pressure_max,10)
vfullrange = np.linspace(velocity_min,velocity_max,10)
rhofullrange = np.linspace(density_min,density_max,10)

sm_p = plt.cm.ScalarMappable(cmap=plt.get_cmap(), norm=norm_p)
sm_p.set_array(pfullrange)

sm_vel = plt.cm.ScalarMappable(cmap=plt.get_cmap(), norm=norm_vel)
sm_vel.set_array(vfullrange)

sm_rho = plt.cm.ScalarMappable(cmap=plt.get_cmap(), norm=norm_rho)
sm_rho.set_array(rhofullrange)


def init():
    c_p = axp.plot([],[])
    c_rho = axrho.plot([],[])
    c_u = axu.plot([],[])
    c_v = axv.plot([],[])
    return (c_u,c_v,c_rho,c_p)


def animate(i):
    # time
    t = so.ctx.tnList[i]
    title.set_text("t = %.2f" %t)

    h5=openFile("guermond_example_variable_density_p0.h5","r")        
    triangles = h5.getNode("/elementsSpatial_Domain%i" %i)
    xvals = h5.getNode("/nodesSpatial_Domain%i" %i)[:]
    n = xvals.shape[0]

    p = h5.getNode("/p%i" %i)[:] 
    u = h5.getNode("/u%i" %i)[:n]
    v = h5.getNode("/v%i" %i)[:n]
    rho = h5.getNode("/rho%i" %i)[:n]

    c_p = axp.tricontourf(xvals[:,0],xvals[:,1], triangles, p, norm=norm_p)
    c_u = axu.tricontourf(xvals[:,0],xvals[:,1], triangles, u, norm=norm_vel)
    c_v = axv.tricontourf(xvals[:,0],xvals[:,1], triangles, v, norm=norm_vel)
    c_rho = axrho.tricontourf(xvals[:,0],xvals[:,1], triangles, rho, norm=norm_rho)

    cbar_farleft = fig.colorbar(sm_p,cax=cbar_ax_farleft, norm=norm_p)
    cbar_farleft.set_label("pressure")

    cbar_left = fig.colorbar(sm_rho,cax=cbar_ax_left, norm=norm_rho)
    cbar_left.set_label("density")

    cbar_right = fig.colorbar(sm_vel, cax=cbar_ax_right, norm=norm_vel)
    cbar_right.set_label("velocity")

    h5.close()
#     plt.show() # force the legends and formatting to show up

    return (c_u,c_v,c_rho,c_p)

# generate an animation from the data using the matplotlib.animation.FuncAnimation() function
anim = animation.FuncAnimation(fig, animate, init_func=init,
                        frames=len(so.ctx.tnList), interval=30, blit=True) # 30 milliseconds between frames  

# Now if possible, save movie as velocity_animation.mp4
if (ffmpeg_is_available or mencoder_is_available) and make_mp4_movie:
    # save the animation as an mp4.  This requires ffmpeg or mencoder to be
    # installed.  The extra_args ensure that the x264 codec is used, so that
    # the video can be embedded in html5.  You may need to adjust this for
    # your system: for more information, see
    # http://matplotlib.sourceforge.net/api/animation_api.html
    anim.save('solutions_animation.mp4', fps=10, extra_args=['-vcodec', 'libx264','-pix_fmt', 'yuv420p']) #fps=30

# by saving the animation as anim, we suppress the html display modified by the JSanimation package
# so we explicitly call the display function in JSanimation as the last thing with our anim object
IPython_display.display_animation(anim)
