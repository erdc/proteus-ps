# %%
from util import load_macros
load_macros("macros.tex")
# Out:
# $\newcommand{\C}{\mathbb{C}}$
# $\newcommand{\Du}{\underline{D}}$
# $\newcommand{\veps}{\varepsilon}$
# $\newcommand{\eps}{\epsilon}$
# $\newcommand{\f}{\textbf{f}}$
# $\newcommand{\fb}{\textbf{f}}$
# $\newcommand{\F}{\mathbb{F}}$
# $\newcommand{\Fb}{\textbf{F}}$
# $\newcommand{\gb}{\textbf{g}}$
# $\newcommand{\h}{\textbf{h}}$
# $\newcommand{\kb}{\textbf{k}}$
# $\newcommand{\M}{\mathcal{M}}$
# $\newcommand{\N}{\mathbb{N}}$
# $\newcommand{\Norm}{\textbf{N}}$
# $\newcommand{\n}{\textbf{n}}$
# $\newcommand{\vp}{\varphi}$
# $\newcommand{\vph}{\hat{\varphi}}$
# $\newcommand{\p}{\phi}$
# $\newcommand{\Proj}{\mathbb{P}}$
# $\newcommand{\Pcal}{\mathcal{P}}$
# $\newcommand{\Q}{\mathbb{Q}}$
# $\newcommand{\R}{\mathbb{R}}$
# $\newcommand{\rb}{\textbf{r}}$
# $\newcommand{\s}[1]{\mathcal{#1}}$
# $\newcommand{\supp}{\text{supp}}$
# $\newcommand{\Surf}{\textbf{S}}$
# $\newcommand{\tpsi}{\tilde{\psi}}$
# $\newcommand{\ub}{\textbf{u}}$
# $\newcommand{\U}{\textbf{U}}$
# $\newcommand{\vb}{\textbf{v}}$
# $\newcommand{\V}{\mathbb{V}}$
# $\newcommand{\wb}{\textbf{w}}$
# $\newcommand{\x}{\textbf{x}}$
# $\newcommand{\xh}{\hat{x}}$
# $\newcommand{\X}{\textbf{X}}$
# $\newcommand{\y}{\textbf{y}}$
# $\newcommand{\yh}{\hat{y}}$
# $\newcommand{\Y}{\textbf{Y}}$
# $\newcommand{\Z}{\mathbb{Z}}$
# $\DeclareMathOperator{\sech}{sech}$
# $\DeclareMathOperator{\atanh}{atanh}$
# $\DeclareMathOperator{\sign}{sign}$
# $\DeclareMathOperator{\tr}{Trace}$
# $\DeclareMathOperator{\gradsymm}{\nabla_{s}}$
# $\DeclareMathOperator{\divergence}{div}$
# $\DeclareMathOperator{\diag}{diag}$
# $\DeclareMathOperator*{\argmin}{argmin}$
# $\DeclareMathOperator*{\argmax}{argmax}$
# $\DeclareMathOperator{\Span}{Span}$
# $\DeclareMathOperator{\rank}{rank}$
# $\newcommand{\br}[1]{\left\langle #1 \right\rangle}$
# $\newcommand{\paren}[1]{\left(#1\right)}$
# $\newcommand{\sq}[1]{\left[#1\right]}$
# $\newcommand{\set}[1]{\left\{\: #1 \:\right\}}$
# $\newcommand{\setp}[2]{\left\{\, #1\: \middle|\: #2 \, \right\}}$
# $\newcommand{\abs}[1]{\left| #1 \right|}$
# $\newcommand{\norm}[1]{\left\| #1 \right\|}$
# $\newcommand{\system}[1]{\left\{ \begin{array}{rl} #1 \end{array} \right.}$
# $\newcommand{\pf}[2]{\frac{\partial #1}{\partial #2}}$
# $\newcommand{\ipt}[2]{\langle #1,#2 \rangle}$
# $\newcommand{\ip}{\int_{-\infty}^{+\infty}}$
# $\renewcommand{\ker}[1]{\mathcal{N}(#1)}$
# $\newcommand{\ran}[1]{\mathcal{R}(#1)}$
# Loaded macros

# %% [markdown]
# Solve the 1D Navier-Stokes equation on a square domain.  That is, find $p,\mathbf{v}:\Omega \rightarrow \R \times \R^n$ such that
#
# $$
# \begin{align*}
# \nabla \cdot \mathbf{v}  &= r(x,t) \\
# \frac{\partial (\rho\mathbf{v})}{\partial t} + \nabla\cdot\left(\rho\mathbf{v}\otimes\mathbf{v}\right) +  \nabla p  - \nabla \cdot \left(\mu \nabla\mathbf{v}\right) &= \rho\mathbf{f}(x,t)
# \end{align*}
# $$
# on
# $$
# \Omega = [0,1]
# $$
#  where $r(x,t)$ is a function of space and time only, $\mathbf{f}(x,t)$ and the density, $\rho$, and viscosity, $\mu$, are constant.
#
# To be complete and solvable we add in dirichlet boundary conditions on $p(x,t)$ and inflow boundary conditions on velocity $v(x,t)$,  (this means we must set the diffusive bc = 0 and advective bc = None to allow for the inflow bc to happen)
# $$
# \left.p\right|_{\partial\Omega} = p(x,t)
# $$
# and for $\partial\Omega^{in} = \{ x \:|\: v(x,t)\cdot n < 0\}$ we have inflow in which case we set
# $$
# \left.v\right|_{\partial\Omega^{in}} = v(x,t).
# $$
# Finally we need initial conditions
# $$
# u(x,t=0) = u_0(x), \hspace{1cm} p(x,t=0) = p_0(x).
# $$

# %%
from proteus.iproteus import * #pull in what we need for using proteus interactively
Profiling.logLevel=2
Profiling.verbose = True

# %% [markdown]
# Define the PDE by defining the coefficients

# %%
class NavierStokes1D(TransportCoefficients.TC_base):
    """
    The coefficients of the Poisson equation 
    """
    def __init__(self,rofx,fofx,rho=1.0,mu=1.0):
        TransportCoefficients.TC_base.__init__(self, 
                         nc=2, #number of components
                         variableNames=['p','v'],
                         mass = {1:{1:'linear'}}, # du/dt
                         advection = {0:{1:'linear'}, # \nabla\cdot v
                                      1:{1:'nonlinear'}}, # \nabla \cdot (v\otimes v)
                         hamiltonian = {1:{0:'linear'}}, # grad (p)
                         diffusion = {1:{1:{1:'constant'}}}, # - 1/Re * \grad v
                         potential = {1:{1:'u'}}, # define the potential for the diffusion term to be the solution itself
                         reaction  = {0:{0:'constant'}, # r(x)
                                      1:{1:'constant'}}) # f(x)
        self.rofx=rofx
        self.fofx=fofx
        self.rho=rho
        self.mu=mu
        
    def evaluate(self,t,c):
        """
        evaluate quadrature point values held in the dictionary c
        These are labelled according to the 'master equation.' For example,
         
        c[('a',0,0)] = diffusion coefficient for the 0th equation (first) with respect to the
                       0th potential (the solution itself)
                       The value at each quadrature point is a n_d x n_d tensor (n_d=number of space dimensions).
                       Usually the tensor values are stored as a flat array in compressed sparse row format to save space. 
                       By default, we assume the tensor is full though.
                       
        c[('r',0)]   = reaction term for the 0th equation. This is where we will put the source term
        """
        p = c[('u',0)]
        v = c[('u',1)] #1D - x component of velocity
        grad_p = c[('grad(u)',0)]
        #equation 0  div(f) + r = 0  (proteus  notation)  div(velocity)=r(x) (our notation)
        c[('f',0)][...,0] = v
        c[('df',0,1)][...,0] = 1.0  # d_f^0_d_u^0
        c[('r',0)][:]     = -self.rofx(c['x'][:],t)
        c[('dr',0,0)][:]   = 0.0
        #equation 1   u_t + div (u^2) + grad(p) + div(-1/Re grad(v)) + f = 0
        c[('m',1)][:] = rho*v  # d/dt ( rho * v) = d/dt (m_1)
        c[('dm',1,1)][:] = rho  # d_m^1_d_u^1
        c[('f',1)][...,0] = rho*v*v # div ( v\otimes v)
        c[('df',1,1)][...,0] = 2.0*rho*v # d_f^1_d_u^1
        c[('H',1)][:] = grad_p[...,0] #grad(p)
        c[('dH',1,0)][...,0] = 1.0 # 1
        c[('r',1)][:]     = -rho*self.fofx(c['x'][:],t)
        c[('dr',1,1)][:]  = 0.0#0
        c[('a',1,1)][...,0] = mu # -mu*\grad v
        c[('da',1,1,1)][...,0] = 0.0 # -d_(1/Re)

# %% [markdown]
# Setup the problem by method of manufactured solution.
#
# We will introduce a specific example that we have implemented, but we use sympy to symbolically compute the source terms based on the navier stokes equation as defined above.  In order to change the solution, it is only necessary to update p and v below.
#
# A specific solution to 1D navier-stokes equation:
#
# $$
# p(x,t) = 1 + \sin(2\pi (x-t))
# $$
# and
# $$
# v(x,t) = \sin(2\pi(x-t))\cos(2\pi(x-t))
# $$
# thus
# $$
# r(x,t) = \nabla\cdot v = 2\pi\cos(4\pi(x-t))
# $$
# and
# $$
# \begin{split}
# f(x,t) = -2\pi\cos(4\pi(x-t)) &+ 4\pi\sin(2\pi(x-t))\cos^3(2\pi(x-t)) - 4\pi\sin^{3}(2\pi(x-t))\cos(2\pi(x-t))\\& + \frac{2\pi}{\rho}\cos(2\pi(x-t)) + \frac{8\pi^2\mu}{\rho}\sin(4\pi(x-t))
# \end{split}
# $$
#
# Note that we are not divergence free here in 1D since that would require constant velocity.  The momentum equation must be written in the form  $\nabla\cdot(v\otimes v)$  instead of $v\cdot\nabla v$ since the second form utilizes the fact that $v$ is divergence free.

# %% [markdown]
# Define the python functions for evaluating the terms. Note that the x array for the quadrature points will be a multidimensional array. The last dimension will be 3 always though.  This is done using the sympy module and is easily modified to represent any manufactured solution desired.

# %%
#use numpy for evaluations
import numpy as np

# Reynolds number
rho = 1.0
mu = 1.0

# Create the manufactured solution and run through sympy 
# to create the forcing function and solutions etc
#
# Import specific sympy functions to avoid overloading 
# numpy etc functions
from sympy.utilities.lambdify import lambdify
from sympy import (symbols, 
                   simplify,
                   diff)
from sympy.functions import (sin as sy_sin,
                             cos as sy_cos)
from sympy import pi as sy_pi

# use xs and ts to represent symbolic x and t
xs,ts = symbols('x t')
# solution:
p = 1 + sy_sin(2*sy_pi*(xs-ts))
v = sy_sin(2*sy_pi*(xs-ts))*sy_cos(2*sy_pi*(xs-ts))

# manufacture the source terms:
r = simplify(diff(v,xs))
# note that we use the div(rho u\otimes u) form of convection since we are not
# divergence free
f = simplify((diff(rho*v,ts) + diff(rho*v*v,xs) + diff(p,xs) - diff(mu*v,xs,xs))/rho)

# use lambdify to convert from sympy to python expressions
pl = lambdify((xs, ts), p, "numpy")
vl = lambdify((xs, ts), v, "numpy")
rl = lambdify((xs, ts), r, "numpy")
fl = lambdify((xs, ts), f, "numpy")

# convert python expressions to the format we need for multidimensional x values
def pex0(x,t): 
    return pl(x[...,0],t)

def vex0(x,t):
    return vl(x[...,0],t)

def rofx0(x,t):
    return rl(x[...,0],t)

def fofx0(x,t):
    return fl(x[...,0],t)

# %% [markdown]
# Define the physical input to the model

# %%
#use numpy for evaluations
import numpy as np
physics = default_p
physics.name = "navier_stokes_1d"
physics.nd = 1; #One dimension
#spatial domain
physics.L=(1.0,1.0,1.0)

# Integrate from t=0 to t=1
physics.T = 1.0

#the object for evaluating the coefficients   
physics.coefficients=NavierStokes1D(rofx0,fofx0,rho,mu)

#this functions job is to return another function holding the Dirichlet boundary conditions 
# wherever they are set
    
eps=1.0e-8
boundaryFlags = {'left':1,'right':2,'top':3}
def getDBC_p(x,flag):
    if x[0] <= 0.0+eps:
        return lambda x,t: pex0(x,t)
    elif x[0] >= physics.L[0]-eps:
        return lambda x,t: pex0(x,t)
    else:
        return None
    
def getDBC_v(x,flag):
    if x[0] <= 0.0+eps:
        return lambda x,t: vex0(x,t)
    elif x[0] >= physics.L[0]-eps:
        return lambda x,t: vex0(x,t)
    else:
        return None
    
def getNone(x,flag):
    return None

def getZeroFlux(x,flag):
    if x[0] <= 0.0+eps:
        return lambda x,t: 0.0
    elif x[0] >= physics.L[0]-eps:
        return lambda x,t: 0.0
    else:
        return None
    
class getIBC_p:
    def __init__(self):
        self.pex0=pex0
        pass
    def uOfXT(self,x,t):
        return self.pex0(x,t)

    
class getIBC_v:
    def __init__(self):
        self.vex0=vex0
        pass
    def uOfXT(self,x,t):
        return self.vex0(x,t)
    
physics.initialConditions = {0:getIBC_p(),
                             1:getIBC_v()}

physics.dirichletConditions = {0:getDBC_p,#pressure Dirichlet
                               1:getDBC_v}

physics.advectiveFluxBoundaryConditions = {0:getNone}#dummy condition for non-existent  advective flux
#physics.advectiveFluxBoundaryConditions = {1:getZeroFlux}#dummy condition for non-existent  advective flux

#there are no diffusion terms in this model, but I had to 
physics.diffusiveFluxBoundaryConditions = {1:{1:getZeroFlux}}#viscous flux
physics.fluxBoundaryConditions = {0:'mixedFlow',1:'outFlow'}
#physics.fluxBoundaryConditions = {0:'setFlow',1:'setFlow'}

# %% [markdown]
# Define the numerics input for the problem

# %%
numerics=default_n
#piecewise linears
numerics.femSpaces = {0:FemTools.C0_AffineLinearOnSimplexWithNodalBasis,#pressure space
                      1:FemTools.C0_AffineQuadraticOnSimplexWithNodalBasis}#velocity space

numerics.timeIntegration = TimeIntegration.BackwardEuler
numerics.DT = 0.01
numerics.tnList = list(np.arange(0.0,physics.T+numerics.DT,numerics.DT))
# numerics.nDTout=10

#Quadrature rules for elements and element  boundaries
numerics.elementQuadrature = Quadrature.SimplexGaussQuadrature(physics.nd,5)
numerics.elementBoundaryQuadrature = Quadrature.SimplexGaussQuadrature(physics.nd-1,5)
#number of nodes in the x and y direction
numerics.nn = 101
#numerics.nny= 41
#matrix type
numerics.numericalFluxType = NumericalFlux.StrongDirichletFactory(physics.fluxBoundaryConditions)
#numerics.numericalFluxType = MixedDarcy_exterior
#numerics.numericalFluxType = NumericalFlux.Advection_DiagonalUpwind_Diffusion_IIPG_exterior
#numerics.numericalFluxType = NumericalFlux.Advection_Diagonal_average
numerics.matrix = LinearAlgebraTools.SparseMatrix
#use petsc solvers wrapped by petsc4py
#numerics.multilevelLinearSolver = LinearSolvers.KSP_petsc4py
#numerics.levelLinearSolver = LinearSolvers.KSP_petsc4py
#using petsc4py requires weak boundary condition enforcement
#can also use our internal wrapper for SuperLU
numerics.multilevelLinearSolver = LinearSolvers.LU
numerics.levelLinearSolver = LinearSolvers.LU

numerics.multilevelNonlinearSolver = NonlinearSolvers.Newton
numerics.levelNonlinearSolver = NonlinearSolvers.Newton

#linear solve rtolerance

numerics.linTolFac = 0.001
numerics.tolFac = 0.0

numerics.l_atol_res = 1.0e-5
numerics.nl_atol_res = 1.0e-5
numerics.periodicDirichletConditions=None
#
# split operator options (trivial since we're not splitting)
#
so = default_so
so.name = physics.name
so.sList=[default_s]
so.tnList = numerics.tnList

# %% [markdown]
# Construct a NumericalSolution object and solve the problem

# %%
ns = NumericalSolution.NS_base(so,[physics],[numerics],so.sList,opts)
ns.calculateSolution('run1')


# begin error analysis and plotting of solution

#arrays for using matplotlib's unstructured plotting interface
x = ns.modelList[0].levelModelList[-1].mesh.nodeArray[:,0]
#y = ns.modelList[0].levelModelList[-1].mesh.nodeArray[:,1]
#triangles = ns.modelList[0].levelModelList[-1].mesh.elementNodesArray

# grab the last time step solution and save the components as pT and vT
pT = ns.modelList[0].levelModelList[-1].u[0].dof
vT = ns.modelList[0].levelModelList[-1].u[1].dof
# Out:
# [      26] Initializing NumericalSolution for navier_stokes_1d
#  System includes:
# navier_stokes_1d
#
# [      26] Setting Archiver(s)
# [      26] Setting up MultilevelMesh
# [      26] Building one multilevel mesh for all models
# [      26] Generating mesh for navier_stokes_1d
# [      26] Partitioning mesh among 1 processors using partitioningType = 0
# [      26] Number of Subdomain Elements Owned= 100
# [      26] Number of Subdomain Elements = 100
# [      26] Number of Subdomain Nodes Owned= 101
# [      26] Number of Subdomain Nodes = 101
# [      26] Number of Subdomain elementBoundaries Owned= 101
# [      26] Number of Subdomain elementBoundaries = 101
# [      26] Number of Subdomain Edges Owned= 100
# [      26] Number of Subdomain Edges = 100
# [      26] Finished partitioning
# [      26] *** Global ***
# Number of edges : 100
# Number of nodes : 101
#
# *** Local ***
# Number of edges : 100
# Number of nodes : 101
#
# [      26] Numerical Solution Sparse diffusion information key (1, 1) = (array([0, 1], dtype=int32), array([0], dtype=int32))
# [      26] Setting up MultilevelTransport for navier_stokes_1d
# [      26] Allocating phi
# [      26] Setting Boundary Conditions
# [      26] Setting Boundary Conditions-1
# [      26] Setting Boundary Conditions-2
# [      26] Setting Boundary Conditions-2a
# [      26] Setting Boundary Conditions-3
# [      26] Setting Boundary Conditions-4
# [      26] Sparse diffusion information key (1, 1) = (array([0, 1], dtype=int32), array([0], dtype=int32))
# fluxBoundaryCondition_components set([0, 1])
# [      26] Setting navier_stokes_1d stepController to proteus.StepControl.SC_base
# [      26] Setting up MultilevelLinearSolver fornavier_stokes_1d
# [      26] multilevelLinearSolverChooser type= proteus.LinearSolvers.LU
# [      26] Setting up MultilevelNonLinearSolver for navier_stokes_1d
# [      26] Finished setting up models and solvers
# [      26] Setting up SimTools for navier_stokes_1d
# [      26] Using tnList from so = navier_stokes_1d
# [      26] Time sequence[0.0, 0.01, 0.02, 0.029999999999999999, 0.040000000000000001, 0.050000000000000003, 0.059999999999999998, 0.070000000000000007, 0.080000000000000002, 0.089999999999999997, 0.10000000000000001, 0.11, 0.12, 0.13, 0.14000000000000001, 0.14999999999999999, 0.16, 0.17000000000000001, 0.17999999999999999, 0.19, 0.20000000000000001, 0.20999999999999999, 0.22, 0.23000000000000001, 0.23999999999999999, 0.25, 0.26000000000000001, 0.27000000000000002, 0.28000000000000003, 0.28999999999999998, 0.29999999999999999, 0.31, 0.32000000000000001, 0.33000000000000002, 0.34000000000000002, 0.35000000000000003, 0.35999999999999999, 0.37, 0.38, 0.39000000000000001, 0.40000000000000002, 0.41000000000000003, 0.41999999999999998, 0.42999999999999999, 0.44, 0.45000000000000001, 0.46000000000000002, 0.47000000000000003, 0.47999999999999998, 0.48999999999999999, 0.5, 0.51000000000000001, 0.52000000000000002, 0.53000000000000003, 0.54000000000000004, 0.55000000000000004, 0.56000000000000005, 0.57000000000000006, 0.57999999999999996, 0.58999999999999997, 0.59999999999999998, 0.60999999999999999, 0.62, 0.63, 0.64000000000000001, 0.65000000000000002, 0.66000000000000003, 0.67000000000000004, 0.68000000000000005, 0.69000000000000006, 0.70000000000000007, 0.70999999999999996, 0.71999999999999997, 0.72999999999999998, 0.73999999999999999, 0.75, 0.76000000000000001, 0.77000000000000002, 0.78000000000000003, 0.79000000000000004, 0.80000000000000004, 0.81000000000000005, 0.82000000000000006, 0.83000000000000007, 0.83999999999999997, 0.84999999999999998, 0.85999999999999999, 0.87, 0.88, 0.89000000000000001, 0.90000000000000002, 0.91000000000000003, 0.92000000000000004, 0.93000000000000005, 0.94000000000000006, 0.95000000000000007, 0.95999999999999996, 0.96999999999999997, 0.97999999999999998, 0.98999999999999999, 1.0]
# [      26] Setting navier_stokes_1d systemStepController to object of type proteus.SplitOperator.Sequential_MinModelStep
# [      26] Finished NumericalSolution initialization
# [      26] Setting initial conditions
# [      26] Setting initial conditions for navier_stokes_1d
# [      26] Setting initial conditions on model navier_stokes_1d
# [      26] Attaching models and running spin-up step if requested
# [      26] Archiving initial conditions
# [      26] Estimating initial time derivative and initializing time history for model navier_stokes_1d
# [      26] Choosing initial time step for model navier_stokes_1d
# [      26] Initializing time step on model navier_stokes_1d to dt =  1.00000e-02
# [      26] Initializing time history for model step controller
# [      26] Auxiliary variable calculations for model navier_stokes_1d
# [      26] Initializing time step on system Default System to dt =  1.00000e-02
# [      26] Initializing step sequence for system Default System to [(0.01, <proteus.Transport.MultilevelTransport instance at 0x7f4a635b0f80>)]
# [      26] Starting time stepping
# [      26] ==============================================================
# [      26] Solving over interval [ 0.00000e+00, 1.00000e-02]
# [      26] ==============================================================
# [      26] Model: navier_stokes_1d
# [      26] StepControl base stepExact t_model= 0.01 tOut= 0.01 t_model_last= 0.0 dt_model= 0.01 setting to 0.01
# [      26]    Newton it 0 norm(r) =  2.39815e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.39815e+06 test=r
# [      26]    Newton it 1 norm(r) =  5.94789e-03  		 norm(r)/(rtol*norm(r0)+atol) = 594.789 test=r
# [      26]    Newton it 2 norm(r) =  3.56728e-12  		 norm(r)/(rtol*norm(r0)+atol) =  3.56728e-07
# [      26] Step Taken, System time step t= 2.00000e-02, dt= 1.00000e-02
# [      26] Step Taken, Model step t= 2.00000e-02, dt= 1.00000e-02 for model navier_stokes_1d
# [      26] ==============================================================
# [      26] Solving over interval [ 1.00000e-02, 2.00000e-02]
# [      26] ==============================================================
# [      26] Model: navier_stokes_1d
# [      26] StepControl base stepExact t_model= 0.02 tOut= 0.02 t_model_last= 0.01 dt_model= 0.01 setting to 0.01
# [      26]    Newton it 0 norm(r) =  2.35911e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.35911e+06 test=r
# [      26]    Newton it 1 norm(r) =  5.79836e-03  		 norm(r)/(rtol*norm(r0)+atol) = 579.836 test=r
# [      26]    Newton it 2 norm(r) =  3.35426e-12  		 norm(r)/(rtol*norm(r0)+atol) =  3.35426e-07
# [      26] Step Taken, System time step t= 3.00000e-02, dt= 1.00000e-02
# [      26] Step Taken, Model step t= 3.00000e-02, dt= 1.00000e-02 for model navier_stokes_1d
# [      26] ==============================================================
# [      26] Solving over interval [ 2.00000e-02, 3.00000e-02]
# [      26] ==============================================================
# [      26] Model: navier_stokes_1d
# [      26] StepControl base stepExact t_model= 0.03 tOut= 0.03 t_model_last= 0.02 dt_model= 0.01 setting to 0.01
# [      26]    Newton it 0 norm(r) =  2.28476e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.28476e+06 test=r
# [      26]    Newton it 1 norm(r) =  5.51460e-03  		 norm(r)/(rtol*norm(r0)+atol) = 551.46 test=r
# [      26]    Newton it 2 norm(r) =  2.95765e-12  		 norm(r)/(rtol*norm(r0)+atol) =  2.95765e-07
# [      26] Step Taken, System time step t= 4.00000e-02, dt= 1.00000e-02
# [      26] Step Taken, Model step t= 4.00000e-02, dt= 1.00000e-02 for model navier_stokes_1d
# [      26] ==============================================================
# [      26] Solving over interval [ 3.00000e-02, 4.00000e-02]
# [      26] ==============================================================
# [      26] Model: navier_stokes_1d
# [      26] StepControl base stepExact t_model= 0.04 tOut= 0.04 t_model_last= 0.03 dt_model= 0.01 setting to 0.01
# [      26]    Newton it 0 norm(r) =  2.17379e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.17379e+06 test=r
# [      26]    Newton it 1 norm(r) =  5.11814e-03  		 norm(r)/(rtol*norm(r0)+atol) = 511.814 test=r
# [      26]    Newton it 2 norm(r) =  2.42646e-12  		 norm(r)/(rtol*norm(r0)+atol) =  2.42646e-07
# [      26] Step Taken, System time step t= 5.00000e-02, dt= 1.00000e-02
# [      26] Step Taken, Model step t= 5.00000e-02, dt= 1.00000e-02 for model navier_stokes_1d
# [      26] ==============================================================
# [      26] Solving over interval [ 4.00000e-02, 5.00000e-02]
# [      26] ==============================================================
# [      26] Model: navier_stokes_1d
# [      26] StepControl base stepExact t_model= 0.05 tOut= 0.05 t_model_last= 0.04 dt_model= 0.01 setting to 0.01
# [      26]    Newton it 0 norm(r) =  2.02858e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.02858e+06 test=r
# [      26]    Newton it 1 norm(r) =  4.64388e-03  		 norm(r)/(rtol*norm(r0)+atol) = 464.388 test=r
# [      26]    Newton it 2 norm(r) =  1.90440e-12  		 norm(r)/(rtol*norm(r0)+atol) =  1.90440e-07
# [      26] Step Taken, System time step t= 6.00000e-02, dt= 1.00000e-02
# [      26] Step Taken, Model step t= 6.00000e-02, dt= 1.00000e-02 for model navier_stokes_1d
# [      26] ==============================================================
# [      26] Solving over interval [ 5.00000e-02, 6.00000e-02]
# [      26] ==============================================================
# [      26] Model: navier_stokes_1d
# [      26] StepControl base stepExact t_model= 0.06 tOut= 0.06 t_model_last= 0.05 dt_model= 0.01 setting to 0.01
# [      26]    Newton it 0 norm(r) =  1.85144e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.85144e+06 test=r
# [      26]    Newton it 1 norm(r) =  4.13591e-03  		 norm(r)/(rtol*norm(r0)+atol) = 413.591 test=r
# [      26]    Newton it 2 norm(r) =  1.36847e-12  		 norm(r)/(rtol*norm(r0)+atol) =  1.36847e-07
# [      26] Step Taken, System time step t= 7.00000e-02, dt= 1.00000e-02
# [      26] Step Taken, Model step t= 7.00000e-02, dt= 1.00000e-02 for model navier_stokes_1d
# [      26] ==============================================================
# [      26] Solving over interval [ 6.00000e-02, 7.00000e-02]
# [      26] ==============================================================
# [      26] Model: navier_stokes_1d
# [      26] StepControl base stepExact t_model= 0.07 tOut= 0.07 t_model_last= 0.06 dt_model= 0.01 setting to 0.01
# [      26]    Newton it 0 norm(r) =  1.64522e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.64522e+06 test=r
# [      26]    Newton it 1 norm(r) =  3.64498e-03  		 norm(r)/(rtol*norm(r0)+atol) = 364.498 test=r
# [      26]    Newton it 2 norm(r) =  8.44129e-13  		 norm(r)/(rtol*norm(r0)+atol) =  8.44129e-08
# [      26] Step Taken, System time step t= 8.00000e-02, dt= 1.00000e-02
# [      26] Step Taken, Model step t= 8.00000e-02, dt= 1.00000e-02 for model navier_stokes_1d
# [      26] ==============================================================
# [      26] Solving over interval [ 7.00000e-02, 8.00000e-02]
# [      26] ==============================================================
# [      26] Model: navier_stokes_1d
# [      26] StepControl base stepExact t_model= 0.08 tOut= 0.08 t_model_last= 0.07 dt_model= 0.01 setting to 0.01
# [      26]    Newton it 0 norm(r) =  1.41320e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.4132e+06 test=r
# [      26]    Newton it 1 norm(r) =  3.22282e-03  		 norm(r)/(rtol*norm(r0)+atol) = 322.282 test=r
# [      26]    Newton it 2 norm(r) =  5.05305e-13  		 norm(r)/(rtol*norm(r0)+atol) =  5.05305e-08
# [      26] Step Taken, System time step t= 9.00000e-02, dt= 1.00000e-02
# [      26] Step Taken, Model step t= 9.00000e-02, dt= 1.00000e-02 for model navier_stokes_1d
# [      26] ==============================================================
# [      26] Solving over interval [ 8.00000e-02, 9.00000e-02]
# [      26] ==============================================================
# [      26] Model: navier_stokes_1d
# [      26] StepControl base stepExact t_model= 0.09 tOut= 0.09 t_model_last= 0.08 dt_model= 0.01 setting to 0.01
# [      26]    Newton it 0 norm(r) =  1.15915e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.15915e+06 test=r
# [      26]    Newton it 1 norm(r) =  2.91051e-03  		 norm(r)/(rtol*norm(r0)+atol) = 291.051 test=r
# [      26]    Newton it 2 norm(r) =  3.08767e-13  		 norm(r)/(rtol*norm(r0)+atol) =  3.08767e-08
# [      26] Step Taken, System time step t= 1.00000e-01, dt= 1.00000e-02
# [      26] Step Taken, Model step t= 1.00000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      26] ==============================================================
# [      26] Solving over interval [ 9.00000e-02, 1.00000e-01]
# [      26] ==============================================================
# [      26] Model: navier_stokes_1d
# [      26] StepControl base stepExact t_model= 0.1 tOut= 0.1 t_model_last= 0.09 dt_model= 0.01 setting to 0.01
# [      26]    Newton it 0 norm(r) =  8.87299e+00  		 norm(r)/(rtol*norm(r0)+atol) = 887299 test=r
# [      26]    Newton it 1 norm(r) =  2.72229e-03  		 norm(r)/(rtol*norm(r0)+atol) = 272.229 test=r
# [      26]    Newton it 2 norm(r) =  2.24259e-13  		 norm(r)/(rtol*norm(r0)+atol) =  2.24259e-08
# [      26] Step Taken, System time step t= 1.10000e-01, dt= 1.00000e-02
# [      26] Step Taken, Model step t= 1.10000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      26] ==============================================================
# [      26] Solving over interval [ 1.00000e-01, 1.10000e-01]
# [      26] ==============================================================
# [      26] Model: navier_stokes_1d
# [      26] StepControl base stepExact t_model= 0.11 tOut= 0.11 t_model_last= 0.1 dt_model= 0.01 setting to 0.01
# [      26]    Newton it 0 norm(r) =  6.02546e+00  		 norm(r)/(rtol*norm(r0)+atol) = 602546 test=r
# [      26]    Newton it 1 norm(r) =  2.63726e-03  		 norm(r)/(rtol*norm(r0)+atol) = 263.726 test=r
# [      26]    Newton it 2 norm(r) =  1.99712e-13  		 norm(r)/(rtol*norm(r0)+atol) =  1.99712e-08
# [      26] Step Taken, System time step t= 1.20000e-01, dt= 1.00000e-02
# [      26] Step Taken, Model step t= 1.20000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      26] ==============================================================
# [      26] Solving over interval [ 1.10000e-01, 1.20000e-01]
# [      26] ==============================================================
# [      26] Model: navier_stokes_1d
# [      26] StepControl base stepExact t_model= 0.12 tOut= 0.12 t_model_last= 0.11 dt_model= 0.01 setting to 0.01
# [      26]    Newton it 0 norm(r) =  3.12293e+00  		 norm(r)/(rtol*norm(r0)+atol) = 312293 test=r
# [      26]    Newton it 1 norm(r) =  2.61254e-03  		 norm(r)/(rtol*norm(r0)+atol) = 261.254 test=r
# [      26]    Newton it 2 norm(r) =  1.90557e-13  		 norm(r)/(rtol*norm(r0)+atol) =  1.90557e-08
# [      26] Step Taken, System time step t= 1.30000e-01, dt= 1.00000e-02
# [      26] Step Taken, Model step t= 1.30000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      26] ==============================================================
# [      26] Solving over interval [ 1.20000e-01, 1.30000e-01]
# [      26] ==============================================================
# [      26] Model: navier_stokes_1d
# [      26] StepControl base stepExact t_model= 0.13 tOut= 0.13 t_model_last= 0.12 dt_model= 0.01 setting to 0.01
# [      26]    Newton it 0 norm(r) =  8.55500e-01  		 norm(r)/(rtol*norm(r0)+atol) = 85550 test=r
# [      26]    Newton it 1 norm(r) =  2.60932e-03  		 norm(r)/(rtol*norm(r0)+atol) = 260.932 test=r
# [      26]    Newton it 2 norm(r) =  1.62178e-13  		 norm(r)/(rtol*norm(r0)+atol) =  1.62178e-08
# [      26] Step Taken, System time step t= 1.40000e-01, dt= 1.00000e-02
# [      26] Step Taken, Model step t= 1.40000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      26] ==============================================================
# [      26] Solving over interval [ 1.30000e-01, 1.40000e-01]
# [      26] ==============================================================
# [      26] Model: navier_stokes_1d
# [      26] StepControl base stepExact t_model= 0.14 tOut= 0.14 t_model_last= 0.13 dt_model= 0.01 setting to 0.01
# [      26]    Newton it 0 norm(r) =  3.13105e+00  		 norm(r)/(rtol*norm(r0)+atol) = 313105 test=r
# [      26]    Newton it 1 norm(r) =  2.61254e-03  		 norm(r)/(rtol*norm(r0)+atol) = 261.254 test=r
# [      26]    Newton it 2 norm(r) =  2.03106e-13  		 norm(r)/(rtol*norm(r0)+atol) =  2.03106e-08
# [      26] Step Taken, System time step t= 1.50000e-01, dt= 1.00000e-02
# [      26] Step Taken, Model step t= 1.50000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      26] ==============================================================
# [      26] Solving over interval [ 1.40000e-01, 1.50000e-01]
# [      26] ==============================================================
# [      26] Model: navier_stokes_1d
# [      26] StepControl base stepExact t_model= 0.15 tOut= 0.15 t_model_last= 0.14 dt_model= 0.01 setting to 0.01
# [      26]    Newton it 0 norm(r) =  6.03245e+00  		 norm(r)/(rtol*norm(r0)+atol) = 603245 test=r
# [      26]    Newton it 1 norm(r) =  2.63726e-03  		 norm(r)/(rtol*norm(r0)+atol) = 263.726 test=r
# [      26]    Newton it 2 norm(r) =  2.20926e-13  		 norm(r)/(rtol*norm(r0)+atol) =  2.20926e-08
# [      26] Step Taken, System time step t= 1.60000e-01, dt= 1.00000e-02
# [      26] Step Taken, Model step t= 1.60000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      26] ==============================================================
# [      26] Solving over interval [ 1.50000e-01, 1.60000e-01]
# [      26] ==============================================================
# [      26] Model: navier_stokes_1d
# [      26] StepControl base stepExact t_model= 0.16 tOut= 0.16 t_model_last= 0.15 dt_model= 0.01 setting to 0.01
# [      26]    Newton it 0 norm(r) =  8.87783e+00  		 norm(r)/(rtol*norm(r0)+atol) = 887783 test=r
# [      26]    Newton it 1 norm(r) =  2.72229e-03  		 norm(r)/(rtol*norm(r0)+atol) = 272.229 test=r
# [      26]    Newton it 2 norm(r) =  2.52015e-13  		 norm(r)/(rtol*norm(r0)+atol) =  2.52015e-08
# [      26] Step Taken, System time step t= 1.70000e-01, dt= 1.00000e-02
# [      26] Step Taken, Model step t= 1.70000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      26] ==============================================================
# [      26] Solving over interval [ 1.60000e-01, 1.70000e-01]
# [      26] ==============================================================
# [      26] Model: navier_stokes_1d
# [      26] StepControl base stepExact t_model= 0.17 tOut= 0.17 t_model_last= 0.16 dt_model= 0.01 setting to 0.01
# [      26]    Newton it 0 norm(r) =  1.15935e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.15935e+06 test=r
# [      26]    Newton it 1 norm(r) =  2.91051e-03  		 norm(r)/(rtol*norm(r0)+atol) = 291.051 test=r
# [      26]    Newton it 2 norm(r) =  3.20742e-13  		 norm(r)/(rtol*norm(r0)+atol) =  3.20742e-08
# [      26] Step Taken, System time step t= 1.80000e-01, dt= 1.00000e-02
# [      26] Step Taken, Model step t= 1.80000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      26] ==============================================================
# [      26] Solving over interval [ 1.70000e-01, 1.80000e-01]
# [      26] ==============================================================
# [      26] Model: navier_stokes_1d
# [      26] StepControl base stepExact t_model= 0.18 tOut= 0.18 t_model_last= 0.17 dt_model= 0.01 setting to 0.01
# [      26]    Newton it 0 norm(r) =  1.41306e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.41306e+06 test=r
# [      26]    Newton it 1 norm(r) =  3.22282e-03  		 norm(r)/(rtol*norm(r0)+atol) = 322.282 test=r
# [      26]    Newton it 2 norm(r) =  5.28141e-13  		 norm(r)/(rtol*norm(r0)+atol) =  5.28141e-08
# [      26] Step Taken, System time step t= 1.90000e-01, dt= 1.00000e-02
# [      26] Step Taken, Model step t= 1.90000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      26] ==============================================================
# [      26] Solving over interval [ 1.80000e-01, 1.90000e-01]
# [      26] ==============================================================
# [      26] Model: navier_stokes_1d
# [      26] StepControl base stepExact t_model= 0.19 tOut= 0.19 t_model_last= 0.18 dt_model= 0.01 setting to 0.01
# [      26]    Newton it 0 norm(r) =  1.64471e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.64471e+06 test=r
# [      26]    Newton it 1 norm(r) =  3.64498e-03  		 norm(r)/(rtol*norm(r0)+atol) = 364.498 test=r
# [      26]    Newton it 2 norm(r) =  8.84301e-13  		 norm(r)/(rtol*norm(r0)+atol) =  8.84301e-08
# [      26] Step Taken, System time step t= 2.00000e-01, dt= 1.00000e-02
# [      26] Step Taken, Model step t= 2.00000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      26] ==============================================================
# [      26] Solving over interval [ 1.90000e-01, 2.00000e-01]
# [      26] ==============================================================
# [      26] Model: navier_stokes_1d
# [      26] StepControl base stepExact t_model= 0.2 tOut= 0.2 t_model_last= 0.19 dt_model= 0.01 setting to 0.01
# [      26]    Newton it 0 norm(r) =  1.85057e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.85057e+06 test=r
# [      26]    Newton it 1 norm(r) =  4.13591e-03  		 norm(r)/(rtol*norm(r0)+atol) = 413.591 test=r
# [      26]    Newton it 2 norm(r) =  1.35005e-12  		 norm(r)/(rtol*norm(r0)+atol) =  1.35005e-07
# [      26] Step Taken, System time step t= 2.10000e-01, dt= 1.00000e-02
# [      26] Step Taken, Model step t= 2.10000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      26] ==============================================================
# [      26] Solving over interval [ 2.00000e-01, 2.10000e-01]
# [      26] ==============================================================
# [      26] Model: navier_stokes_1d
# [      26] StepControl base stepExact t_model= 0.21 tOut= 0.21 t_model_last= 0.2 dt_model= 0.01 setting to 0.01
# [      26]    Newton it 0 norm(r) =  2.02735e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.02735e+06 test=r
# [      26]    Newton it 1 norm(r) =  4.64389e-03  		 norm(r)/(rtol*norm(r0)+atol) = 464.389 test=r
# [      26]    Newton it 2 norm(r) =  1.88568e-12  		 norm(r)/(rtol*norm(r0)+atol) =  1.88568e-07
# [      26] Step Taken, System time step t= 2.20000e-01, dt= 1.00000e-02
# [      26] Step Taken, Model step t= 2.20000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      26] ==============================================================
# [      26] Solving over interval [ 2.10000e-01, 2.20000e-01]
# [      26] ==============================================================
# [      26] Model: navier_stokes_1d
# [      26] StepControl base stepExact t_model= 0.22 tOut= 0.22 t_model_last= 0.21 dt_model= 0.01 setting to 0.01
# [      26]    Newton it 0 norm(r) =  2.17225e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.17225e+06 test=r
# [      26]    Newton it 1 norm(r) =  5.11816e-03  		 norm(r)/(rtol*norm(r0)+atol) = 511.816 test=r
# [      26]    Newton it 2 norm(r) =  2.44573e-12  		 norm(r)/(rtol*norm(r0)+atol) =  2.44573e-07
# [      26] Step Taken, System time step t= 2.30000e-01, dt= 1.00000e-02
# [      26] Step Taken, Model step t= 2.30000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      27] ==============================================================
# [      27] Solving over interval [ 2.20000e-01, 2.30000e-01]
# [      27] ==============================================================
# [      27] Model: navier_stokes_1d
# [      27] StepControl base stepExact t_model= 0.23 tOut= 0.23 t_model_last= 0.22 dt_model= 0.01 setting to 0.01
# [      27]    Newton it 0 norm(r) =  2.28298e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.28298e+06 test=r
# [      27]    Newton it 1 norm(r) =  5.51471e-03  		 norm(r)/(rtol*norm(r0)+atol) = 551.471 test=r
# [      27]    Newton it 2 norm(r) =  2.96644e-12  		 norm(r)/(rtol*norm(r0)+atol) =  2.96644e-07
# [      27] Step Taken, System time step t= 2.40000e-01, dt= 1.00000e-02
# [      27] Step Taken, Model step t= 2.40000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      27] ==============================================================
# [      27] Solving over interval [ 2.30000e-01, 2.40000e-01]
# [      27] ==============================================================
# [      27] Model: navier_stokes_1d
# [      27] StepControl base stepExact t_model= 0.24 tOut= 0.24 t_model_last= 0.23 dt_model= 0.01 setting to 0.01
# [      27]    Newton it 0 norm(r) =  2.35778e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.35778e+06 test=r
# [      27]    Newton it 1 norm(r) =  5.79896e-03  		 norm(r)/(rtol*norm(r0)+atol) = 579.896 test=r
# [      27]    Newton it 2 norm(r) =  3.35181e-12  		 norm(r)/(rtol*norm(r0)+atol) =  3.35181e-07
# [      27] Step Taken, System time step t= 2.50000e-01, dt= 1.00000e-02
# [      27] Step Taken, Model step t= 2.50000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      27] ==============================================================
# [      27] Solving over interval [ 2.40000e-01, 2.50000e-01]
# [      27] ==============================================================
# [      27] Model: navier_stokes_1d
# [      27] StepControl base stepExact t_model= 0.25 tOut= 0.25 t_model_last= 0.24 dt_model= 0.01 setting to 0.01
# [      27]    Newton it 0 norm(r) =  2.39548e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.39548e+06 test=r
# [      27]    Newton it 1 norm(r) =  5.94713e-03  		 norm(r)/(rtol*norm(r0)+atol) = 594.713 test=r
# [      27]    Newton it 2 norm(r) =  3.56315e-12  		 norm(r)/(rtol*norm(r0)+atol) =  3.56315e-07
# [      27] Step Taken, System time step t= 2.60000e-01, dt= 1.00000e-02
# [      27] Step Taken, Model step t= 2.60000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      27] ==============================================================
# [      27] Solving over interval [ 2.50000e-01, 2.60000e-01]
# [      27] ==============================================================
# [      27] Model: navier_stokes_1d
# [      27] StepControl base stepExact t_model= 0.26 tOut= 0.26 t_model_last= 0.25 dt_model= 0.01 setting to 0.01
# [      27]    Newton it 0 norm(r) =  2.39548e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.39548e+06 test=r
# [      27]    Newton it 1 norm(r) =  5.94713e-03  		 norm(r)/(rtol*norm(r0)+atol) = 594.713 test=r
# [      27]    Newton it 2 norm(r) =  3.56549e-12  		 norm(r)/(rtol*norm(r0)+atol) =  3.56549e-07
# [      27] Step Taken, System time step t= 2.70000e-01, dt= 1.00000e-02
# [      27] Step Taken, Model step t= 2.70000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      27] ==============================================================
# [      27] Solving over interval [ 2.60000e-01, 2.70000e-01]
# [      27] ==============================================================
# [      27] Model: navier_stokes_1d
# [      27] StepControl base stepExact t_model= 0.27 tOut= 0.27 t_model_last= 0.26 dt_model= 0.01 setting to 0.01
# [      27]    Newton it 0 norm(r) =  2.35778e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.35778e+06 test=r
# [      27]    Newton it 1 norm(r) =  5.79896e-03  		 norm(r)/(rtol*norm(r0)+atol) = 579.896 test=r
# [      27]    Newton it 2 norm(r) =  3.36277e-12  		 norm(r)/(rtol*norm(r0)+atol) =  3.36277e-07
# [      27] Step Taken, System time step t= 2.80000e-01, dt= 1.00000e-02
# [      27] Step Taken, Model step t= 2.80000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      27] ==============================================================
# [      27] Solving over interval [ 2.70000e-01, 2.80000e-01]
# [      27] ==============================================================
# [      27] Model: navier_stokes_1d
# [      27] StepControl base stepExact t_model= 0.28 tOut= 0.28 t_model_last= 0.27 dt_model= 0.01 setting to 0.01
# [      27]    Newton it 0 norm(r) =  2.28297e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.28297e+06 test=r
# [      27]    Newton it 1 norm(r) =  5.51471e-03  		 norm(r)/(rtol*norm(r0)+atol) = 551.471 test=r
# [      27]    Newton it 2 norm(r) =  2.97308e-12  		 norm(r)/(rtol*norm(r0)+atol) =  2.97308e-07
# [      27] Step Taken, System time step t= 2.90000e-01, dt= 1.00000e-02
# [      27] Step Taken, Model step t= 2.90000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      27] ==============================================================
# [      27] Solving over interval [ 2.80000e-01, 2.90000e-01]
# [      27] ==============================================================
# [      27] Model: navier_stokes_1d
# [      27] StepControl base stepExact t_model= 0.29 tOut= 0.29 t_model_last= 0.28 dt_model= 0.01 setting to 0.01
# [      27]    Newton it 0 norm(r) =  2.17225e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.17225e+06 test=r
# [      27]    Newton it 1 norm(r) =  5.11815e-03  		 norm(r)/(rtol*norm(r0)+atol) = 511.815 test=r
# [      27]    Newton it 2 norm(r) =  2.45823e-12  		 norm(r)/(rtol*norm(r0)+atol) =  2.45823e-07
# [      27] Step Taken, System time step t= 3.00000e-01, dt= 1.00000e-02
# [      27] Step Taken, Model step t= 3.00000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      27] ==============================================================
# [      27] Solving over interval [ 2.90000e-01, 3.00000e-01]
# [      27] ==============================================================
# [      27] Model: navier_stokes_1d
# [      27] StepControl base stepExact t_model= 0.3 tOut= 0.3 t_model_last= 0.29 dt_model= 0.01 setting to 0.01
# [      27]    Newton it 0 norm(r) =  2.02734e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.02734e+06 test=r
# [      27]    Newton it 1 norm(r) =  4.64388e-03  		 norm(r)/(rtol*norm(r0)+atol) = 464.388 test=r
# [      27]    Newton it 2 norm(r) =  1.85164e-12  		 norm(r)/(rtol*norm(r0)+atol) =  1.85164e-07
# [      27] Step Taken, System time step t= 3.10000e-01, dt= 1.00000e-02
# [      27] Step Taken, Model step t= 3.10000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      27] ==============================================================
# [      27] Solving over interval [ 3.00000e-01, 3.10000e-01]
# [      27] ==============================================================
# [      27] Model: navier_stokes_1d
# [      27] StepControl base stepExact t_model= 0.31 tOut= 0.31 t_model_last= 0.3 dt_model= 0.01 setting to 0.01
# [      27]    Newton it 0 norm(r) =  1.85056e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.85056e+06 test=r
# [      27]    Newton it 1 norm(r) =  4.13590e-03  		 norm(r)/(rtol*norm(r0)+atol) = 413.59 test=r
# [      27]    Newton it 2 norm(r) =  1.33906e-12  		 norm(r)/(rtol*norm(r0)+atol) =  1.33906e-07
# [      27] Step Taken, System time step t= 3.20000e-01, dt= 1.00000e-02
# [      27] Step Taken, Model step t= 3.20000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      27] ==============================================================
# [      27] Solving over interval [ 3.10000e-01, 3.20000e-01]
# [      27] ==============================================================
# [      27] Model: navier_stokes_1d
# [      27] StepControl base stepExact t_model= 0.32 tOut= 0.32 t_model_last= 0.31 dt_model= 0.01 setting to 0.01
# [      27]    Newton it 0 norm(r) =  1.64470e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.6447e+06 test=r
# [      27]    Newton it 1 norm(r) =  3.64497e-03  		 norm(r)/(rtol*norm(r0)+atol) = 364.497 test=r
# [      27]    Newton it 2 norm(r) =  8.51880e-13  		 norm(r)/(rtol*norm(r0)+atol) =  8.51880e-08
# [      27] Step Taken, System time step t= 3.30000e-01, dt= 1.00000e-02
# [      27] Step Taken, Model step t= 3.30000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      27] ==============================================================
# [      27] Solving over interval [ 3.20000e-01, 3.30000e-01]
# [      27] ==============================================================
# [      27] Model: navier_stokes_1d
# [      27] StepControl base stepExact t_model= 0.33 tOut= 0.33 t_model_last= 0.32 dt_model= 0.01 setting to 0.01
# [      27]    Newton it 0 norm(r) =  1.41305e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.41305e+06 test=r
# [      27]    Newton it 1 norm(r) =  3.22282e-03  		 norm(r)/(rtol*norm(r0)+atol) = 322.282 test=r
# [      27]    Newton it 2 norm(r) =  5.28912e-13  		 norm(r)/(rtol*norm(r0)+atol) =  5.28912e-08
# [      27] Step Taken, System time step t= 3.40000e-01, dt= 1.00000e-02
# [      27] Step Taken, Model step t= 3.40000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      27] ==============================================================
# [      27] Solving over interval [ 3.30000e-01, 3.40000e-01]
# [      27] ==============================================================
# [      27] Model: navier_stokes_1d
# [      27] StepControl base stepExact t_model= 0.34 tOut= 0.34 t_model_last= 0.33 dt_model= 0.01 setting to 0.01
# [      27]    Newton it 0 norm(r) =  1.15934e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.15934e+06 test=r
# [      27]    Newton it 1 norm(r) =  2.91051e-03  		 norm(r)/(rtol*norm(r0)+atol) = 291.051 test=r
# [      27]    Newton it 2 norm(r) =  3.05159e-13  		 norm(r)/(rtol*norm(r0)+atol) =  3.05159e-08
# [      27] Step Taken, System time step t= 3.50000e-01, dt= 1.00000e-02
# [      27] Step Taken, Model step t= 3.50000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      27] ==============================================================
# [      27] Solving over interval [ 3.40000e-01, 3.50000e-01]
# [      27] ==============================================================
# [      27] Model: navier_stokes_1d
# [      27] StepControl base stepExact t_model= 0.35 tOut= 0.35 t_model_last= 0.34 dt_model= 0.01 setting to 0.01
# [      27]    Newton it 0 norm(r) =  8.87773e+00  		 norm(r)/(rtol*norm(r0)+atol) = 887773 test=r
# [      27]    Newton it 1 norm(r) =  2.72228e-03  		 norm(r)/(rtol*norm(r0)+atol) = 272.228 test=r
# [      27]    Newton it 2 norm(r) =  2.25175e-13  		 norm(r)/(rtol*norm(r0)+atol) =  2.25175e-08
# [      27] Step Taken, System time step t= 3.60000e-01, dt= 1.00000e-02
# [      27] Step Taken, Model step t= 3.60000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      27] ==============================================================
# [      27] Solving over interval [ 3.50000e-01, 3.60000e-01]
# [      27] ==============================================================
# [      27] Model: navier_stokes_1d
# [      27] StepControl base stepExact t_model= 0.36 tOut= 0.36 t_model_last= 0.35 dt_model= 0.01 setting to 0.01
# [      27]    Newton it 0 norm(r) =  6.03237e+00  		 norm(r)/(rtol*norm(r0)+atol) = 603237 test=r
# [      27]    Newton it 1 norm(r) =  2.63726e-03  		 norm(r)/(rtol*norm(r0)+atol) = 263.726 test=r
# [      27]    Newton it 2 norm(r) =  2.16517e-13  		 norm(r)/(rtol*norm(r0)+atol) =  2.16517e-08
# [      27] Step Taken, System time step t= 3.70000e-01, dt= 1.00000e-02
# [      27] Step Taken, Model step t= 3.70000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      27] ==============================================================
# [      27] Solving over interval [ 3.60000e-01, 3.70000e-01]
# [      27] ==============================================================
# [      27] Model: navier_stokes_1d
# [      27] StepControl base stepExact t_model= 0.37 tOut= 0.37 t_model_last= 0.36 dt_model= 0.01 setting to 0.01
# [      27]    Newton it 0 norm(r) =  3.13099e+00  		 norm(r)/(rtol*norm(r0)+atol) = 313099 test=r
# [      27]    Newton it 1 norm(r) =  2.61254e-03  		 norm(r)/(rtol*norm(r0)+atol) = 261.254 test=r
# [      27]    Newton it 2 norm(r) =  2.18318e-13  		 norm(r)/(rtol*norm(r0)+atol) =  2.18318e-08
# [      27] Step Taken, System time step t= 3.80000e-01, dt= 1.00000e-02
# [      27] Step Taken, Model step t= 3.80000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      27] ==============================================================
# [      27] Solving over interval [ 3.70000e-01, 3.80000e-01]
# [      27] ==============================================================
# [      27] Model: navier_stokes_1d
# [      27] StepControl base stepExact t_model= 0.38 tOut= 0.38 t_model_last= 0.37 dt_model= 0.01 setting to 0.01
# [      27]    Newton it 0 norm(r) =  8.55500e-01  		 norm(r)/(rtol*norm(r0)+atol) = 85550 test=r
# [      27]    Newton it 1 norm(r) =  2.60932e-03  		 norm(r)/(rtol*norm(r0)+atol) = 260.932 test=r
# [      27]    Newton it 2 norm(r) =  1.97650e-13  		 norm(r)/(rtol*norm(r0)+atol) =  1.97650e-08
# [      27] Step Taken, System time step t= 3.90000e-01, dt= 1.00000e-02
# [      27] Step Taken, Model step t= 3.90000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      27] ==============================================================
# [      27] Solving over interval [ 3.80000e-01, 3.90000e-01]
# [      27] ==============================================================
# [      27] Model: navier_stokes_1d
# [      27] StepControl base stepExact t_model= 0.39 tOut= 0.39 t_model_last= 0.38 dt_model= 0.01 setting to 0.01
# [      27]    Newton it 0 norm(r) =  3.12295e+00  		 norm(r)/(rtol*norm(r0)+atol) = 312295 test=r
# [      27]    Newton it 1 norm(r) =  2.61254e-03  		 norm(r)/(rtol*norm(r0)+atol) = 261.254 test=r
# [      27]    Newton it 2 norm(r) =  2.02373e-13  		 norm(r)/(rtol*norm(r0)+atol) =  2.02373e-08
# [      27] Step Taken, System time step t= 4.00000e-01, dt= 1.00000e-02
# [      27] Step Taken, Model step t= 4.00000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      27] ==============================================================
# [      27] Solving over interval [ 3.90000e-01, 4.00000e-01]
# [      27] ==============================================================
# [      27] Model: navier_stokes_1d
# [      27] StepControl base stepExact t_model= 0.4 tOut= 0.4 t_model_last= 0.39 dt_model= 0.01 setting to 0.01
# [      27]    Newton it 0 norm(r) =  6.02545e+00  		 norm(r)/(rtol*norm(r0)+atol) = 602545 test=r
# [      27]    Newton it 1 norm(r) =  2.63726e-03  		 norm(r)/(rtol*norm(r0)+atol) = 263.726 test=r
# [      27]    Newton it 2 norm(r) =  2.23383e-13  		 norm(r)/(rtol*norm(r0)+atol) =  2.23383e-08
# [      27] Step Taken, System time step t= 4.10000e-01, dt= 1.00000e-02
# [      27] Step Taken, Model step t= 4.10000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      27] ==============================================================
# [      27] Solving over interval [ 4.00000e-01, 4.10000e-01]
# [      27] ==============================================================
# [      27] Model: navier_stokes_1d
# [      27] StepControl base stepExact t_model= 0.41 tOut= 0.41 t_model_last= 0.4 dt_model= 0.01 setting to 0.01
# [      27]    Newton it 0 norm(r) =  8.87296e+00  		 norm(r)/(rtol*norm(r0)+atol) = 887296 test=r
# [      27]    Newton it 1 norm(r) =  2.72228e-03  		 norm(r)/(rtol*norm(r0)+atol) = 272.228 test=r
# [      27]    Newton it 2 norm(r) =  2.20849e-13  		 norm(r)/(rtol*norm(r0)+atol) =  2.20849e-08
# [      27] Step Taken, System time step t= 4.20000e-01, dt= 1.00000e-02
# [      27] Step Taken, Model step t= 4.20000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      27] ==============================================================
# [      27] Solving over interval [ 4.10000e-01, 4.20000e-01]
# [      27] ==============================================================
# [      27] Model: navier_stokes_1d
# [      27] StepControl base stepExact t_model= 0.42 tOut= 0.42 t_model_last= 0.41 dt_model= 0.01 setting to 0.01
# [      27]    Newton it 0 norm(r) =  1.15915e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.15915e+06 test=r
# [      27]    Newton it 1 norm(r) =  2.91051e-03  		 norm(r)/(rtol*norm(r0)+atol) = 291.051 test=r
# [      27]    Newton it 2 norm(r) =  3.02977e-13  		 norm(r)/(rtol*norm(r0)+atol) =  3.02977e-08
# [      27] Step Taken, System time step t= 4.30000e-01, dt= 1.00000e-02
# [      27] Step Taken, Model step t= 4.30000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      28] ==============================================================
# [      28] Solving over interval [ 4.20000e-01, 4.30000e-01]
# [      28] ==============================================================
# [      28] Model: navier_stokes_1d
# [      28] StepControl base stepExact t_model= 0.43 tOut= 0.43 t_model_last= 0.42 dt_model= 0.01 setting to 0.01
# [      28]    Newton it 0 norm(r) =  1.41319e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.41319e+06 test=r
# [      28]    Newton it 1 norm(r) =  3.22282e-03  		 norm(r)/(rtol*norm(r0)+atol) = 322.282 test=r
# [      28]    Newton it 2 norm(r) =  5.10605e-13  		 norm(r)/(rtol*norm(r0)+atol) =  5.10605e-08
# [      28] Step Taken, System time step t= 4.40000e-01, dt= 1.00000e-02
# [      28] Step Taken, Model step t= 4.40000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      28] ==============================================================
# [      28] Solving over interval [ 4.30000e-01, 4.40000e-01]
# [      28] ==============================================================
# [      28] Model: navier_stokes_1d
# [      28] StepControl base stepExact t_model= 0.44 tOut= 0.44 t_model_last= 0.43 dt_model= 0.01 setting to 0.01
# [      28]    Newton it 0 norm(r) =  1.64521e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.64521e+06 test=r
# [      28]    Newton it 1 norm(r) =  3.64497e-03  		 norm(r)/(rtol*norm(r0)+atol) = 364.497 test=r
# [      28]    Newton it 2 norm(r) =  8.63506e-13  		 norm(r)/(rtol*norm(r0)+atol) =  8.63506e-08
# [      28] Step Taken, System time step t= 4.50000e-01, dt= 1.00000e-02
# [      28] Step Taken, Model step t= 4.50000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      28] ==============================================================
# [      28] Solving over interval [ 4.40000e-01, 4.50000e-01]
# [      28] ==============================================================
# [      28] Model: navier_stokes_1d
# [      28] StepControl base stepExact t_model= 0.45 tOut= 0.45 t_model_last= 0.44 dt_model= 0.01 setting to 0.01
# [      28]    Newton it 0 norm(r) =  1.85144e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.85144e+06 test=r
# [      28]    Newton it 1 norm(r) =  4.13590e-03  		 norm(r)/(rtol*norm(r0)+atol) = 413.59 test=r
# [      28]    Newton it 2 norm(r) =  1.34099e-12  		 norm(r)/(rtol*norm(r0)+atol) =  1.34099e-07
# [      28] Step Taken, System time step t= 4.60000e-01, dt= 1.00000e-02
# [      28] Step Taken, Model step t= 4.60000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      28] ==============================================================
# [      28] Solving over interval [ 4.50000e-01, 4.60000e-01]
# [      28] ==============================================================
# [      28] Model: navier_stokes_1d
# [      28] StepControl base stepExact t_model= 0.46 tOut= 0.46 t_model_last= 0.45 dt_model= 0.01 setting to 0.01
# [      28]    Newton it 0 norm(r) =  2.02857e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.02857e+06 test=r
# [      28]    Newton it 1 norm(r) =  4.64388e-03  		 norm(r)/(rtol*norm(r0)+atol) = 464.388 test=r
# [      28]    Newton it 2 norm(r) =  1.84899e-12  		 norm(r)/(rtol*norm(r0)+atol) =  1.84899e-07
# [      28] Step Taken, System time step t= 4.70000e-01, dt= 1.00000e-02
# [      28] Step Taken, Model step t= 4.70000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      28] ==============================================================
# [      28] Solving over interval [ 4.60000e-01, 4.70000e-01]
# [      28] ==============================================================
# [      28] Model: navier_stokes_1d
# [      28] StepControl base stepExact t_model= 0.47 tOut= 0.47 t_model_last= 0.46 dt_model= 0.01 setting to 0.01
# [      28]    Newton it 0 norm(r) =  2.17378e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.17378e+06 test=r
# [      28]    Newton it 1 norm(r) =  5.11815e-03  		 norm(r)/(rtol*norm(r0)+atol) = 511.815 test=r
# [      28]    Newton it 2 norm(r) =  2.44959e-12  		 norm(r)/(rtol*norm(r0)+atol) =  2.44959e-07
# [      28] Step Taken, System time step t= 4.80000e-01, dt= 1.00000e-02
# [      28] Step Taken, Model step t= 4.80000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      28] ==============================================================
# [      28] Solving over interval [ 4.70000e-01, 4.80000e-01]
# [      28] ==============================================================
# [      28] Model: navier_stokes_1d
# [      28] StepControl base stepExact t_model= 0.48 tOut= 0.48 t_model_last= 0.47 dt_model= 0.01 setting to 0.01
# [      28]    Newton it 0 norm(r) =  2.28475e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.28475e+06 test=r
# [      28]    Newton it 1 norm(r) =  5.51471e-03  		 norm(r)/(rtol*norm(r0)+atol) = 551.471 test=r
# [      28]    Newton it 2 norm(r) =  2.95966e-12  		 norm(r)/(rtol*norm(r0)+atol) =  2.95966e-07
# [      28] Step Taken, System time step t= 4.90000e-01, dt= 1.00000e-02
# [      28] Step Taken, Model step t= 4.90000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      28] ==============================================================
# [      28] Solving over interval [ 4.80000e-01, 4.90000e-01]
# [      28] ==============================================================
# [      28] Model: navier_stokes_1d
# [      28] StepControl base stepExact t_model= 0.49 tOut= 0.49 t_model_last= 0.48 dt_model= 0.01 setting to 0.01
# [      28]    Newton it 0 norm(r) =  2.35972e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.35972e+06 test=r
# [      28]    Newton it 1 norm(r) =  5.79896e-03  		 norm(r)/(rtol*norm(r0)+atol) = 579.896 test=r
# [      28]    Newton it 2 norm(r) =  3.35385e-12  		 norm(r)/(rtol*norm(r0)+atol) =  3.35385e-07
# [      28] Step Taken, System time step t= 5.00000e-01, dt= 1.00000e-02
# [      28] Step Taken, Model step t= 5.00000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      28] ==============================================================
# [      28] Solving over interval [ 4.90000e-01, 5.00000e-01]
# [      28] ==============================================================
# [      28] Model: navier_stokes_1d
# [      28] StepControl base stepExact t_model= 0.5 tOut= 0.5 t_model_last= 0.49 dt_model= 0.01 setting to 0.01
# [      28]    Newton it 0 norm(r) =  2.39750e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.3975e+06 test=r
# [      28]    Newton it 1 norm(r) =  5.94713e-03  		 norm(r)/(rtol*norm(r0)+atol) = 594.713 test=r
# [      28]    Newton it 2 norm(r) =  3.56655e-12  		 norm(r)/(rtol*norm(r0)+atol) =  3.56655e-07
# [      28] Step Taken, System time step t= 5.10000e-01, dt= 1.00000e-02
# [      28] Step Taken, Model step t= 5.10000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      28] ==============================================================
# [      28] Solving over interval [ 5.00000e-01, 5.10000e-01]
# [      28] ==============================================================
# [      28] Model: navier_stokes_1d
# [      28] StepControl base stepExact t_model= 0.51 tOut= 0.51 t_model_last= 0.5 dt_model= 0.01 setting to 0.01
# [      28]    Newton it 0 norm(r) =  2.39748e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.39748e+06 test=r
# [      28]    Newton it 1 norm(r) =  5.94714e-03  		 norm(r)/(rtol*norm(r0)+atol) = 594.714 test=r
# [      28]    Newton it 2 norm(r) =  3.56215e-12  		 norm(r)/(rtol*norm(r0)+atol) =  3.56215e-07
# [      28] Step Taken, System time step t= 5.20000e-01, dt= 1.00000e-02
# [      28] Step Taken, Model step t= 5.20000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      28] ==============================================================
# [      28] Solving over interval [ 5.10000e-01, 5.20000e-01]
# [      28] ==============================================================
# [      28] Model: navier_stokes_1d
# [      28] StepControl base stepExact t_model= 0.52 tOut= 0.52 t_model_last= 0.51 dt_model= 0.01 setting to 0.01
# [      28]    Newton it 0 norm(r) =  2.35967e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.35967e+06 test=r
# [      28]    Newton it 1 norm(r) =  5.79896e-03  		 norm(r)/(rtol*norm(r0)+atol) = 579.896 test=r
# [      28]    Newton it 2 norm(r) =  3.35800e-12  		 norm(r)/(rtol*norm(r0)+atol) =  3.35800e-07
# [      28] Step Taken, System time step t= 5.30000e-01, dt= 1.00000e-02
# [      28] Step Taken, Model step t= 5.30000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      28] ==============================================================
# [      28] Solving over interval [ 5.20000e-01, 5.30000e-01]
# [      28] ==============================================================
# [      28] Model: navier_stokes_1d
# [      28] StepControl base stepExact t_model= 0.53 tOut= 0.53 t_model_last= 0.52 dt_model= 0.01 setting to 0.01
# [      28]    Newton it 0 norm(r) =  2.28466e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.28466e+06 test=r
# ...
# [      31]    Newton it 2 norm(r) =  1.34432e-12  		 norm(r)/(rtol*norm(r0)+atol) =  1.34432e-07
# [      31] Step Taken, System time step t= 8.20000e-01, dt= 1.00000e-02
# [      31] Step Taken, Model step t= 8.20000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      31] ==============================================================
# [      31] Solving over interval [ 8.10000e-01, 8.20000e-01]
# [      31] ==============================================================
# [      31] Model: navier_stokes_1d
# [      31] StepControl base stepExact t_model= 0.82 tOut= 0.82 t_model_last= 0.81 dt_model= 0.01 setting to 0.01
# [      31]    Newton it 0 norm(r) =  1.64532e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.64532e+06 test=r
# [      31]    Newton it 1 norm(r) =  3.64497e-03  		 norm(r)/(rtol*norm(r0)+atol) = 364.497 test=r
# [      31]    Newton it 2 norm(r) =  8.90759e-13  		 norm(r)/(rtol*norm(r0)+atol) =  8.90759e-08
# [      31] Step Taken, System time step t= 8.30000e-01, dt= 1.00000e-02
# [      31] Step Taken, Model step t= 8.30000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      31] ==============================================================
# [      31] Solving over interval [ 8.20000e-01, 8.30000e-01]
# [      31] ==============================================================
# [      31] Model: navier_stokes_1d
# [      31] StepControl base stepExact t_model= 0.83 tOut= 0.83 t_model_last= 0.82 dt_model= 0.01 setting to 0.01
# [      31]    Newton it 0 norm(r) =  1.41364e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.41364e+06 test=r
# [      31]    Newton it 1 norm(r) =  3.22282e-03  		 norm(r)/(rtol*norm(r0)+atol) = 322.282 test=r
# [      31]    Newton it 2 norm(r) =  5.19638e-13  		 norm(r)/(rtol*norm(r0)+atol) =  5.19638e-08
# [      31] Step Taken, System time step t= 8.40000e-01, dt= 1.00000e-02
# [      31] Step Taken, Model step t= 8.40000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      31] ==============================================================
# [      31] Solving over interval [ 8.30000e-01, 8.40000e-01]
# [      31] ==============================================================
# [      31] Model: navier_stokes_1d
# [      31] StepControl base stepExact t_model= 0.84 tOut= 0.84 t_model_last= 0.83 dt_model= 0.01 setting to 0.01
# [      31]    Newton it 0 norm(r) =  1.15991e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.15991e+06 test=r
# [      31]    Newton it 1 norm(r) =  2.91051e-03  		 norm(r)/(rtol*norm(r0)+atol) = 291.051 test=r
# [      31]    Newton it 2 norm(r) =  2.86592e-13  		 norm(r)/(rtol*norm(r0)+atol) =  2.86592e-08
# [      31] Step Taken, System time step t= 8.50000e-01, dt= 1.00000e-02
# [      31] Step Taken, Model step t= 8.50000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      32] ==============================================================
# [      32] Solving over interval [ 8.40000e-01, 8.50000e-01]
# [      32] ==============================================================
# [      32] Model: navier_stokes_1d
# [      32] StepControl base stepExact t_model= 0.85 tOut= 0.85 t_model_last= 0.84 dt_model= 0.01 setting to 0.01
# [      32]    Newton it 0 norm(r) =  8.88316e+00  		 norm(r)/(rtol*norm(r0)+atol) = 888316 test=r
# [      32]    Newton it 1 norm(r) =  2.72228e-03  		 norm(r)/(rtol*norm(r0)+atol) = 272.228 test=r
# [      32]    Newton it 2 norm(r) =  2.35596e-13  		 norm(r)/(rtol*norm(r0)+atol) =  2.35596e-08
# [      32] Step Taken, System time step t= 8.60000e-01, dt= 1.00000e-02
# [      32] Step Taken, Model step t= 8.60000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      32] ==============================================================
# [      32] Solving over interval [ 8.50000e-01, 8.60000e-01]
# [      32] ==============================================================
# [      32] Model: navier_stokes_1d
# [      32] StepControl base stepExact t_model= 0.86 tOut= 0.86 t_model_last= 0.85 dt_model= 0.01 setting to 0.01
# [      32]    Newton it 0 norm(r) =  6.03744e+00  		 norm(r)/(rtol*norm(r0)+atol) = 603744 test=r
# [      32]    Newton it 1 norm(r) =  2.63726e-03  		 norm(r)/(rtol*norm(r0)+atol) = 263.726 test=r
# [      32]    Newton it 2 norm(r) =  2.00336e-13  		 norm(r)/(rtol*norm(r0)+atol) =  2.00336e-08
# [      32] Step Taken, System time step t= 8.70000e-01, dt= 1.00000e-02
# [      32] Step Taken, Model step t= 8.70000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      32] ==============================================================
# [      32] Solving over interval [ 8.60000e-01, 8.70000e-01]
# [      32] ==============================================================
# [      32] Model: navier_stokes_1d
# [      32] StepControl base stepExact t_model= 0.87 tOut= 0.87 t_model_last= 0.86 dt_model= 0.01 setting to 0.01
# [      32]    Newton it 0 norm(r) =  3.13548e+00  		 norm(r)/(rtol*norm(r0)+atol) = 313548 test=r
# [      32]    Newton it 1 norm(r) =  2.61254e-03  		 norm(r)/(rtol*norm(r0)+atol) = 261.254 test=r
# [      32]    Newton it 2 norm(r) =  2.11424e-13  		 norm(r)/(rtol*norm(r0)+atol) =  2.11424e-08
# [      32] Step Taken, System time step t= 8.80000e-01, dt= 1.00000e-02
# [      32] Step Taken, Model step t= 8.80000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      32] ==============================================================
# [      32] Solving over interval [ 8.70000e-01, 8.80000e-01]
# [      32] ==============================================================
# [      32] Model: navier_stokes_1d
# [      32] StepControl base stepExact t_model= 0.88 tOut= 0.88 t_model_last= 0.87 dt_model= 0.01 setting to 0.01
# [      32]    Newton it 0 norm(r) =  8.54324e-01  		 norm(r)/(rtol*norm(r0)+atol) = 85432.4 test=r
# [      32]    Newton it 1 norm(r) =  2.60932e-03  		 norm(r)/(rtol*norm(r0)+atol) = 260.932 test=r
# [      32]    Newton it 2 norm(r) =  2.05824e-13  		 norm(r)/(rtol*norm(r0)+atol) =  2.05824e-08
# [      32] Step Taken, System time step t= 8.90000e-01, dt= 1.00000e-02
# [      32] Step Taken, Model step t= 8.90000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      32] ==============================================================
# [      32] Solving over interval [ 8.80000e-01, 8.90000e-01]
# [      32] ==============================================================
# [      32] Model: navier_stokes_1d
# [      32] StepControl base stepExact t_model= 0.89 tOut= 0.89 t_model_last= 0.88 dt_model= 0.01 setting to 0.01
# [      32]    Newton it 0 norm(r) =  3.11841e+00  		 norm(r)/(rtol*norm(r0)+atol) = 311841 test=r
# [      32]    Newton it 1 norm(r) =  2.61254e-03  		 norm(r)/(rtol*norm(r0)+atol) = 261.254 test=r
# [      32]    Newton it 2 norm(r) =  2.15291e-13  		 norm(r)/(rtol*norm(r0)+atol) =  2.15291e-08
# [      32] Step Taken, System time step t= 9.00000e-01, dt= 1.00000e-02
# [      32] Step Taken, Model step t= 9.00000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      32] ==============================================================
# [      32] Solving over interval [ 8.90000e-01, 9.00000e-01]
# [      32] ==============================================================
# [      32] Model: navier_stokes_1d
# [      32] StepControl base stepExact t_model= 0.9 tOut= 0.9 t_model_last= 0.89 dt_model= 0.01 setting to 0.01
# [      32]    Newton it 0 norm(r) =  6.02129e+00  		 norm(r)/(rtol*norm(r0)+atol) = 602129 test=r
# [      32]    Newton it 1 norm(r) =  2.63726e-03  		 norm(r)/(rtol*norm(r0)+atol) = 263.726 test=r
# [      32]    Newton it 2 norm(r) =  2.08846e-13  		 norm(r)/(rtol*norm(r0)+atol) =  2.08846e-08
# [      32] Step Taken, System time step t= 9.10000e-01, dt= 1.00000e-02
# [      32] Step Taken, Model step t= 9.10000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      32] ==============================================================
# [      32] Solving over interval [ 9.00000e-01, 9.10000e-01]
# [      32] ==============================================================
# [      32] Model: navier_stokes_1d
# [      32] StepControl base stepExact t_model= 0.91 tOut= 0.91 t_model_last= 0.9 dt_model= 0.01 setting to 0.01
# [      32]    Newton it 0 norm(r) =  8.86919e+00  		 norm(r)/(rtol*norm(r0)+atol) = 886919 test=r
# [      32]    Newton it 1 norm(r) =  2.72228e-03  		 norm(r)/(rtol*norm(r0)+atol) = 272.228 test=r
# [      32]    Newton it 2 norm(r) =  2.46385e-13  		 norm(r)/(rtol*norm(r0)+atol) =  2.46385e-08
# [      32] Step Taken, System time step t= 9.20000e-01, dt= 1.00000e-02
# [      32] Step Taken, Model step t= 9.20000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      33] ==============================================================
# [      33] Solving over interval [ 9.10000e-01, 9.20000e-01]
# [      33] ==============================================================
# [      33] Model: navier_stokes_1d
# [      33] StepControl base stepExact t_model= 0.92 tOut= 0.92 t_model_last= 0.91 dt_model= 0.01 setting to 0.01
# [      33]    Newton it 0 norm(r) =  1.15881e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.15881e+06 test=r
# [      33]    Newton it 1 norm(r) =  2.91051e-03  		 norm(r)/(rtol*norm(r0)+atol) = 291.051 test=r
# [      33]    Newton it 2 norm(r) =  3.20406e-13  		 norm(r)/(rtol*norm(r0)+atol) =  3.20406e-08
# [      33] Step Taken, System time step t= 9.30000e-01, dt= 1.00000e-02
# [      33] Step Taken, Model step t= 9.30000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      33] ==============================================================
# [      33] Solving over interval [ 9.20000e-01, 9.30000e-01]
# [      33] ==============================================================
# [      33] Model: navier_stokes_1d
# [      33] StepControl base stepExact t_model= 0.93 tOut= 0.93 t_model_last= 0.92 dt_model= 0.01 setting to 0.01
# [      33]    Newton it 0 norm(r) =  1.41289e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.41289e+06 test=r
# [      33]    Newton it 1 norm(r) =  3.22282e-03  		 norm(r)/(rtol*norm(r0)+atol) = 322.282 test=r
# [      33]    Newton it 2 norm(r) =  5.14885e-13  		 norm(r)/(rtol*norm(r0)+atol) =  5.14885e-08
# [      33] Step Taken, System time step t= 9.40000e-01, dt= 1.00000e-02
# [      33] Step Taken, Model step t= 9.40000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      33] ==============================================================
# [      33] Solving over interval [ 9.30000e-01, 9.40000e-01]
# [      33] ==============================================================
# [      33] Model: navier_stokes_1d
# [      33] StepControl base stepExact t_model= 0.94 tOut= 0.94 t_model_last= 0.93 dt_model= 0.01 setting to 0.01
# [      33]    Newton it 0 norm(r) =  1.64495e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.64495e+06 test=r
# [      33]    Newton it 1 norm(r) =  3.64497e-03  		 norm(r)/(rtol*norm(r0)+atol) = 364.497 test=r
# [      33]    Newton it 2 norm(r) =  8.54573e-13  		 norm(r)/(rtol*norm(r0)+atol) =  8.54573e-08
# [      33] Step Taken, System time step t= 9.50000e-01, dt= 1.00000e-02
# [      33] Step Taken, Model step t= 9.50000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      33] ==============================================================
# [      33] Solving over interval [ 9.40000e-01, 9.50000e-01]
# [      33] ==============================================================
# [      33] Model: navier_stokes_1d
# [      33] StepControl base stepExact t_model= 0.95 tOut= 0.95 t_model_last= 0.94 dt_model= 0.01 setting to 0.01
# [      33]    Newton it 0 norm(r) =  1.85122e+01  		 norm(r)/(rtol*norm(r0)+atol) = 1.85122e+06 test=r
# [      33]    Newton it 1 norm(r) =  4.13590e-03  		 norm(r)/(rtol*norm(r0)+atol) = 413.59 test=r
# [      33]    Newton it 2 norm(r) =  1.32696e-12  		 norm(r)/(rtol*norm(r0)+atol) =  1.32696e-07
# [      33] Step Taken, System time step t= 9.60000e-01, dt= 1.00000e-02
# [      33] Step Taken, Model step t= 9.60000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      33] ==============================================================
# [      33] Solving over interval [ 9.50000e-01, 9.60000e-01]
# [      33] ==============================================================
# [      33] Model: navier_stokes_1d
# [      33] StepControl base stepExact t_model= 0.96 tOut= 0.96 t_model_last= 0.95 dt_model= 0.01 setting to 0.01
# [      33]    Newton it 0 norm(r) =  2.02839e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.02839e+06 test=r
# [      33]    Newton it 1 norm(r) =  4.64388e-03  		 norm(r)/(rtol*norm(r0)+atol) = 464.388 test=r
# [      33]    Newton it 2 norm(r) =  1.87710e-12  		 norm(r)/(rtol*norm(r0)+atol) =  1.87710e-07
# [      33] Step Taken, System time step t= 9.70000e-01, dt= 1.00000e-02
# [      33] Step Taken, Model step t= 9.70000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      33] ==============================================================
# [      33] Solving over interval [ 9.60000e-01, 9.70000e-01]
# [      33] ==============================================================
# [      33] Model: navier_stokes_1d
# [      33] StepControl base stepExact t_model= 0.97 tOut= 0.97 t_model_last= 0.96 dt_model= 0.01 setting to 0.01
# [      33]    Newton it 0 norm(r) =  2.17364e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.17364e+06 test=r
# [      33]    Newton it 1 norm(r) =  5.11815e-03  		 norm(r)/(rtol*norm(r0)+atol) = 511.815 test=r
# [      33]    Newton it 2 norm(r) =  2.43640e-12  		 norm(r)/(rtol*norm(r0)+atol) =  2.43640e-07
# [      33] Step Taken, System time step t= 9.80000e-01, dt= 1.00000e-02
# [      33] Step Taken, Model step t= 9.80000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      33] ==============================================================
# [      33] Solving over interval [ 9.70000e-01, 9.80000e-01]
# [      33] ==============================================================
# [      33] Model: navier_stokes_1d
# [      33] StepControl base stepExact t_model= 0.98 tOut= 0.98 t_model_last= 0.97 dt_model= 0.01 setting to 0.01
# [      33]    Newton it 0 norm(r) =  2.28465e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.28465e+06 test=r
# [      33]    Newton it 1 norm(r) =  5.51471e-03  		 norm(r)/(rtol*norm(r0)+atol) = 551.471 test=r
# [      33]    Newton it 2 norm(r) =  2.95438e-12  		 norm(r)/(rtol*norm(r0)+atol) =  2.95438e-07
# [      33] Step Taken, System time step t= 9.90000e-01, dt= 1.00000e-02
# [      33] Step Taken, Model step t= 9.90000e-01, dt= 1.00000e-02 for model navier_stokes_1d
# [      33] ==============================================================
# [      33] Solving over interval [ 9.80000e-01, 9.90000e-01]
# [      33] ==============================================================
# [      33] Model: navier_stokes_1d
# [      33] StepControl base stepExact t_model= 0.99 tOut= 0.99 t_model_last= 0.98 dt_model= 0.01 setting to 0.01
# [      33]    Newton it 0 norm(r) =  2.35966e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.35966e+06 test=r
# [      33]    Newton it 1 norm(r) =  5.79896e-03  		 norm(r)/(rtol*norm(r0)+atol) = 579.896 test=r
# [      33]    Newton it 2 norm(r) =  3.35208e-12  		 norm(r)/(rtol*norm(r0)+atol) =  3.35208e-07
# [      33] Step Taken, System time step t= 1.00000e+00, dt= 1.00000e-02
# [      33] Step Taken, Model step t= 1.00000e+00, dt= 1.00000e-02 for model navier_stokes_1d
# [      33] ==============================================================
# [      33] Solving over interval [ 9.90000e-01, 1.00000e+00]
# [      33] ==============================================================
# [      33] Model: navier_stokes_1d
# [      33] StepControl base stepExact t_model= 1.0 tOut= 1.0 t_model_last= 0.99 dt_model= 0.01 setting to 0.01
# [      33]    Newton it 0 norm(r) =  2.39748e+01  		 norm(r)/(rtol*norm(r0)+atol) = 2.39748e+06 test=r
# [      33]    Newton it 1 norm(r) =  5.94713e-03  		 norm(r)/(rtol*norm(r0)+atol) = 594.713 test=r
# [      33]    Newton it 2 norm(r) =  3.55613e-12  		 norm(r)/(rtol*norm(r0)+atol) =  3.55613e-07
# [      33] Step Taken, System time step t= 1.01000e+00, dt= 1.00000e-02
# [      33] Step Taken, Model step t= 1.01000e+00, dt= 1.00000e-02 for model navier_stokes_1d
# [      34] Closing solution archive for navier_stokes_1d
# [      34] Closing Archive
# [      34] Done Closing Archive

# %% [markdown]
# Plot the solution with matplotlib. Only works for $C^0 P^1$ right now

# %%
# %matplotlib inline

# %%
# plot computed solutions

import matplotlib.pyplot as plt
fig, (ax1,ax2) = plt.subplots(2,1)
fig.tight_layout() # spread out the plots so that they don't overlap
ax1.plot(x,pT)
ax1.set_xlabel('x')
ax1.set_ylabel('p(T)')
useTH=True
if not useTH:
    ax2.plot(x,vT[:numerics.nn])
    ax2.set_xlabel('x')
    ax2.set_ylabel('v(T)')
else:
    xm = np.array(0.5*(x[:-1]+x[1:]))
    xq=[];
    vq=[];
    pq=[];
    for i in range(numerics.nn-1):
        xq.append(x[i])
        vq.append(vT[i])
#    uq.append(u[i])
        xq.append(xm[i])
        vq.append(vT[numerics.nn+i])
#    uq.append(u[numerics.nn+i])
    xq.append(x[-1])
    vq.append(vT[-1])
#uq.append(u[-1])
#xq = np.concatenate([x,xm])
#xq.append(x1[-1])
#ax1.plot(xq,uq)
    ax2.plot(xq,vq)
    ax2.set_xlabel('x')
    ax2.set_ylabel('v(T)')

# %%
# extract exact solutions
import numpy as np
pex_vals_at_T = pex0(ns.modelList[0].levelModelList[-1].mesh.nodeArray,physics.T)
vex_vals_at_T = vex0(ns.modelList[0].levelModelList[-1].mesh.nodeArray,physics.T)
rex_vals_at_T = rofx0(ns.modelList[0].levelModelList[-1].mesh.nodeArray,physics.T)

# %% [markdown]
# Compare to the exact solution, evaluated at the degrees of freedom. Again, only works for $C^0 P^1$ elements

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3,1)
fig.tight_layout() # spread out the plots so that they don't overlap
ax1.plot(x,pex_vals_at_T)
ax1.set_xlabel('x')
ax1.set_ylabel('p(T) exact') 
ax2.plot(x,vex_vals_at_T)
ax2.set_xlabel('x')
ax2.set_ylabel('v(T) exact')
ax3.plot(x,rex_vals_at_T)
ax3.set_xlabel('x')
ax3.set_ylabel('r(T) exact')

# %%
print x.shape,xm.shape

# output error data for pressure
fig, (ax1,ax2) = plt.subplots(2,1)
fig.tight_layout() # spread out the plots so that they don't overlap
err_p = pT-pex_vals_at_T
print "maximal error of pressure on gridpoints             = %s" % max(abs(err_p))
ax1.plot(x,abs(err_p))
ax1.set_xlabel('x')
ax1.set_ylabel('|p-p_{true}| at time T')
err_p *= err_p
err_p *= physics.L[0]*physics.L[1]/(numerics.nn)
L2approx_p = np.sqrt(err_p.sum())

print "Trapezoidal rule approx to \ell_2 error of pressure = %s\n" % L2approx_p


# output error data for velocity
vtrue = 0.0*vT
for i,val in enumerate(np.concatenate((x,xm))):
    vtrue[i] = vex0(np.array([val]),physics.T)
err_v = vT-vtrue
print "maximal error of velocity on gridpoints                        is %s" % max(abs(err_v))
ax2.plot(xq,err_v)
ax2.set_xlabel('x')
ax2.set_ylabel('|v-v_{true}| at time T')
err_v *= err_v
err_v *= physics.L[0]*physics.L[1]/(numerics.nn)
L2approx_v = np.sqrt(err_v.sum())
print "Trapezoidal rule approx to \ell_2 error of velocity for nn=%s is %s" % (numerics.nn, L2approx_v)
# Out:
# (101,) (100,)
# maximal error of pressure on gridpoints             = 0.0631607853313
# Trapezoidal rule approx to \ell_2 error of pressure = 0.0382973545235
#
# maximal error of velocity on gridpoints                        is 8.14329391696e-08
# Trapezoidal rule approx to \ell_2 error of velocity for nn=101 is 4.98119736239e-08
